# %%
import os
import shutil
import cv2
import math
import random
import numpy as np
import tensorflow as tf
from tensorflow import keras
from collections import deque
import matplotlib.pyplot as plt
plt.style.use("seaborn")
import tqdm
# %matplotlib inline
from tensorflow.keras import Model
from sklearn.model_selection import train_test_split
from keras.applications.mobilenet_v2 import MobileNetV2
from keras.layers import *
from keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.utils import plot_model

from IPython.display import HTML
from base64 import b64encode
from tensorflow.keras.layers import Input,Dense, Flatten, ReLU, Conv2D, DepthwiseConv2D,AvgPool2D, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.optimizers import Adam
import keras.backend as K
from typing import Optional
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings('ignore')

# %%
def Play_Video(filepath):
    html = ''
    video = open(filepath, 'rb').read()
    src = 'data:video/mp4;base64,' + b64encode(video).decode()
    html += '<video width=640 muted controls autoplay loop><source src="%s" type="video/mp4"></video>' % src
    return HTML(html)

# %%
IMAGE_HEIGHT, IMAGE_WIDTH = 128, 128
SEQUENCE_LENGTH = 30

# %%
CLASSES_LIST = ["E04(Medial_Rotation)"]

# %%
def frames_extraction(video_path):
    frames_list = []
    video_reader = cv2.VideoCapture(video_path)
    video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))
    skip_frames_window = max(int(video_frames_count/SEQUENCE_LENGTH), 1)

    for frame_counter in range(SEQUENCE_LENGTH):
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)
        success, frame = video_reader.read()

        if not success:
            break

        resized_frame = cv2.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))
        normalized_frame = resized_frame / 255
        frames_list.append(normalized_frame)

    video_reader.release()
    return frames_list

# %%
def create_dataset(video_dir, csv_file_path):
    features = []
    labels = []
    video_files_paths = []
    matching_files_count = 0

    # Read the CSV file
    csv_data = pd.read_csv(csv_file_path)

    for class_index, class_name in enumerate(CLASSES_LIST):
        print(f'Extracting Data of Class: {class_name}')
        files_list = os.listdir(os.path.join(video_dir, class_name))

        for file_name in files_list:
            # Remove the .mp4 extension from the file name
            video_name = os.path.splitext(file_name)[0]

            video_file_path = os.path.join(video_dir, class_name, file_name)
            frames = frames_extraction(video_file_path)

            if len(frames) == SEQUENCE_LENGTH:
                # Search for the exercise name in the CSV data that matches with video file name
                matching_row = csv_data[csv_data['Excercise Name'].str.lower() == video_name.lower()]

                if not matching_row.empty:
                    assessment_score = matching_row['Assessment Score'].values[0]
                    features.append(frames)
                    labels.append(class_index)
                    video_files_paths.append(video_file_path)
                    matching_files_count += 1
                    print(f'Matched file: {video_name}, Assessment Score: {assessment_score}')
                else:
                    # Append None if no matching row is found
                    features.append(frames)
                    labels.append(class_index)
                    video_files_paths.append(video_file_path)
                    print(f'No matching row found for file: {video_name}')

    features = np.asarray(features)
    labels = np.asarray(labels)

    print(f'Total matching files: {matching_files_count}')

    return features, labels, matching_files_count, video_files_paths

# %%
import pandas as pd

video_dir = '/kaggle/input/regression-folders/dataset_regression'
csv_file_path = '/kaggle/input/csv-files-regression/Ex_04_sub.csv'
features, labels, matching_files_count, video_files_paths =  create_dataset(video_dir, csv_file_path)
print("Features shape:", features.shape)
print("Labels shape:", labels.shape)
print("Matching files count:", matching_files_count)
print("Number of video files:", len(video_files_paths))
# Out:
# Extracting Data of Class: E04(Medial_Rotation)
# Matched file: E04_P23_AL_VFL_GM, Assessment Score: 81.43
# Matched file: E04_P09_AL_VML_GF, Assessment Score: 81.43
# Matched file: E04_P16_AL_VLL_GF, Assessment Score: 73.81
# Matched file: E04_P08_AL_VO_GM, Assessment Score: 72.86
# Matched file: E04_P22_AR_VFL_GM, Assessment Score: 69.52
# Matched file: E04_P19_AR_VFL_GM, Assessment Score: 74.76
# Matched file: E04_P04_AR_VO_GM, Assessment Score: 61.9
# Matched file: E04_P18_AR_VFL_GM, Assessment Score: 75.71
# Matched file: E04_P16_AF_VO_GF, Assessment Score: 76.19
# Matched file: E04_P05_AF_VHJ_GM, Assessment Score: 90.48
# Matched file: E04_P09_AL_VLL_GF, Assessment Score: 84.29
# Matched file: E04_P23_AL_VLJ_GM, Assessment Score: 70.95
# Matched file: E04_P07_AL_VML_GM, Assessment Score: 68.1
# Matched file: E04_P05_AF_VLJ_GM, Assessment Score: 95.24
# Matched file: E04_P17_AR_VHJ_GM, Assessment Score: 95.24
# Matched file: E04_P07_AR_VHJ_GM, Assessment Score: 57.14
# Matched file: E04_P22_AR_VHJ_GM, Assessment Score: 75.24
# Matched file: E04_P18_AR_VO_GM, Assessment Score: 65.71
# Matched file: E04_P01_AL_VFL_GM, Assessment Score: 73.81
# Matched file: E04_P07_AL_VO_GM, Assessment Score: 69.05
# Matched file: E04_P12_AF_VO_GF, Assessment Score: 100.0
# Matched file: E04_P02_AL_VO_GM, Assessment Score: 73.33
# Matched file: E04_P07_AL_VFL_GM, Assessment Score: 67.14
# Matched file: E04_P08_AF_VO_GM, Assessment Score: 72.86
# Matched file: E04_P07_AF_VFL_GM, Assessment Score: 65.71
# Matched file: E04_P01_AF_VO_GM, Assessment Score: 80.48
# Matched file: E04_P01_AF_VML_GM, Assessment Score: 81.9
# Matched file: E04_P05_AL_VO_GM, Assessment Score: 82.86
# Matched file: E04_P13_AF_VML_GF, Assessment Score: 74.29
# Matched file: E04_P05_AR_VHJ_GM, Assessment Score: 70.48
# Matched file: E04_P02_AR_VLL_GM, Assessment Score: 64.29
# Matched file: E04_P05_AF_VLL_GM, Assessment Score: 79.52
# Matched file: E04_P13_AF_VO_GF, Assessment Score: 74.29
# Matched file: E04_P20_AR_VML_GM, Assessment Score: 64.29
# Matched file: E04_P09_AR_VO_GF, Assessment Score: 97.62
# Matched file: E04_P21_AF_VLJ_GM, Assessment Score: 77.14
# Matched file: E04_P22_AL_VO_GM, Assessment Score: 66.67
# Matched file: E04_P19_AF_VO_GM, Assessment Score: 69.05
# Matched file: E04_P21_AL_VO_GM, Assessment Score: 75.24
# Matched file: E04_P10_AL_VLL_GF, Assessment Score: 79.05
# Matched file: E04_P05_AR_VFL_GM, Assessment Score: 92.86
# Matched file: E04_P07_AF_VLL_GM, Assessment Score: 77.14
# Matched file: E04_P11_AF_VLL_GF, Assessment Score: 74.76
# Matched file: E04_P02_AF_VO_GM, Assessment Score: 77.62
# Matched file: E04_P10_AR_VLL_GF, Assessment Score: 79.05
# Matched file: E04_P16_AR_VFL_GF, Assessment Score: 70.48
# Matched file: E04_P23_AR_VHJ_GM, Assessment Score: 84.29
# Matched file: E04_P05_AL_VFL_GM, Assessment Score: 92.86
# Matched file: E04_P23_AR_VO_GM, Assessment Score: 78.57
# Matched file: E04_P05_AL_VHJ_GM, Assessment Score: 90.48
# Matched file: E04_P20_AF_VHJ_GM, Assessment Score: 67.14
# Matched file: E04_P20_AL_VLL_GM, Assessment Score: 68.1
# Matched file: E04_P02_AR_VO_GM, Assessment Score: 73.33
# Matched file: E04_P23_AF_VLJ_GM, Assessment Score: 70.95
# Matched file: E04_P21_AF_VFL_GM, Assessment Score: 80.0
# Matched file: E04_P18_AL_VML_GM, Assessment Score: 67.62
# Matched file: E04_P16_AF_VLL_GF, Assessment Score: 76.67
# Matched file: E04_P01_AL_VO_GM, Assessment Score: 80.48
# Matched file: E04_P17_AR_VLJ_GM, Assessment Score: 79.52
# Matched file: E04_P17_AL_VLJ_GM, Assessment Score: 78.1
# Matched file: E04_P18_AL_VFL_GM, Assessment Score: 75.71
# Matched file: E04_P18_AF_VML_GM, Assessment Score: 67.62
# Matched file: E04_P11_AF_VML_GF, Assessment Score: 71.43
# Matched file: E04_P18_AR_VLJ_GM, Assessment Score: 71.9
# Matched file: E04_P10_AR_VFL_GF, Assessment Score: 97.62
# Matched file: E04_P21_AF_VLL_GM, Assessment Score: 80.0
# Matched file: E04_P21_AF_VO_GM, Assessment Score: 72.38
# Matched file: E04_P12_AF_VFL_GF, Assessment Score: 100.0
# Matched file: E04_P01_AR_VLJ_GM, Assessment Score: 77.62
# Matched file: E04_P04_AL_VFL_GM, Assessment Score: 57.14
# Matched file: E04_P04_AF_VO_GM, Assessment Score: 61.9
# Matched file: E04_P17_AF_VML_GM, Assessment Score: 78.1
# Matched file: E04_P21_AR_VFL_GM, Assessment Score: 71.43
# Matched file: E04_P12_AF_VML_GF, Assessment Score: 82.86
# Matched file: E04_P01_AR_VFL_GM, Assessment Score: 76.67
# Matched file: E04_P07_AL_VLJ_GM, Assessment Score: 66.67
# Matched file: E04_P12_AF_VLL_GF, Assessment Score: 78.57
# Matched file: E04_P16_AL_VLJ_GF, Assessment Score: 69.52
# Matched file: E04_P19_AL_VFL_GM, Assessment Score: 76.19
# Matched file: E04_P17_AF_VO_GM, Assessment Score: 81.9
# Total matching files: 80
# Features shape: (80, 30, 128, 128, 3)
# Labels shape: (80,)
# Matching files count: 80
# Number of video files: 80

# %%
np.save("features.npy", features)
np.save("labels.npy", labels)
np.save("video_files_paths.npy", video_files_paths)

# %%
features, labels, video_files_paths = np.load("features.npy"), np.load("labels.npy"), np.load("video_files_paths.npy")

# %%
print(f'Number of features: {len(features)}, Number of labels: {len(labels)}, Number of video_files_paths: {len(video_files_paths)}')
# Out:
# Number of features: 80, Number of labels: 80, Number of video_files_paths: 80

# %%
features_train, features_test, labels_train, labels_test = train_test_split(
    features, labels, test_size=0.20, shuffle=True, random_state=42
)

print(f"Training features: {features_train.shape}, Training labels: {labels_train.shape}")
print(f"Testing features: {features_test.shape}, Testing labels: {labels_test.shape}")
# Out:
# Training features: (64, 30, 128, 128, 3), Training labels: (64,)
# Testing features: (16, 30, 128, 128, 3), Testing labels: (16,)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler
import matplotlib.pyplot as plt
import numpy as np

# Define RMSE and MAD as custom metrics with correct casting
def rmse(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)  # Cast y_true to float32
    return tf.sqrt(tf.reduce_mean(tf.square(y_pred - y_true)))

def mad(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)  # Cast y_true to float32
    return tf.reduce_mean(tf.abs(y_pred - tf.reduce_mean(y_pred)))



# Define the CNN + LSTM model
def create_cnn_lstm_model(SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH):
    """
    A CNN + LSTM model for sequence prediction.
    """
    # Define the video input (3D input for CNN + LSTM)
    video_input = layers.Input(shape=(SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3))
    
    # CNN layers for feature extraction
    x = layers.Conv3D(32, (3, 3, 3), padding='same', activation='relu')(video_input)
    x = layers.MaxPooling3D((2, 2, 2))(x)
    x = layers.Dropout(0.3)(x)
    x = layers.BatchNormalization()(x)
    
    x = layers.Conv3D(64, (3, 3, 3), padding='same', activation='relu')(x)
    x = layers.MaxPooling3D((2, 2, 2))(x)
    x = layers.Dropout(0.3)(x)
    x = layers.BatchNormalization()(x)

    # Flatten the output of the CNN to make it compatible with LSTM
    x = layers.Reshape((-1, x.shape[1] * x.shape[2] * x.shape[3]))(x)  # Flatten the spatial dimensions

    # LSTM layer to capture temporal dependencies
    x = layers.LSTM(64, return_sequences=False)(x)
    
    # Dense layer with sigmoid activation to scale output to [0, 1]
    regression_output = layers.Dense(1, activation='sigmoid', name='regression_output')(x)
    
    # Build the model
    model = models.Model(inputs=video_input, outputs=[regression_output])
    model.summary()
    
    return model

# %%
# Define hyperparameters
SEQUENCE_LENGTH = 30  # Set according to your input data
IMAGE_HEIGHT = 128  # Set the height of your input images
IMAGE_WIDTH = 128  # Set the width of your input images

# Create the model
model = create_cnn_lstm_model(SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 30, 128, 128,   │             0 │
# │                                 │ 3)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d (Conv3D)                 │ (None, 30, 128, 128,   │         2,624 │
# │                                 │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d (MaxPooling3D)    │ (None, 15, 64, 64, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 15, 64, 64, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 15, 64, 64, 32) │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_1 (Conv3D)               │ (None, 15, 64, 64, 64) │        55,360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_1 (MaxPooling3D)  │ (None, 7, 32, 32, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 7, 32, 32, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 7, 32, 32, 64)  │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 64, 7168)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 64)             │     1,851,648 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ regression_output (Dense)       │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,910,081 (7.29 MB)
#  Trainable params: 1,909,889 (7.29 MB)
#  Non-trainable params: 192 (768.00 B)

# %%
# Compile the model for regression task
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='mean_squared_error',  # Use MSE for regression
              metrics=['mean_absolute_error', rmse, mad])

# Define Early Stopping and Learning Rate Scheduler callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
lr_scheduler = LearningRateScheduler(lambda epoch, lr: lr * 0.5 if epoch % 5 == 0 and epoch > 0 else lr, verbose=1)

callbacks = [early_stopping, lr_scheduler]

# Train the model
history = model.fit(features_train, labels_train,
                    validation_data=(features_test, labels_test),
                    epochs=60, batch_size=8, verbose=1, 
                    callbacks=callbacks)
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 1/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 139s 16s/step - loss: 0.1512 - mad: 0.0984 - mean_absolute_error: 0.3584 - rmse: 0.3803 - val_loss: 0.2078 - val_mad: 0.0236 - val_mean_absolute_error: 0.4547 - val_rmse: 0.4558 - learning_rate: 1.0000e-04
#
# Epoch 2: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 2/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 127s 16s/step - loss: 0.0149 - mad: 0.0446 - mean_absolute_error: 0.1026 - rmse: 0.1186 - val_loss: 0.0848 - val_mad: 0.0408 - val_mean_absolute_error: 0.2867 - val_rmse: 0.2911 - learning_rate: 1.0000e-04
#
# Epoch 3: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 3/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 126s 16s/step - loss: 0.0019 - mad: 0.0159 - mean_absolute_error: 0.0362 - rmse: 0.0423 - val_loss: 0.0210 - val_mad: 0.0291 - val_mean_absolute_error: 0.1404 - val_rmse: 0.1447 - learning_rate: 1.0000e-04
#
# Epoch 4: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 4/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 126s 16s/step - loss: 0.0011 - mad: 0.0132 - mean_absolute_error: 0.0219 - rmse: 0.0288 - val_loss: 0.0054 - val_mad: 0.0141 - val_mean_absolute_error: 0.0710 - val_rmse: 0.0731 - learning_rate: 1.0000e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 5/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 141s 18s/step - loss: 7.6224e-04 - mad: 0.0114 - mean_absolute_error: 0.0172 - rmse: 0.0235 - val_loss: 0.0019 - val_mad: 0.0074 - val_mean_absolute_error: 0.0425 - val_rmse: 0.0435 - learning_rate: 1.0000e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 6/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 128s 16s/step - loss: 2.9546e-04 - mad: 0.0067 - mean_absolute_error: 0.0134 - rmse: 0.0162 - val_loss: 8.8435e-04 - val_mad: 0.0043 - val_mean_absolute_error: 0.0292 - val_rmse: 0.0297 - learning_rate: 5.0000e-05
#
# Epoch 7: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 7/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 128s 16s/step - loss: 2.8514e-04 - mad: 0.0062 - mean_absolute_error: 0.0133 - rmse: 0.0160 - val_loss: 4.9170e-04 - val_mad: 0.0027 - val_mean_absolute_error: 0.0219 - val_rmse: 0.0222 - learning_rate: 5.0000e-05
#
# Epoch 8: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 8/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 128s 16s/step - loss: 6.5677e-04 - mad: 0.0096 - mean_absolute_error: 0.0146 - rmse: 0.0206 - val_loss: 3.1465e-04 - val_mad: 0.0018 - val_mean_absolute_error: 0.0176 - val_rmse: 0.0177 - learning_rate: 5.0000e-05
#
# Epoch 9: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 9/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 128s 16s/step - loss: 2.4814e-04 - mad: 0.0061 - mean_absolute_error: 0.0121 - rmse: 0.0148 - val_loss: 2.1986e-04 - val_mad: 0.0013 - val_mean_absolute_error: 0.0147 - val_rmse: 0.0148 - learning_rate: 5.0000e-05
#
# Epoch 10: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 10/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 135s 17s/step - loss: 1.7702e-04 - mad: 0.0047 - mean_absolute_error: 0.0109 - rmse: 0.0127 - val_loss: 1.6377e-04 - val_mad: 9.6543e-04 - val_mean_absolute_error: 0.0127 - val_rmse: 0.0128 - learning_rate: 5.0000e-05
#
# Epoch 11: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 11/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 127s 16s/step - loss: 3.0688e-04 - mad: 0.0062 - mean_absolute_error: 0.0121 - rmse: 0.0153 - val_loss: 1.2912e-04 - val_mad: 7.7110e-04 - val_mean_absolute_error: 0.0113 - val_rmse: 0.0114 - learning_rate: 2.5000e-05
#
# Epoch 12: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 12/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 127s 16s/step - loss: 5.2584e-04 - mad: 0.0083 - mean_absolute_error: 0.0130 - rmse: 0.0181 - val_loss: 1.0605e-04 - val_mad: 6.4208e-04 - val_mean_absolute_error: 0.0103 - val_rmse: 0.0103 - learning_rate: 2.5000e-05
#
# Epoch 13: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 13/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 128s 16s/step - loss: 2.4514e-04 - mad: 0.0062 - mean_absolute_error: 0.0119 - rmse: 0.0149 - val_loss: 8.9178e-05 - val_mad: 5.5217e-04 - val_mean_absolute_error: 0.0094 - val_rmse: 0.0094 - learning_rate: 2.5000e-05
#
# Epoch 14: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 14/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 127s 16s/step - loss: 2.2291e-04 - mad: 0.0052 - mean_absolute_error: 0.0115 - rmse: 0.0137 - val_loss: 7.6402e-05 - val_mad: 4.8565e-04 - val_mean_absolute_error: 0.0087 - val_rmse: 0.0087 - learning_rate: 2.5000e-05
#
# Epoch 15: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 15/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 127s 16s/step - loss: 3.0576e-04 - mad: 0.0071 - mean_absolute_error: 0.0119 - rmse: 0.0157 - val_loss: 6.7356e-05 - val_mad: 4.4329e-04 - val_mean_absolute_error: 0.0082 - val_rmse: 0.0082 - learning_rate: 2.5000e-05
#
# Epoch 16: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 16/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 127s 16s/step - loss: 2.0512e-04 - mad: 0.0060 - mean_absolute_error: 0.0120 - rmse: 0.0140 - val_loss: 5.9905e-05 - val_mad: 4.1198e-04 - val_mean_absolute_error: 0.0077 - val_rmse: 0.0077 - learning_rate: 1.2500e-05
#
# Epoch 17: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 17/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 127s 16s/step - loss: 1.4320e-04 - mad: 0.0045 - mean_absolute_error: 0.0103 - rmse: 0.0117 - val_loss: 5.3830e-05 - val_mad: 3.8612e-04 - val_mean_absolute_error: 0.0073 - val_rmse: 0.0073 - learning_rate: 1.2500e-05
#
# Epoch 18: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 18/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 125s 16s/step - loss: 2.5386e-04 - mad: 0.0062 - mean_absolute_error: 0.0119 - rmse: 0.0145 - val_loss: 4.8755e-05 - val_mad: 3.7122e-04 - val_mean_absolute_error: 0.0070 - val_rmse: 0.0070 - learning_rate: 1.2500e-05
#
# Epoch 19: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 19/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 126s 16s/step - loss: 2.2464e-04 - mad: 0.0061 - mean_absolute_error: 0.0115 - rmse: 0.0142 - val_loss: 4.4664e-05 - val_mad: 3.6021e-04 - val_mean_absolute_error: 0.0067 - val_rmse: 0.0067 - learning_rate: 1.2500e-05
#
# Epoch 20: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 20/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 126s 16s/step - loss: 3.3169e-04 - mad: 0.0071 - mean_absolute_error: 0.0117 - rmse: 0.0155 - val_loss: 4.1336e-05 - val_mad: 3.5524e-04 - val_mean_absolute_error: 0.0064 - val_rmse: 0.0064 - learning_rate: 1.2500e-05
#
# Epoch 21: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 21/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 126s 16s/step - loss: 5.0510e-04 - mad: 0.0094 - mean_absolute_error: 0.0136 - rmse: 0.0195 - val_loss: 3.8516e-05 - val_mad: 3.5371e-04 - val_mean_absolute_error: 0.0062 - val_rmse: 0.0062 - learning_rate: 6.2500e-06
#
# Epoch 22: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 22/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 125s 16s/step - loss: 1.8434e-04 - mad: 0.0051 - mean_absolute_error: 0.0103 - rmse: 0.0124 - val_loss: 3.6091e-05 - val_mad: 3.5335e-04 - val_mean_absolute_error: 0.0060 - val_rmse: 0.0060 - learning_rate: 6.2500e-06
#
# Epoch 23: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 23/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 125s 16s/step - loss: 1.9627e-04 - mad: 0.0056 - mean_absolute_error: 0.0107 - rmse: 0.0131 - val_loss: 3.4126e-05 - val_mad: 3.5614e-04 - val_mean_absolute_error: 0.0058 - val_rmse: 0.0058 - learning_rate: 6.2500e-06
#
# Epoch 24: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 24/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 125s 16s/step - loss: 4.5107e-04 - mad: 0.0093 - mean_absolute_error: 0.0133 - rmse: 0.0192 - val_loss: 3.2383e-05 - val_mad: 3.6026e-04 - val_mean_absolute_error: 0.0057 - val_rmse: 0.0057 - learning_rate: 6.2500e-06
#
# Epoch 25: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 25/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 126s 16s/step - loss: 2.5038e-04 - mad: 0.0063 - mean_absolute_error: 0.0118 - rmse: 0.0147 - val_loss: 3.0810e-05 - val_mad: 3.6445e-04 - val_mean_absolute_error: 0.0055 - val_rmse: 0.0056 - learning_rate: 6.2500e-06
#
# Epoch 26: LearningRateScheduler setting learning rate to 3.12499992105586e-06.
# Epoch 26/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 126s 16s/step - loss: 1.8971e-04 - mad: 0.0053 - mean_absolute_error: 0.0109 - rmse: 0.0130 - val_loss: 2.9399e-05 - val_mad: 3.6994e-04 - val_mean_absolute_error: 0.0054 - val_rmse: 0.0054 - learning_rate: 3.1250e-06
#
# Epoch 27: LearningRateScheduler setting learning rate to 3.12499992105586e-06.
# Epoch 27/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 127s 16s/step - loss: 1.7538e-04 - mad: 0.0053 - mean_absolute_error: 0.0108 - rmse: 0.0129 - val_loss: 2.8204e-05 - val_mad: 3.7804e-04 - val_mean_absolute_error: 0.0053 - val_rmse: 0.0053 - learning_rate: 3.1250e-06
#
# Epoch 28: LearningRateScheduler setting learning rate to 3.12499992105586e-06.
# Epoch 28/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 125s 16s/step - loss: 2.9861e-04 - mad: 0.0060 - mean_absolute_error: 0.0106 - rmse: 0.0139 - val_loss: 2.7132e-05 - val_mad: 3.8523e-04 - val_mean_absolute_error: 0.0052 - val_rmse: 0.0052 - learning_rate: 3.1250e-06
#
# Epoch 29: LearningRateScheduler setting learning rate to 3.12499992105586e-06.
# Epoch 29/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 125s 16s/step - loss: 1.1061e-04 - mad: 0.0035 - mean_absolute_error: 0.0090 - rmse: 0.0101 - val_loss: 2.6139e-05 - val_mad: 3.9251e-04 - val_mean_absolute_error: 0.0051 - val_rmse: 0.0051 - learning_rate: 3.1250e-06
#
# Epoch 30: LearningRateScheduler setting learning rate to 3.12499992105586e-06.
# Epoch 30/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 125s 16s/step - loss: 4.0125e-04 - mad: 0.0082 - mean_absolute_error: 0.0116 - rmse: 0.0167 - val_loss: 2.5263e-05 - val_mad: 4.0040e-04 - val_mean_absolute_error: 0.0050 - val_rmse: 0.0050 - learning_rate: 3.1250e-06
#
# Epoch 31: LearningRateScheduler setting learning rate to 1.56249996052793e-06.
# Epoch 31/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 126s 16s/step - loss: 1.7985e-04 - mad: 0.0051 - mean_absolute_error: 0.0102 - rmse: 0.0122 - val_loss: 2.4472e-05 - val_mad: 4.0794e-04 - val_mean_absolute_error: 0.0049 - val_rmse: 0.0049 - learning_rate: 1.5625e-06
#
# Epoch 32: LearningRateScheduler setting learning rate to 1.56249996052793e-06.
# Epoch 32/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 126s 16s/step - loss: 1.6157e-04 - mad: 0.0048 - mean_absolute_error: 0.0103 - rmse: 0.0122 - val_loss: 2.3728e-05 - val_mad: 4.1534e-04 - val_mean_absolute_error: 0.0048 - val_rmse: 0.0049 - learning_rate: 1.5625e-06
#
# Epoch 33: LearningRateScheduler setting learning rate to 1.56249996052793e-06.
# Epoch 33/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 126s 16s/step - loss: 1.9518e-04 - mad: 0.0055 - mean_absolute_error: 0.0108 - rmse: 0.0132 - val_loss: 2.3011e-05 - val_mad: 4.2268e-04 - val_mean_absolute_error: 0.0048 - val_rmse: 0.0048 - learning_rate: 1.5625e-06
#
# Epoch 34: LearningRateScheduler setting learning rate to 1.56249996052793e-06.
# Epoch 34/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 125s 16s/step - loss: 3.5584e-04 - mad: 0.0075 - mean_absolute_error: 0.0117 - rmse: 0.0160 - val_loss: 2.2375e-05 - val_mad: 4.3018e-04 - val_mean_absolute_error: 0.0047 - val_rmse: 0.0047 - learning_rate: 1.5625e-06
#
# Epoch 35: LearningRateScheduler setting learning rate to 1.56249996052793e-06.
# Epoch 35/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 142s 16s/step - loss: 1.8457e-04 - mad: 0.0043 - mean_absolute_error: 0.0097 - rmse: 0.0117 - val_loss: 2.1803e-05 - val_mad: 4.3794e-04 - val_mean_absolute_error: 0.0046 - val_rmse: 0.0047 - learning_rate: 1.5625e-06
#
# Epoch 36: LearningRateScheduler setting learning rate to 7.81249980263965e-07.
# Epoch 36/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 126s 16s/step - loss: 3.0558e-04 - mad: 0.0076 - mean_absolute_error: 0.0114 - rmse: 0.0160 - val_loss: 2.1258e-05 - val_mad: 4.4549e-04 - val_mean_absolute_error: 0.0046 - val_rmse: 0.0046 - learning_rate: 7.8125e-07
#
# Epoch 37: LearningRateScheduler setting learning rate to 7.81249980263965e-07.
# Epoch 37/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 128s 16s/step - loss: 1.1588e-04 - mad: 0.0036 - mean_absolute_error: 0.0091 - rmse: 0.0102 - val_loss: 2.0715e-05 - val_mad: 4.5287e-04 - val_mean_absolute_error: 0.0045 - val_rmse: 0.0046 - learning_rate: 7.8125e-07
#
# Epoch 38: LearningRateScheduler setting learning rate to 7.81249980263965e-07.
# Epoch 38/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 126s 16s/step - loss: 2.3833e-04 - mad: 0.0054 - mean_absolute_error: 0.0102 - rmse: 0.0131 - val_loss: 2.0188e-05 - val_mad: 4.5995e-04 - val_mean_absolute_error: 0.0045 - val_rmse: 0.0045 - learning_rate: 7.8125e-07
#
# Epoch 39: LearningRateScheduler setting learning rate to 7.81249980263965e-07.
# Epoch 39/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 126s 16s/step - loss: 3.1820e-04 - mad: 0.0072 - mean_absolute_error: 0.0128 - rmse: 0.0161 - val_loss: 1.9686e-05 - val_mad: 4.6677e-04 - val_mean_absolute_error: 0.0044 - val_rmse: 0.0044 - learning_rate: 7.8125e-07
#
# Epoch 40: LearningRateScheduler setting learning rate to 7.81249980263965e-07.
# Epoch 40/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 125s 16s/step - loss: 2.0701e-04 - mad: 0.0045 - mean_absolute_error: 0.0094 - rmse: 0.0118 - val_loss: 1.9229e-05 - val_mad: 4.7340e-04 - val_mean_absolute_error: 0.0043 - val_rmse: 0.0044 - learning_rate: 7.8125e-07
#
# Epoch 41: LearningRateScheduler setting learning rate to 3.906249901319825e-07.
# Epoch 41/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 125s 16s/step - loss: 1.2626e-04 - mad: 0.0036 - mean_absolute_error: 0.0093 - rmse: 0.0106 - val_loss: 1.8776e-05 - val_mad: 4.7933e-04 - val_mean_absolute_error: 0.0043 - val_rmse: 0.0043 - learning_rate: 3.9062e-07
#
# Epoch 42: LearningRateScheduler setting learning rate to 3.906249901319825e-07.
# Epoch 42/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 126s 16s/step - loss: 1.7922e-04 - mad: 0.0055 - mean_absolute_error: 0.0104 - rmse: 0.0127 - val_loss: 1.8334e-05 - val_mad: 4.8529e-04 - val_mean_absolute_error: 0.0042 - val_rmse: 0.0043 - learning_rate: 3.9062e-07
#
# Epoch 43: LearningRateScheduler setting learning rate to 3.906249901319825e-07.
# Epoch 43/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 126s 16s/step - loss: 1.9767e-04 - mad: 0.0061 - mean_absolute_error: 0.0105 - rmse: 0.0134 - val_loss: 1.7908e-05 - val_mad: 4.9106e-04 - val_mean_absolute_error: 0.0042 - val_rmse: 0.0042 - learning_rate: 3.9062e-07
#
# Epoch 44: LearningRateScheduler setting learning rate to 3.906249901319825e-07.
# Epoch 44/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 126s 16s/step - loss: 1.5968e-04 - mad: 0.0050 - mean_absolute_error: 0.0102 - rmse: 0.0125 - val_loss: 1.7492e-05 - val_mad: 4.9654e-04 - val_mean_absolute_error: 0.0041 - val_rmse: 0.0042 - learning_rate: 3.9062e-07
#
# Epoch 45: LearningRateScheduler setting learning rate to 3.906249901319825e-07.
# Epoch 45/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 125s 16s/step - loss: 1.5599e-04 - mad: 0.0050 - mean_absolute_error: 0.0098 - rmse: 0.0117 - val_loss: 1.7101e-05 - val_mad: 5.0181e-04 - val_mean_absolute_error: 0.0041 - val_rmse: 0.0041 - learning_rate: 3.9062e-07
#
# Epoch 46: LearningRateScheduler setting learning rate to 1.9531249506599124e-07.
# Epoch 46/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 125s 16s/step - loss: 1.6321e-04 - mad: 0.0052 - mean_absolute_error: 0.0105 - rmse: 0.0123 - val_loss: 1.6723e-05 - val_mad: 5.0699e-04 - val_mean_absolute_error: 0.0040 - val_rmse: 0.0041 - learning_rate: 1.9531e-07
#
# Epoch 47: LearningRateScheduler setting learning rate to 1.9531249506599124e-07.
# Epoch 47/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 125s 16s/step - loss: 1.2017e-04 - mad: 0.0042 - mean_absolute_error: 0.0093 - rmse: 0.0108 - val_loss: 1.6351e-05 - val_mad: 5.1299e-04 - val_mean_absolute_error: 0.0040 - val_rmse: 0.0040 - learning_rate: 1.9531e-07
#
# Epoch 48: LearningRateScheduler setting learning rate to 1.9531249506599124e-07.
# Epoch 48/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 126s 16s/step - loss: 1.7739e-04 - mad: 0.0049 - mean_absolute_error: 0.0100 - rmse: 0.0122 - val_loss: 1.5971e-05 - val_mad: 5.2009e-04 - val_mean_absolute_error: 0.0039 - val_rmse: 0.0040 - learning_rate: 1.9531e-07
#
# Epoch 49: LearningRateScheduler setting learning rate to 1.9531249506599124e-07.
# Epoch 49/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 127s 16s/step - loss: 2.8532e-04 - mad: 0.0066 - mean_absolute_error: 0.0117 - rmse: 0.0151 - val_loss: 1.5616e-05 - val_mad: 5.2698e-04 - val_mean_absolute_error: 0.0039 - val_rmse: 0.0039 - learning_rate: 1.9531e-07
#
# Epoch 50: LearningRateScheduler setting learning rate to 1.9531249506599124e-07.
# Epoch 50/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 126s 16s/step - loss: 1.5209e-04 - mad: 0.0043 - mean_absolute_error: 0.0096 - rmse: 0.0114 - val_loss: 1.5269e-05 - val_mad: 5.3349e-04 - val_mean_absolute_error: 0.0038 - val_rmse: 0.0039 - learning_rate: 1.9531e-07
#
# Epoch 51: LearningRateScheduler setting learning rate to 9.765624753299562e-08.
# Epoch 51/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 126s 16s/step - loss: 2.3591e-04 - mad: 0.0065 - mean_absolute_error: 0.0120 - rmse: 0.0145 - val_loss: 1.4923e-05 - val_mad: 5.3944e-04 - val_mean_absolute_error: 0.0038 - val_rmse: 0.0039 - learning_rate: 9.7656e-08
#
# Epoch 52: LearningRateScheduler setting learning rate to 9.765624753299562e-08.
# Epoch 52/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 125s 16s/step - loss: 1.4894e-04 - mad: 0.0045 - mean_absolute_error: 0.0098 - rmse: 0.0118 - val_loss: 1.4597e-05 - val_mad: 5.4488e-04 - val_mean_absolute_error: 0.0038 - val_rmse: 0.0038 - learning_rate: 9.7656e-08
#
# Epoch 53: LearningRateScheduler setting learning rate to 9.765624753299562e-08.
# Epoch 53/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 142s 16s/step - loss: 1.4071e-04 - mad: 0.0045 - mean_absolute_error: 0.0096 - rmse: 0.0113 - val_loss: 1.4269e-05 - val_mad: 5.4957e-04 - val_mean_absolute_error: 0.0037 - val_rmse: 0.0038 - learning_rate: 9.7656e-08
#
# Epoch 54: LearningRateScheduler setting learning rate to 9.765624753299562e-08.
# Epoch 54/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 127s 16s/step - loss: 1.9361e-04 - mad: 0.0048 - mean_absolute_error: 0.0099 - rmse: 0.0122 - val_loss: 1.3953e-05 - val_mad: 5.5447e-04 - val_mean_absolute_error: 0.0037 - val_rmse: 0.0037 - learning_rate: 9.7656e-08
#
# Epoch 55: LearningRateScheduler setting learning rate to 9.765624753299562e-08.
# Epoch 55/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 126s 16s/step - loss: 3.8020e-04 - mad: 0.0079 - mean_absolute_error: 0.0128 - rmse: 0.0172 - val_loss: 1.3649e-05 - val_mad: 5.5893e-04 - val_mean_absolute_error: 0.0036 - val_rmse: 0.0037 - learning_rate: 9.7656e-08
#
# Epoch 56: LearningRateScheduler setting learning rate to 4.882812376649781e-08.
# Epoch 56/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 126s 16s/step - loss: 1.8039e-04 - mad: 0.0049 - mean_absolute_error: 0.0100 - rmse: 0.0124 - val_loss: 1.3352e-05 - val_mad: 5.6259e-04 - val_mean_absolute_error: 0.0036 - val_rmse: 0.0037 - learning_rate: 4.8828e-08
#
# Epoch 57: LearningRateScheduler setting learning rate to 4.882812376649781e-08.
# Epoch 57/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 125s 16s/step - loss: 2.2608e-04 - mad: 0.0065 - mean_absolute_error: 0.0115 - rmse: 0.0146 - val_loss: 1.3064e-05 - val_mad: 5.6583e-04 - val_mean_absolute_error: 0.0035 - val_rmse: 0.0036 - learning_rate: 4.8828e-08
#
# Epoch 58: LearningRateScheduler setting learning rate to 4.882812376649781e-08.
# Epoch 58/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 125s 16s/step - loss: 1.7783e-04 - mad: 0.0047 - mean_absolute_error: 0.0108 - rmse: 0.0126 - val_loss: 1.2772e-05 - val_mad: 5.6833e-04 - val_mean_absolute_error: 0.0035 - val_rmse: 0.0036 - learning_rate: 4.8828e-08
#
# Epoch 59: LearningRateScheduler setting learning rate to 4.882812376649781e-08.
# Epoch 59/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 125s 16s/step - loss: 1.4487e-04 - mad: 0.0051 - mean_absolute_error: 0.0100 - rmse: 0.0118 - val_loss: 1.2489e-05 - val_mad: 5.7037e-04 - val_mean_absolute_error: 0.0035 - val_rmse: 0.0035 - learning_rate: 4.8828e-08
#
# Epoch 60: LearningRateScheduler setting learning rate to 4.882812376649781e-08.
# Epoch 60/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 126s 16s/step - loss: 2.1036e-04 - mad: 0.0060 - mean_absolute_error: 0.0111 - rmse: 0.0139 - val_loss: 1.2218e-05 - val_mad: 5.7190e-04 - val_mean_absolute_error: 0.0034 - val_rmse: 0.0035 - learning_rate: 4.8828e-08

# %%
# Evaluate the model on the test data
evaluation = model.evaluate(features_test, labels_test)

# Print the evaluation results with four decimal places
print(f"Evaluation Loss (MSE): {evaluation[0]:.5f}")
print(f"Evaluation MAE: {evaluation[1]:.5f}")
print(f"Evaluation RMSE: {evaluation[2]:.5f}")
print(f"Evaluation MAD: {evaluation[3]:.5f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - loss: 1.2218e-05 - mad: 5.7554e-04 - mean_absolute_error: 0.0034 - rmse: 0.0035
# Evaluation Loss (MSE): 0.00001
# Evaluation MAE: 0.00342
# Evaluation RMSE: 0.00350
# Evaluation MAD: 0.00058

# %%
# Plot the Train loss and validation loss
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss and validation loss')
plt.xlabel('Epoch')
plt.ylabel('Metric Value')
plt.legend()
plt.show()

# %%
# Plot the train rmse and validation rmse
plt.figure(figsize=(12, 6))
plt.plot(history.history['rmse'], label='Train RMSE')
plt.plot(history.history['val_rmse'], label='Validation RMSE')
plt.title('Train RMSE Vs Validation RMSE')
plt.xlabel('Epoch')
plt.ylabel('Metric Value')
plt.legend()
plt.show()

# %%
# Plot the tain MAD and validation MAD
plt.figure(figsize=(12, 6))
plt.plot(history.history['mad'], label='Train MAD')
plt.plot(history.history['val_mad'], label='Validation MAD')
plt.title('Train MAD Vs Validation MAD')
plt.xlabel('Epoch')
plt.ylabel('Metric Value')
plt.legend()
plt.show()

# %%
model.save('Conv3d(E04).h5')

# %%
import os
import cv2
import numpy as np

# Function to save all split videos from the test set to a folder
def save_all_split_videos(video_data, save_dir, SEQUENCE_LENGTH=16, IMAGE_HEIGHT=64, IMAGE_WIDTH=64, fps=30):
    """
    Save all split videos from the video data as individual video files in the specified directory.

    Args:
        video_data: Numpy array containing video data of shape (num_videos, SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3).
        save_dir: Directory to save the videos.
        SEQUENCE_LENGTH: Number of frames per video (default is 16).
        IMAGE_HEIGHT: Height of the frames (default is 64).
        IMAGE_WIDTH: Width of the frames (default is 64).
        fps: Frames per second for the output videos (default is 30).
    """
    # Create the save directory if it doesn't exist
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    # Iterate over all videos in the dataset
    for video_index in range(video_data.shape[0]):
        video_frames = video_data[video_index]  # Shape: (SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3)

        # Prepare the VideoWriter object to save the video
        video_filename = os.path.join(save_dir, f"split_video_{video_index + 1}.mp4")
        fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Use 'mp4v' for .mp4 format
        video_writer = cv2.VideoWriter(video_filename, fourcc, fps, (IMAGE_WIDTH, IMAGE_HEIGHT))

        # Add frames to the video
        for frame in video_frames:
            # Ensure the frame has values in the range [0, 255] and convert to uint8
            frame_rgb = (frame * 255).astype(np.uint8)
            # Convert RGB to BGR for OpenCV
            frame_bgr = cv2.cvtColor(frame_rgb, cv2.COLOR_RGB2BGR)
            # Write the frame to the video
            video_writer.write(frame_bgr)

        # Release the video writer
        video_writer.release()
        print(f"Video {video_index + 1} saved to: {video_filename}")

# Example usage: Save all split videos from the test set
# Make sure `features_test` is defined before calling this function
save_all_split_videos(features_test, save_dir="/kaggle/working/split_videos")
# Out:
# Video 1 saved to: /kaggle/working/split_videos/split_video_1.mp4
# Video 2 saved to: /kaggle/working/split_videos/split_video_2.mp4
# Video 3 saved to: /kaggle/working/split_videos/split_video_3.mp4
# Video 4 saved to: /kaggle/working/split_videos/split_video_4.mp4
# Video 5 saved to: /kaggle/working/split_videos/split_video_5.mp4
# Video 6 saved to: /kaggle/working/split_videos/split_video_6.mp4
# Video 7 saved to: /kaggle/working/split_videos/split_video_7.mp4
# Video 8 saved to: /kaggle/working/split_videos/split_video_8.mp4
# Video 9 saved to: /kaggle/working/split_videos/split_video_9.mp4
# Video 10 saved to: /kaggle/working/split_videos/split_video_10.mp4
# Video 11 saved to: /kaggle/working/split_videos/split_video_11.mp4
# Video 12 saved to: /kaggle/working/split_videos/split_video_12.mp4
# Video 13 saved to: /kaggle/working/split_videos/split_video_13.mp4
# Video 14 saved to: /kaggle/working/split_videos/split_video_14.mp4
# Video 15 saved to: /kaggle/working/split_videos/split_video_15.mp4
# Video 16 saved to: /kaggle/working/split_videos/split_video_16.mp4

# %%
# Example prediction for a new video
video_path = '/kaggle/working/split_videos/split_video_1.mp4'

# Assuming `process_video` function is implemented, use it to preprocess the video input
def process_video(video_path):
    # Example: Preprocessing video to match the input shape of (SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3)
    # You should implement this based on your dataset and requirements
    video_data = np.random.random((SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3))  # Replace with real video processing code
    return np.expand_dims(video_data, axis=0)  # Expand dims to add batch dimension

# Predict for a new video
predicted_score = model.predict(process_video(video_path))
scaled_score = predicted_score * 99 + 1
print(f"Predicted Score: {scaled_score[0][0]:.2f}")  # Assuming `predicted_score` is a 2D array
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 622ms/step
# Predicted Score: 59.73
