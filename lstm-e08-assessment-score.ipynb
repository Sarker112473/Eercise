# %%
pip install tensorflow opencv-python pandas scikit-learn matplotlib
# Out:
# Requirement already satisfied: tensorflow in /opt/conda/lib/python3.10/site-packages (2.16.1)
# Requirement already satisfied: opencv-python in /opt/conda/lib/python3.10/site-packages (4.10.0.84)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (2.2.3)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (1.2.2)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (3.7.5)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorflow) (21.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from tensorflow) (70.0.0)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (3.3.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (0.37.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.10/site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: rich in /opt/conda/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in /opt/conda/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /opt/conda/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow) (0.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich->keras>=3.0.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich->keras>=3.0.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Conv3D, MaxPooling3D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split

# %%
def Play_Video(filepath):
    html = ''
    video = open(filepath, 'rb').read()
    src = 'data:video/mp4;base64,' + b64encode(video).decode()
    html += '<video width=640 muted controls autoplay loop><source src="%s" type="video/mp4"></video>' % src
    return HTML(html)

# %%
# Constants
IMAGE_HEIGHT, IMAGE_WIDTH = 128, 128
SEQUENCE_LENGTH = 30
CLASSES_LIST = ["E08(Both_Leg_Flexion)"]

# %%
def frames_extraction(video_path):
    frames_list = []
    video_reader = cv2.VideoCapture(video_path)
    video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))
    skip_frames_window = max(int(video_frames_count/SEQUENCE_LENGTH), 1)

    for frame_counter in range(SEQUENCE_LENGTH):
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)
        success, frame = video_reader.read()

        if not success:
            break

        resized_frame = cv2.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))
        normalized_frame = resized_frame / 255
        frames_list.append(normalized_frame)

    video_reader.release()
    return frames_list

# %%
def create_dataset(video_dir, csv_file_path):
    features = []
    labels = []
    video_files_paths = []
    matching_files_count = 0

    # Read the CSV file
    csv_data = pd.read_csv(csv_file_path)

    for class_index, class_name in enumerate(CLASSES_LIST):
        print(f'Extracting Data of Class: {class_name}')
        files_list = os.listdir(os.path.join(video_dir, class_name))

        for file_name in files_list:
            # Remove the .mp4 extension from the file name
            video_name = os.path.splitext(file_name)[0]

            video_file_path = os.path.join(video_dir, class_name, file_name)
            frames = frames_extraction(video_file_path)

            if len(frames) == SEQUENCE_LENGTH:
                # Search for the exercise name in the CSV data that matches with video file name
                matching_row = csv_data[csv_data['Excercise Name'].str.lower() == video_name.lower()]

                if not matching_row.empty:
                    assessment_score = matching_row['Assessment Score'].values[0]
                    features.append(frames)
                    labels.append(class_index)
                    video_files_paths.append(video_file_path)
                    matching_files_count += 1
                    print(f'Matched file: {video_name}, Assessment Score: {assessment_score}')
                else:
                    # Append None if no matching row is found
                    features.append(frames)
                    labels.append(class_index)
                    video_files_paths.append(video_file_path)
                    print(f'No matching row found for file: {video_name}')

    features = np.asarray(features)
    labels = np.asarray(labels)

    print(f'Total matching files: {matching_files_count}')

    return features, labels, matching_files_count, video_files_paths

# %%
import pandas as pd

video_dir = '/kaggle/input/regression-folders/dataset_regression'
csv_file_path = '/kaggle/input/csv-files-regression/Ex_08_sub.csv'
features, labels, matching_files_count, video_files_paths =  create_dataset(video_dir, csv_file_path)
print("Features shape:", features.shape)
print("Labels shape:", labels.shape)
print("Matching files count:", matching_files_count)
print("Number of video files:", len(video_files_paths))
# Out:
# Extracting Data of Class: E08(Both_Leg_Flexion)
# Matched file: E08_P04_AL_VML_GM, Assessment Score: 81.9
# Matched file: E08_P42_AF_VO_GM, Assessment Score: 16.67
# Matched file: E08_P21_AR_VLL_GM, Assessment Score: 84.29
# Matched file: E08_P50_AR_VFL_GM, Assessment Score: 47.62
# Matched file: E08_P04_AF_VML_GM, Assessment Score: 97.62
# Matched file: E08_P47_AF_VML_GM, Assessment Score: 60.0
# Matched file: E08_P22_AL_VLL_GM, Assessment Score: 78.57
# Matched file: E08_P02_AR_VFL_GM, Assessment Score: 82.86
# Matched file: E08_P04_AF_VHJ_GM, Assessment Score: 83.33
# Matched file: E08_P31_AF_VO_GM, Assessment Score: 19.05
# Matched file: E08_P21_AL_VFL_GM, Assessment Score: 67.14
# Matched file: E08_P45_AF_VML_GM, Assessment Score: 52.86
# Matched file: E08_P28_AL_VFL_GM, Assessment Score: 39.52
# Matched file: E08_P48_AF_VFL_GM, Assessment Score: 33.33
# Matched file: E08_P27_AR_VFL_GM, Assessment Score: 47.62
# Matched file: E08_P07_AR_VML_GM, Assessment Score: 80.48
# Matched file: E08_P32_AF_VO_GM, Assessment Score: 34.76
# Matched file: E08_P27_AF_VFL_GM, Assessment Score: 58.57
# Matched file: E08_P22_AF_VML_GM, Assessment Score: 97.62
# Matched file: E08_P08_AF_VHJ_GM, Assessment Score: 85.71
# Matched file: E08_P47_AL_VFL_GM, Assessment Score: 57.62
# Matched file: E08_P38_AR_VFL_GM, Assessment Score: 9.52
# Matched file: E08_P47_AF_VLJ_GM, Assessment Score: 56.19
# Matched file: E08_P29_AF_VLR_GM, Assessment Score: 0.0
# Matched file: E08_P48_AR_VFL_GM, Assessment Score: 50.48
# Matched file: E08_P04_AL_VFL_GM, Assessment Score: 95.24
# Matched file: E08_P29_AR_VFL_GM, Assessment Score: 14.29
# Matched file: E08_P04_AF_VFL_GM, Assessment Score: 76.67
# Matched file: E08_P48_AL_VFL_GM, Assessment Score: 49.05
# Matched file: E08_P35_AF_VLJ_GM, Assessment Score: 21.43
# Matched file: E08_P35_AF_VLL_GM, Assessment Score: 32.38
# Matched file: E08_P04_AR_VFL_GM, Assessment Score: 95.24
# Matched file: E08_P38_AF_VLL_GM, Assessment Score: 9.52
# Matched file: E08_P07_AL_VML_GM, Assessment Score: 79.05
# Matched file: E08_P27_AF_VLR_GM, Assessment Score: 51.43
# Matched file: E08_P50_AL_VFL_GM, Assessment Score: 45.24
# Matched file: E08_P28_AF_VLL_GM, Assessment Score: 28.57
# Matched file: E08_P08_AF_VLJ_GM, Assessment Score: 69.05
# Matched file: E08_P38_AF_VFL_GM, Assessment Score: 4.76
# Matched file: E08_P46_AF_VFL_GM, Assessment Score: 55.24
# Matched file: E08_P22_AR_VLL_GM, Assessment Score: 80.0
# Matched file: E08_P47_AF_VHJ_GM, Assessment Score: 56.19
# Matched file: E08_P38_AF_VLJ_GM, Assessment Score: 9.52
# Matched file: E08_P21_AF_VFL_GM, Assessment Score: 67.14
# Matched file: E08_P08_AR_VML_GM, Assessment Score: 78.1
# Matched file: E08_P28_AF_VML_GM, Assessment Score: 39.52
# Matched file: E08_P07_AR_VLL_GM, Assessment Score: 81.9
# Matched file: E08_P42_AL_VFL_GM, Assessment Score: 16.67
# Matched file: E08_P35_AF_VFL_GM, Assessment Score: 21.43
# Matched file: E08_P32_AF_VLL_GM, Assessment Score: 34.76
# Matched file: E08_P04_AR_VHJ_GM, Assessment Score: 67.62
# Matched file: E08_P18_AR_VFL_GM, Assessment Score: 100.0
# Matched file: E08_P22_AF_VLL_GM, Assessment Score: 80.0
# Matched file: E08_P46_AL_VFL_GM, Assessment Score: 55.24
# Matched file: E08_P47_AF_VFL_GM, Assessment Score: 50.0
# Matched file: E08_P08_AR_VLJ_GM, Assessment Score: 69.05
# Matched file: E08_P48_AF_VML_GM, Assessment Score: 40.48
# Matched file: E08_P04_AL_VHJ_GM, Assessment Score: 67.62
# Matched file: E08_P38_AF_VHJ_GM, Assessment Score: 4.76
# Matched file: E08_P23_AF_VO_GM, Assessment Score: 81.43
# Matched file: E08_P21_AR_VFL_GM, Assessment Score: 65.71
# Matched file: E08_P49_AF_VHJ_GM, Assessment Score: 58.57
# Matched file: E08_P27_AF_VLJ_GM, Assessment Score: 52.38
# Matched file: E08_P08_AF_VML_GM, Assessment Score: 79.52
# Matched file: E08_P35_AF_VLR_GM, Assessment Score: 28.57
# Matched file: E08_P29_AF_VFL_GM, Assessment Score: 0.0
# Matched file: E08_P08_AL_VML_GM, Assessment Score: 78.1
# Matched file: E08_P45_AF_VFL_GM, Assessment Score: 48.1
# Matched file: E08_P42_AF_VHJ_GM, Assessment Score: 19.05
# Matched file: E08_P35_AF_VHJ_GM, Assessment Score: 2.38
# Matched file: E08_P49_AF_VML_GM, Assessment Score: 60.0
# Matched file: E08_P37_AF_VML_GM, Assessment Score: 23.81
# Matched file: E08_P02_AF_VFL_GM, Assessment Score: 82.86
# Matched file: E08_P06_AF_VML_GM, Assessment Score: 100.0
# Matched file: E08_P21_AR_VML_GM, Assessment Score: 84.29
# Matched file: E08_P08_AR_VHJ_GM, Assessment Score: 70.0
# Matched file: E08_P37_AF_VLL_GM, Assessment Score: 23.81
# Matched file: E08_P07_AF_VML_GM, Assessment Score: 80.48
# Matched file: E08_P42_AF_VLR_GM, Assessment Score: 19.05
# Matched file: E08_P22_AL_VFL_GM, Assessment Score: 70.0
# Total matching files: 80
# Features shape: (80, 30, 128, 128, 3)
# Labels shape: (80,)
# Matching files count: 80
# Number of video files: 80

# %%
np.save("features.npy", features)
np.save("labels.npy", labels)
np.save("video_files_paths.npy", video_files_paths)

# %%
features, labels, video_files_paths = np.load("features.npy"), np.load("labels.npy"), np.load("video_files_paths.npy")

# %%
features_train, features_test, labels_train, labels_test = train_test_split(
    features, labels, test_size=0.20, shuffle=True, random_state=42
)

print(f"Training features: {features_train.shape}, Training labels: {labels_train.shape}")
print(f"Testing features: {features_test.shape}, Testing labels: {labels_test.shape}")
# Out:
# Training features: (64, 30, 128, 128, 3), Training labels: (64,)
# Testing features: (16, 30, 128, 128, 3), Testing labels: (16,)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam

# Define RMSE and MAD as custom metrics with correct casting
def rmse(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)  # Cast y_true to float32
    return tf.sqrt(tf.reduce_mean(tf.square(y_pred - y_true)))

def mad(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)  # Cast y_true to float32
    return tf.reduce_mean(tf.abs(y_pred - tf.reduce_mean(y_pred)))

# Define the LSTM model
def create_lstm_model(SEQUENCE_LENGTH, FEATURE_SIZE):
    """
    An LSTM model for sequence prediction.
    Args:
    - SEQUENCE_LENGTH: Length of the input sequence.
    - FEATURE_SIZE: Number of features in each time step.
    """
    # Define the sequence input (3D input for LSTM)
    sequence_input = layers.Input(shape=(SEQUENCE_LENGTH, FEATURE_SIZE))
    
    # First LSTM layer with return_sequences=True for stacked LSTM
    x = layers.LSTM(
        units=64,
        activation='relu',
        return_sequences=True
    )(sequence_input)
    x = layers.Dropout(0.3)(x)
    x = layers.BatchNormalization()(x)
    
    # Second LSTM layer with return_sequences=False for final output
    x = layers.LSTM(
        units=128,
        activation='relu',
        return_sequences=False
    )(x)
    x = layers.Dropout(0.3)(x)
    x = layers.BatchNormalization()(x)

    # Dense layer with sigmoid activation to scale output to [0, 1]
    regression_output = layers.Dense(1, activation='sigmoid', name='regression_output')(x)
    
    # Build the model
    model = models.Model(inputs=sequence_input, outputs=[regression_output])
    model.summary()
    
    return model

# Determine FEATURE_SIZE for RGB input
IMAGE_HEIGHT = 128
IMAGE_WIDTH = 128
CHANNELS = 3  # RGB
FEATURE_SIZE = IMAGE_HEIGHT * IMAGE_WIDTH * CHANNELS  # Flattened spatial and channel dimensions

# Reshape features
features_train = features_train.reshape(features_train.shape[0], features_train.shape[1], FEATURE_SIZE)
features_test = features_test.reshape(features_test.shape[0], features_test.shape[1], FEATURE_SIZE)

print(f"Reshaped features_train: {features_train.shape}")
print(f"Reshaped features_test: {features_test.shape}")

# Recreate model with updated FEATURE_SIZE
model = create_lstm_model(SEQUENCE_LENGTH, FEATURE_SIZE)
# Out:
# Reshaped features_train: (64, 30, 49152)
# Reshaped features_test: (16, 30, 49152)
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 30, 49152)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 30, 64)         │    12,599,552 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 30, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 30, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 128)            │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ regression_output (Dense)       │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,699,265 (48.44 MB)
#  Trainable params: 12,698,881 (48.44 MB)
#  Non-trainable params: 384 (1.50 KB)

# %%
from tensorflow.keras.callbacks import LearningRateScheduler

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='mean_squared_error',  # Use MSE for regression
              metrics=['mean_absolute_error', rmse, mad])

# Define Early Stopping and Learning Rate Scheduler callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
lr_scheduler = LearningRateScheduler(lambda epoch, lr: lr * 0.5 if epoch % 5 == 0 and epoch > 0 else lr, verbose=1)

callbacks = [early_stopping, lr_scheduler]

# Train the model
history = model.fit(features_train, labels_train,
                    validation_data=(features_test, labels_test),
                    epochs=60, batch_size=8, verbose=1, 
                    callbacks=callbacks)
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 1/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - loss: 0.3081 - mad: 0.2322 - mean_absolute_error: 0.4880 - rmse: 0.5548 - val_loss: 0.7260 - val_mad: 0.2831 - val_mean_absolute_error: 0.7852 - val_rmse: 0.8507 - learning_rate: 1.0000e-04
#
# Epoch 2: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 2/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.3247 - mad: 0.2241 - mean_absolute_error: 0.5043 - rmse: 0.5694 - val_loss: 0.4733 - val_mad: 0.1484 - val_mean_absolute_error: 0.6657 - val_rmse: 0.6867 - learning_rate: 1.0000e-04
#
# Epoch 3: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 3/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.3203 - mad: 0.2356 - mean_absolute_error: 0.4990 - rmse: 0.5658 - val_loss: 0.4029 - val_mad: 0.0753 - val_mean_absolute_error: 0.6267 - val_rmse: 0.6346 - learning_rate: 1.0000e-04
#
# Epoch 4: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 4/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - loss: 0.3036 - mad: 0.2238 - mean_absolute_error: 0.4858 - rmse: 0.5505 - val_loss: 0.3382 - val_mad: 0.0227 - val_mean_absolute_error: 0.5808 - val_rmse: 0.5816 - learning_rate: 1.0000e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 5/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 24s 3s/step - loss: 0.2929 - mad: 0.1830 - mean_absolute_error: 0.4936 - rmse: 0.5409 - val_loss: 0.2610 - val_mad: 0.0138 - val_mean_absolute_error: 0.5106 - val_rmse: 0.5109 - learning_rate: 1.0000e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 6/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - loss: 0.3032 - mad: 0.2083 - mean_absolute_error: 0.4915 - rmse: 0.5503 - val_loss: 0.2419 - val_mad: 0.0036 - val_mean_absolute_error: 0.4918 - val_rmse: 0.4918 - learning_rate: 5.0000e-05
#
# Epoch 7: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 7/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2919 - mad: 0.2031 - mean_absolute_error: 0.4866 - rmse: 0.5401 - val_loss: 0.2454 - val_mad: 0.0046 - val_mean_absolute_error: 0.4954 - val_rmse: 0.4954 - learning_rate: 5.0000e-05
#
# Epoch 8: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 8/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.2802 - mad: 0.1791 - mean_absolute_error: 0.4861 - rmse: 0.5290 - val_loss: 0.2465 - val_mad: 0.0055 - val_mean_absolute_error: 0.4964 - val_rmse: 0.4965 - learning_rate: 5.0000e-05
#
# Epoch 9: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 9/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 0.2993 - mad: 0.2155 - mean_absolute_error: 0.4902 - rmse: 0.5468 - val_loss: 0.2461 - val_mad: 0.0067 - val_mean_absolute_error: 0.4960 - val_rmse: 0.4961 - learning_rate: 5.0000e-05
#
# Epoch 10: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 10/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.3071 - mad: 0.2007 - mean_absolute_error: 0.5026 - rmse: 0.5529 - val_loss: 0.2449 - val_mad: 0.0075 - val_mean_absolute_error: 0.4948 - val_rmse: 0.4949 - learning_rate: 5.0000e-05
#
# Epoch 11: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 11/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2700 - mad: 0.1685 - mean_absolute_error: 0.4788 - rmse: 0.5193 - val_loss: 0.2413 - val_mad: 0.0076 - val_mean_absolute_error: 0.4911 - val_rmse: 0.4912 - learning_rate: 2.5000e-05
#
# Epoch 12: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 12/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2898 - mad: 0.2038 - mean_absolute_error: 0.4823 - rmse: 0.5381 - val_loss: 0.2372 - val_mad: 0.0074 - val_mean_absolute_error: 0.4869 - val_rmse: 0.4870 - learning_rate: 2.5000e-05
#
# Epoch 13: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 13/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2802 - mad: 0.1933 - mean_absolute_error: 0.4764 - rmse: 0.5289 - val_loss: 0.2334 - val_mad: 0.0069 - val_mean_absolute_error: 0.4830 - val_rmse: 0.4831 - learning_rate: 2.5000e-05
#
# Epoch 14: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 14/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2765 - mad: 0.1611 - mean_absolute_error: 0.4835 - rmse: 0.5254 - val_loss: 0.2297 - val_mad: 0.0069 - val_mean_absolute_error: 0.4792 - val_rmse: 0.4793 - learning_rate: 2.5000e-05
#
# Epoch 15: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 15/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2812 - mad: 0.1826 - mean_absolute_error: 0.4803 - rmse: 0.5300 - val_loss: 0.2281 - val_mad: 0.0074 - val_mean_absolute_error: 0.4776 - val_rmse: 0.4776 - learning_rate: 2.5000e-05
#
# Epoch 16: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 16/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2777 - mad: 0.1842 - mean_absolute_error: 0.4798 - rmse: 0.5267 - val_loss: 0.2238 - val_mad: 0.0072 - val_mean_absolute_error: 0.4730 - val_rmse: 0.4731 - learning_rate: 1.2500e-05
#
# Epoch 17: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 17/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2771 - mad: 0.2009 - mean_absolute_error: 0.4713 - rmse: 0.5263 - val_loss: 0.2200 - val_mad: 0.0069 - val_mean_absolute_error: 0.4690 - val_rmse: 0.4690 - learning_rate: 1.2500e-05
#
# Epoch 18: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 18/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2728 - mad: 0.1923 - mean_absolute_error: 0.4694 - rmse: 0.5220 - val_loss: 0.2166 - val_mad: 0.0064 - val_mean_absolute_error: 0.4653 - val_rmse: 0.4654 - learning_rate: 1.2500e-05
#
# Epoch 19: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 19/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2581 - mad: 0.1507 - mean_absolute_error: 0.4756 - rmse: 0.5078 - val_loss: 0.2131 - val_mad: 0.0064 - val_mean_absolute_error: 0.4615 - val_rmse: 0.4616 - learning_rate: 1.2500e-05
#
# Epoch 20: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 20/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2679 - mad: 0.1775 - mean_absolute_error: 0.4731 - rmse: 0.5173 - val_loss: 0.2094 - val_mad: 0.0058 - val_mean_absolute_error: 0.4576 - val_rmse: 0.4576 - learning_rate: 1.2500e-05
#
# Epoch 21: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 21/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2704 - mad: 0.1680 - mean_absolute_error: 0.4787 - rmse: 0.5197 - val_loss: 0.2061 - val_mad: 0.0060 - val_mean_absolute_error: 0.4539 - val_rmse: 0.4540 - learning_rate: 6.2500e-06
#
# Epoch 22: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 22/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2762 - mad: 0.1717 - mean_absolute_error: 0.4792 - rmse: 0.5253 - val_loss: 0.2044 - val_mad: 0.0060 - val_mean_absolute_error: 0.4520 - val_rmse: 0.4521 - learning_rate: 6.2500e-06
#
# Epoch 23: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 23/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2776 - mad: 0.1746 - mean_absolute_error: 0.4815 - rmse: 0.5256 - val_loss: 0.2022 - val_mad: 0.0061 - val_mean_absolute_error: 0.4496 - val_rmse: 0.4496 - learning_rate: 6.2500e-06
#
# Epoch 24: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 24/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2919 - mad: 0.2004 - mean_absolute_error: 0.4821 - rmse: 0.5391 - val_loss: 0.1996 - val_mad: 0.0063 - val_mean_absolute_error: 0.4467 - val_rmse: 0.4468 - learning_rate: 6.2500e-06
#
# Epoch 25: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 25/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.2646 - mad: 0.1725 - mean_absolute_error: 0.4710 - rmse: 0.5141 - val_loss: 0.1976 - val_mad: 0.0064 - val_mean_absolute_error: 0.4445 - val_rmse: 0.4445 - learning_rate: 6.2500e-06
#
# Epoch 26: LearningRateScheduler setting learning rate to 3.12499992105586e-06.
# Epoch 26/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2811 - mad: 0.1875 - mean_absolute_error: 0.4807 - rmse: 0.5300 - val_loss: 0.1958 - val_mad: 0.0065 - val_mean_absolute_error: 0.4424 - val_rmse: 0.4424 - learning_rate: 3.1250e-06
#
# Epoch 27: LearningRateScheduler setting learning rate to 3.12499992105586e-06.
# Epoch 27/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.2634 - mad: 0.1623 - mean_absolute_error: 0.4714 - rmse: 0.5127 - val_loss: 0.1942 - val_mad: 0.0066 - val_mean_absolute_error: 0.4406 - val_rmse: 0.4407 - learning_rate: 3.1250e-06
#
# Epoch 28: LearningRateScheduler setting learning rate to 3.12499992105586e-06.
# Epoch 28/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2935 - mad: 0.2008 - mean_absolute_error: 0.4850 - rmse: 0.5413 - val_loss: 0.1918 - val_mad: 0.0069 - val_mean_absolute_error: 0.4379 - val_rmse: 0.4380 - learning_rate: 3.1250e-06
#
# Epoch 29: LearningRateScheduler setting learning rate to 3.12499992105586e-06.
# Epoch 29/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.2690 - mad: 0.1828 - mean_absolute_error: 0.4708 - rmse: 0.5185 - val_loss: 0.1900 - val_mad: 0.0070 - val_mean_absolute_error: 0.4358 - val_rmse: 0.4359 - learning_rate: 3.1250e-06
#
# Epoch 30: LearningRateScheduler setting learning rate to 3.12499992105586e-06.
# Epoch 30/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2750 - mad: 0.1771 - mean_absolute_error: 0.4814 - rmse: 0.5239 - val_loss: 0.1871 - val_mad: 0.0072 - val_mean_absolute_error: 0.4325 - val_rmse: 0.4326 - learning_rate: 3.1250e-06
#
# Epoch 31: LearningRateScheduler setting learning rate to 1.56249996052793e-06.
# Epoch 31/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2666 - mad: 0.1656 - mean_absolute_error: 0.4754 - rmse: 0.5160 - val_loss: 0.1855 - val_mad: 0.0074 - val_mean_absolute_error: 0.4306 - val_rmse: 0.4307 - learning_rate: 1.5625e-06
#
# Epoch 32: LearningRateScheduler setting learning rate to 1.56249996052793e-06.
# Epoch 32/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.2659 - mad: 0.1829 - mean_absolute_error: 0.4677 - rmse: 0.5156 - val_loss: 0.1837 - val_mad: 0.0076 - val_mean_absolute_error: 0.4285 - val_rmse: 0.4286 - learning_rate: 1.5625e-06
#
# Epoch 33: LearningRateScheduler setting learning rate to 1.56249996052793e-06.
# Epoch 33/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.2780 - mad: 0.1769 - mean_absolute_error: 0.4801 - rmse: 0.5267 - val_loss: 0.1817 - val_mad: 0.0079 - val_mean_absolute_error: 0.4262 - val_rmse: 0.4263 - learning_rate: 1.5625e-06
#
# Epoch 34: LearningRateScheduler setting learning rate to 1.56249996052793e-06.
# Epoch 34/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.2713 - mad: 0.1824 - mean_absolute_error: 0.4706 - rmse: 0.5207 - val_loss: 0.1782 - val_mad: 0.0081 - val_mean_absolute_error: 0.4220 - val_rmse: 0.4221 - learning_rate: 1.5625e-06
#
# Epoch 35: LearningRateScheduler setting learning rate to 1.56249996052793e-06.
# Epoch 35/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2717 - mad: 0.1587 - mean_absolute_error: 0.4843 - rmse: 0.5208 - val_loss: 0.1750 - val_mad: 0.0084 - val_mean_absolute_error: 0.4182 - val_rmse: 0.4183 - learning_rate: 1.5625e-06
#
# Epoch 36: LearningRateScheduler setting learning rate to 7.81249980263965e-07.
# Epoch 36/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2756 - mad: 0.1934 - mean_absolute_error: 0.4738 - rmse: 0.5246 - val_loss: 0.1722 - val_mad: 0.0087 - val_mean_absolute_error: 0.4148 - val_rmse: 0.4149 - learning_rate: 7.8125e-07
#
# Epoch 37: LearningRateScheduler setting learning rate to 7.81249980263965e-07.
# Epoch 37/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2561 - mad: 0.1483 - mean_absolute_error: 0.4736 - rmse: 0.5060 - val_loss: 0.1711 - val_mad: 0.0094 - val_mean_absolute_error: 0.4135 - val_rmse: 0.4137 - learning_rate: 7.8125e-07
#
# Epoch 38: LearningRateScheduler setting learning rate to 7.81249980263965e-07.
# Epoch 38/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2657 - mad: 0.1627 - mean_absolute_error: 0.4751 - rmse: 0.5150 - val_loss: 0.1695 - val_mad: 0.0098 - val_mean_absolute_error: 0.4115 - val_rmse: 0.4116 - learning_rate: 7.8125e-07
#
# Epoch 39: LearningRateScheduler setting learning rate to 7.81249980263965e-07.
# Epoch 39/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.2696 - mad: 0.1650 - mean_absolute_error: 0.4722 - rmse: 0.5188 - val_loss: 0.1662 - val_mad: 0.0101 - val_mean_absolute_error: 0.4074 - val_rmse: 0.4076 - learning_rate: 7.8125e-07
#
# Epoch 40: LearningRateScheduler setting learning rate to 7.81249980263965e-07.
# Epoch 40/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2664 - mad: 0.1732 - mean_absolute_error: 0.4726 - rmse: 0.5160 - val_loss: 0.1636 - val_mad: 0.0105 - val_mean_absolute_error: 0.4042 - val_rmse: 0.4044 - learning_rate: 7.8125e-07
#
# Epoch 41: LearningRateScheduler setting learning rate to 3.906249901319825e-07.
# Epoch 41/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2652 - mad: 0.1672 - mean_absolute_error: 0.4737 - rmse: 0.5148 - val_loss: 0.1626 - val_mad: 0.0108 - val_mean_absolute_error: 0.4030 - val_rmse: 0.4032 - learning_rate: 3.9062e-07
#
# Epoch 42: LearningRateScheduler setting learning rate to 3.906249901319825e-07.
# Epoch 42/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2695 - mad: 0.1696 - mean_absolute_error: 0.4752 - rmse: 0.5188 - val_loss: 0.1608 - val_mad: 0.0110 - val_mean_absolute_error: 0.4007 - val_rmse: 0.4010 - learning_rate: 3.9062e-07
#
# Epoch 43: LearningRateScheduler setting learning rate to 3.906249901319825e-07.
# Epoch 43/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2944 - mad: 0.2060 - mean_absolute_error: 0.4854 - rmse: 0.5419 - val_loss: 0.1583 - val_mad: 0.0112 - val_mean_absolute_error: 0.3976 - val_rmse: 0.3978 - learning_rate: 3.9062e-07
#
# Epoch 44: LearningRateScheduler setting learning rate to 3.906249901319825e-07.
# Epoch 44/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.2705 - mad: 0.1779 - mean_absolute_error: 0.4776 - rmse: 0.5199 - val_loss: 0.1582 - val_mad: 0.0115 - val_mean_absolute_error: 0.3974 - val_rmse: 0.3977 - learning_rate: 3.9062e-07
#
# Epoch 45: LearningRateScheduler setting learning rate to 3.906249901319825e-07.
# Epoch 45/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2713 - mad: 0.1983 - mean_absolute_error: 0.4697 - rmse: 0.5206 - val_loss: 0.1551 - val_mad: 0.0116 - val_mean_absolute_error: 0.3935 - val_rmse: 0.3938 - learning_rate: 3.9062e-07
#
# Epoch 46: LearningRateScheduler setting learning rate to 1.9531249506599124e-07.
# Epoch 46/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2838 - mad: 0.2076 - mean_absolute_error: 0.4768 - rmse: 0.5321 - val_loss: 0.1537 - val_mad: 0.0119 - val_mean_absolute_error: 0.3917 - val_rmse: 0.3920 - learning_rate: 1.9531e-07
#
# Epoch 47: LearningRateScheduler setting learning rate to 1.9531249506599124e-07.
# Epoch 47/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2740 - mad: 0.1826 - mean_absolute_error: 0.4775 - rmse: 0.5233 - val_loss: 0.1496 - val_mad: 0.0121 - val_mean_absolute_error: 0.3865 - val_rmse: 0.3868 - learning_rate: 1.9531e-07
#
# Epoch 48: LearningRateScheduler setting learning rate to 1.9531249506599124e-07.
# Epoch 48/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2773 - mad: 0.1916 - mean_absolute_error: 0.4753 - rmse: 0.5264 - val_loss: 0.1492 - val_mad: 0.0125 - val_mean_absolute_error: 0.3859 - val_rmse: 0.3862 - learning_rate: 1.9531e-07
#
# Epoch 49: LearningRateScheduler setting learning rate to 1.9531249506599124e-07.
# Epoch 49/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2611 - mad: 0.1603 - mean_absolute_error: 0.4744 - rmse: 0.5106 - val_loss: 0.1473 - val_mad: 0.0128 - val_mean_absolute_error: 0.3834 - val_rmse: 0.3837 - learning_rate: 1.9531e-07
#
# Epoch 50: LearningRateScheduler setting learning rate to 1.9531249506599124e-07.
# Epoch 50/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2581 - mad: 0.1511 - mean_absolute_error: 0.4740 - rmse: 0.5078 - val_loss: 0.1465 - val_mad: 0.0131 - val_mean_absolute_error: 0.3823 - val_rmse: 0.3827 - learning_rate: 1.9531e-07
#
# Epoch 51: LearningRateScheduler setting learning rate to 9.765624753299562e-08.
# Epoch 51/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2761 - mad: 0.1863 - mean_absolute_error: 0.4755 - rmse: 0.5252 - val_loss: 0.1435 - val_mad: 0.0133 - val_mean_absolute_error: 0.3783 - val_rmse: 0.3787 - learning_rate: 9.7656e-08
#
# Epoch 52: LearningRateScheduler setting learning rate to 9.765624753299562e-08.
# Epoch 52/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.2675 - mad: 0.1766 - mean_absolute_error: 0.4763 - rmse: 0.5169 - val_loss: 0.1413 - val_mad: 0.0135 - val_mean_absolute_error: 0.3753 - val_rmse: 0.3758 - learning_rate: 9.7656e-08
#
# Epoch 53: LearningRateScheduler setting learning rate to 9.765624753299562e-08.
# Epoch 53/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2601 - mad: 0.1531 - mean_absolute_error: 0.4761 - rmse: 0.5099 - val_loss: 0.1416 - val_mad: 0.0139 - val_mean_absolute_error: 0.3758 - val_rmse: 0.3762 - learning_rate: 9.7656e-08
#
# Epoch 54: LearningRateScheduler setting learning rate to 9.765624753299562e-08.
# Epoch 54/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2917 - mad: 0.2044 - mean_absolute_error: 0.4831 - rmse: 0.5391 - val_loss: 0.1415 - val_mad: 0.0142 - val_mean_absolute_error: 0.3756 - val_rmse: 0.3760 - learning_rate: 9.7656e-08
#
# Epoch 55: LearningRateScheduler setting learning rate to 9.765624753299562e-08.
# Epoch 55/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2650 - mad: 0.1798 - mean_absolute_error: 0.4692 - rmse: 0.5146 - val_loss: 0.1374 - val_mad: 0.0143 - val_mean_absolute_error: 0.3700 - val_rmse: 0.3705 - learning_rate: 9.7656e-08
#
# Epoch 56: LearningRateScheduler setting learning rate to 4.882812376649781e-08.
# Epoch 56/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.2863 - mad: 0.2236 - mean_absolute_error: 0.4756 - rmse: 0.5349 - val_loss: 0.1358 - val_mad: 0.0144 - val_mean_absolute_error: 0.3679 - val_rmse: 0.3684 - learning_rate: 4.8828e-08
#
# Epoch 57: LearningRateScheduler setting learning rate to 4.882812376649781e-08.
# Epoch 57/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2487 - mad: 0.1377 - mean_absolute_error: 0.4665 - rmse: 0.4986 - val_loss: 0.1331 - val_mad: 0.0147 - val_mean_absolute_error: 0.3642 - val_rmse: 0.3647 - learning_rate: 4.8828e-08
#
# Epoch 58: LearningRateScheduler setting learning rate to 4.882812376649781e-08.
# Epoch 58/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2883 - mad: 0.2156 - mean_absolute_error: 0.4806 - rmse: 0.5367 - val_loss: 0.1317 - val_mad: 0.0149 - val_mean_absolute_error: 0.3623 - val_rmse: 0.3628 - learning_rate: 4.8828e-08
#
# Epoch 59: LearningRateScheduler setting learning rate to 4.882812376649781e-08.
# Epoch 59/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2899 - mad: 0.2000 - mean_absolute_error: 0.4834 - rmse: 0.5370 - val_loss: 0.1308 - val_mad: 0.0150 - val_mean_absolute_error: 0.3610 - val_rmse: 0.3615 - learning_rate: 4.8828e-08
#
# Epoch 60: LearningRateScheduler setting learning rate to 4.882812376649781e-08.
# Epoch 60/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.2730 - mad: 0.1838 - mean_absolute_error: 0.4715 - rmse: 0.5220 - val_loss: 0.1279 - val_mad: 0.0150 - val_mean_absolute_error: 0.3569 - val_rmse: 0.3575 - learning_rate: 4.8828e-08

# %%
# Evaluate the model on the test data
evaluation = model.evaluate(features_test, labels_test)

# Print the evaluation results with four decimal places
print(f"Evaluation Loss (MSE): {evaluation[0]:.5f}")
print(f"Evaluation MAE: {evaluation[1]:.5f}")
print(f"Evaluation RMSE: {evaluation[2]:.5f}")
print(f"Evaluation MAD: {evaluation[3]:.5f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 784ms/step - loss: 0.1279 - mad: 0.0157 - mean_absolute_error: 0.3569 - rmse: 0.3576
# Evaluation Loss (MSE): 0.12790
# Evaluation MAE: 0.35693
# Evaluation RMSE: 0.35764
# Evaluation MAD: 0.01566

# %%
# Plot the Train loss and validation loss
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss and validation loss')
plt.xlabel('Epoch')
plt.ylabel('Metric Value')
plt.legend()
plt.show()

# %%
# Plot the train rmse and validation rmse
plt.figure(figsize=(12, 6))
plt.plot(history.history['rmse'], label='Train RMSE')
plt.plot(history.history['val_rmse'], label='Validation RMSE')
plt.title('Train RMSE Vs Validation RMSE')
plt.xlabel('Epoch')
plt.ylabel('Metric Value')
plt.legend()
plt.show()

# %%
# Plot the tain MAD and validation MAD
plt.figure(figsize=(12, 6))
plt.plot(history.history['mad'], label='Train MAD')
plt.plot(history.history['val_mad'], label='Validation MAD')
plt.title('Train MAD Vs Validation MAD')
plt.xlabel('Epoch')
plt.ylabel('Metric Value')
plt.legend()
plt.show()

# %%
model.save('LSTM(E08).h5')

# %%
import os
import cv2
import numpy as np

# Function to save all split videos from the test set to a folder
def save_all_split_videos(video_data, save_dir, SEQUENCE_LENGTH=16, IMAGE_HEIGHT=64, IMAGE_WIDTH=64, fps=30):
    """
    Save all split videos from the video data as individual video files in the specified directory.

    Args:
        video_data: Numpy array containing video data of shape (num_videos, SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3).
        save_dir: Directory to save the videos.
        SEQUENCE_LENGTH: Number of frames per video (default is 16).
        IMAGE_HEIGHT: Height of the frames (default is 64).
        IMAGE_WIDTH: Width of the frames (default is 64).
        fps: Frames per second for the output videos (default is 30).
    """
    # Create the save directory if it doesn't exist
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    # Iterate over all videos in the dataset
    for video_index in range(video_data.shape[0]):
        video_frames = video_data[video_index]  # Shape: (SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3)

        # Prepare the VideoWriter object to save the video
        video_filename = os.path.join(save_dir, f"split_video_{video_index + 1}.mp4")
        fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Use 'mp4v' for .mp4 format
        video_writer = cv2.VideoWriter(video_filename, fourcc, fps, (IMAGE_WIDTH, IMAGE_HEIGHT))

        # Add frames to the video
        for frame in video_frames:
            # Ensure the frame has values in the range [0, 255] and convert to uint8
            frame_rgb = (frame * 255).astype(np.uint8)
            # Convert RGB to BGR for OpenCV
            frame_bgr = cv2.cvtColor(frame_rgb, cv2.COLOR_RGB2BGR)
            # Write the frame to the video
            video_writer.write(frame_bgr)

        # Release the video writer
        video_writer.release()
        print(f"Video {video_index + 1} saved to: {video_filename}")

# Example usage: Save all split videos from the test set
# Make sure `features_test` is defined before calling this function
save_all_split_videos(features_test, save_dir="/kaggle/working/split_videos")
# Out:
# Video 1 saved to: /kaggle/working/split_videos/split_video_1.mp4
# Video 2 saved to: /kaggle/working/split_videos/split_video_2.mp4
# Video 3 saved to: /kaggle/working/split_videos/split_video_3.mp4
# Video 4 saved to: /kaggle/working/split_videos/split_video_4.mp4
# Video 5 saved to: /kaggle/working/split_videos/split_video_5.mp4
# Video 6 saved to: /kaggle/working/split_videos/split_video_6.mp4
# Video 7 saved to: /kaggle/working/split_videos/split_video_7.mp4
# Video 8 saved to: /kaggle/working/split_videos/split_video_8.mp4
# Video 9 saved to: /kaggle/working/split_videos/split_video_9.mp4
# Video 10 saved to: /kaggle/working/split_videos/split_video_10.mp4
# Video 11 saved to: /kaggle/working/split_videos/split_video_11.mp4
# Video 12 saved to: /kaggle/working/split_videos/split_video_12.mp4
# Video 13 saved to: /kaggle/working/split_videos/split_video_13.mp4
# Video 14 saved to: /kaggle/working/split_videos/split_video_14.mp4
# Video 15 saved to: /kaggle/working/split_videos/split_video_15.mp4
# Video 16 saved to: /kaggle/working/split_videos/split_video_16.mp4

# %%
# Example prediction for a new video
video_path = '/kaggle/working/split_videos/split_video_13.mp4'
def process_video(video_path):
    # Example preprocessing: Replace this with actual video processing logic
    video_data = np.random.random((SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3))  # Replace with real processing
    
    # Flatten spatial dimensions into FEATURE_SIZE
    FEATURE_SIZE = IMAGE_HEIGHT * IMAGE_WIDTH * 3  # RGB channels
    video_data = video_data.reshape(SEQUENCE_LENGTH, FEATURE_SIZE)
    
    # Add batch dimension
    return np.expand_dims(video_data, axis=0)
predicted_score = model.predict(process_video(video_path))

scaled_score = predicted_score * 99 + 1
print(f"Predicted Score: {scaled_score[0][0]:.2f}")  # Assuming `predicted_score` is a 2D array
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# Predicted Score: 36.11
