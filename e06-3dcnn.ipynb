# %%
import os
import shutil
import cv2
import math
import random
import numpy as np
import tensorflow as tf
from tensorflow import keras
from collections import deque
import matplotlib.pyplot as plt
plt.style.use("seaborn")
import tqdm
# %matplotlib inline
from tensorflow.keras import Model
from sklearn.model_selection import train_test_split
from keras.applications.mobilenet_v2 import MobileNetV2
from keras.layers import *
from keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.utils import plot_model

from IPython.display import HTML
from base64 import b64encode
from tensorflow.keras.layers import Input,Dense, Flatten, ReLU, Conv2D, DepthwiseConv2D,AvgPool2D, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.optimizers import Adam
import keras.backend as K
from typing import Optional
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings('ignore')

# %%
IMAGE_HEIGHT, IMAGE_WIDTH = 128, 128
SEQUENCE_LENGTH = 30

# %%
CLASSES_LIST = ["E06(Wrist_Extension)"]

# %%
def frames_extraction(video_path):
    frames_list = []
    video_reader = cv2.VideoCapture(video_path)
    video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))
    skip_frames_window = max(int(video_frames_count/SEQUENCE_LENGTH), 1)

    for frame_counter in range(SEQUENCE_LENGTH):
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)
        success, frame = video_reader.read()

        if not success:
            break

        resized_frame = cv2.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))
        normalized_frame = resized_frame / 255
        frames_list.append(normalized_frame)

    video_reader.release()
    return frames_list

# %%
def create_dataset(video_dir, csv_file_path):
    features = []
    labels = []
    video_files_paths = []
    matching_files_count = 0

    # Read the CSV file
    csv_data = pd.read_csv(csv_file_path)

    for class_index, class_name in enumerate(CLASSES_LIST):
        print(f'Extracting Data of Class: {class_name}')
        files_list = os.listdir(os.path.join(video_dir, class_name))

        for file_name in files_list:
            # Remove the .mp4 extension from the file name
            video_name = os.path.splitext(file_name)[0]

            video_file_path = os.path.join(video_dir, class_name, file_name)
            frames = frames_extraction(video_file_path)

            if len(frames) == SEQUENCE_LENGTH:
                # Search for the exercise name in the CSV data that matches with video file name
                matching_row = csv_data[csv_data['Excercise Name'].str.lower() == video_name.lower()]

                if not matching_row.empty:
                    assessment_score = matching_row['Assessment Score'].values[0]
                    features.append(frames)
                    labels.append(class_index)
                    video_files_paths.append(video_file_path)
                    matching_files_count += 1
                    print(f'Matched file: {video_name}, Assessment Score: {assessment_score}')
                else:
                    # Append None if no matching row is found
                    features.append(frames)
                    labels.append(class_index)
                    video_files_paths.append(video_file_path)
                    print(f'No matching row found for file: {video_name}')

    features = np.asarray(features)
    labels = np.asarray(labels)

    print(f'Total matching files: {matching_files_count}')

    return features, labels, matching_files_count, video_files_paths

# %%
import pandas as pd

video_dir = '/kaggle/input/regression-folders/dataset_regression'
csv_file_path = '/kaggle/input/csv-files-regression/Ex_06_sub.csv'
features, labels, matching_files_count, video_files_paths =  create_dataset(video_dir, csv_file_path)
print("Features shape:", features.shape)
print("Labels shape:", labels.shape)
print("Matching files count:", matching_files_count)
print("Number of video files:", len(video_files_paths))
# Out:
# Extracting Data of Class: E06(Wrist_Extension)
# Matched file: E06_P05_AF_VML_GM, Assessment Score: 74.76
# Matched file: E06_P10_AR_VLL_GF, Assessment Score: 95.24
# Matched file: E06_P09_AF_VLL_GF, Assessment Score: 100.0
# Matched file: E06_P21_AF_VO_GM, Assessment Score: 83.33
# Matched file: E06_P03_AR_VLJ_GM, Assessment Score: 97.62
# Matched file: E06_P07_AR_VLJ_GM, Assessment Score: 76.19
# Matched file: E06_P17_AL_VHJ_GM, Assessment Score: 82.86
# Matched file: E06_P11_AF_VO_GF, Assessment Score: 79.52
# Matched file: E06_P07_AR_VHJ_GM, Assessment Score: 73.81
# Matched file: E06_P04_AF_VHJ_GM, Assessment Score: 95.24
# Matched file: E06_P07_AL_VLJ_GM, Assessment Score: 76.19
# Matched file: E06_P11_AR_VFL_GF, Assessment Score: 100.0
# Matched file: E06_P22_AL_VO_GM, Assessment Score: 84.29
# Matched file: E06_P12_AF_VO_GF, Assessment Score: 100.0
# Matched file: E06_P16_AR_VHJ_GF, Assessment Score: 95.24
# Matched file: E06_P16_AF_VLL_GF, Assessment Score: 77.14
# Matched file: E06_P15_AL_VLL_GF, Assessment Score: 100.0
# Matched file: E06_P08_AL_VHJ_GM, Assessment Score: 70.0
# Matched file: E06_P07_AR_VLL_GM, Assessment Score: 85.71
# Matched file: E06_P21_AL_VLJ_GM, Assessment Score: 88.1
# Matched file: E06_P13_AL_VLL_GF, Assessment Score: 84.29
# Matched file: E06_P19_AL_VO_GM, Assessment Score: 92.86
# Matched file: E06_P21_AR_VO_GM, Assessment Score: 83.33
# Matched file: E06_P08_AF_VHJ_GM, Assessment Score: 85.71
# Matched file: E06_P03_AR_VML_GM, Assessment Score: 81.9
# Matched file: E06_P19_AF_VHJ_GM, Assessment Score: 97.62
# Matched file: E06_P17_AF_VFL_GM, Assessment Score: 95.24
# Matched file: E06_P16_AF_VML_GF, Assessment Score: 92.86
# Matched file: E06_P07_AF_VO_GM, Assessment Score: 78.1
# Matched file: E06_P17_AR_VHJ_GM, Assessment Score: 84.29
# Matched file: E06_P06_AL_VO_GM, Assessment Score: 100.0
# Matched file: E06_P10_AF_VLL_GF, Assessment Score: 95.24
# Matched file: E06_P03_AL_VLL_GM, Assessment Score: 84.29
# Matched file: E06_P07_AF_VHJ_GM, Assessment Score: 73.81
# Matched file: E06_P07_AF_VLL_GM, Assessment Score: 85.71
# Matched file: E06_P05_AR_VML_GM, Assessment Score: 74.76
# Matched file: E06_P19_AR_VML_GM, Assessment Score: 97.62
# Matched file: E06_P03_AF_VML_GM, Assessment Score: 81.9
# Matched file: E06_P19_AL_VHJ_GM, Assessment Score: 97.62
# Matched file: E06_P21_AL_VLL_GM, Assessment Score: 74.76
# Matched file: E06_P08_AL_VFL_GM, Assessment Score: 95.24
# Matched file: E06_P15_AF_VLJ_GF, Assessment Score: 100.0
# Matched file: E06_P03_AL_VML_GM, Assessment Score: 81.9
# Matched file: E06_P21_AF_VLJ_GM, Assessment Score: 88.1
# Matched file: E06_P07_AL_VLL_GM, Assessment Score: 85.71
# Matched file: E06_P07_AL_VHJ_GM, Assessment Score: 73.81
# Matched file: E06_P03_AR_VLL_GM, Assessment Score: 84.29
# Matched file: E06_P05_AF_VLJ_GM, Assessment Score: 97.62
# Matched file: E06_P21_AR_VML_GM, Assessment Score: 67.62
# Matched file: E06_P16_AR_VLJ_GF, Assessment Score: 79.52
# Matched file: E06_P16_AR_VLL_GF, Assessment Score: 75.71
# Matched file: E06_P20_AF_VLL_GM, Assessment Score: 90.48
# Matched file: E06_P22_AL_VML_GM, Assessment Score: 79.52
# Matched file: E06_P21_AL_VML_GM, Assessment Score: 67.62
# Matched file: E06_P21_AR_VLJ_GM, Assessment Score: 88.1
# Matched file: E06_P21_AR_VLL_GM, Assessment Score: 90.48
# Matched file: E06_P07_AL_VO_GM, Assessment Score: 67.62
# Matched file: E06_P20_AR_VLL_GM, Assessment Score: 90.48
# Matched file: E06_P19_AR_VO_GM, Assessment Score: 92.86
# Matched file: E06_P08_AR_VHJ_GM, Assessment Score: 70.0
# Matched file: E06_P07_AL_VML_GM, Assessment Score: 84.29
# Matched file: E06_P19_AF_VLL_GM, Assessment Score: 92.86
# Matched file: E06_P09_AF_VML_GF, Assessment Score: 95.24
# Matched file: E06_P05_AL_VML_GM, Assessment Score: 74.76
# Matched file: E06_P04_AL_VML_GM, Assessment Score: 79.52
# Matched file: E06_P04_AF_VML_GM, Assessment Score: 79.52
# Matched file: E06_P16_AF_VO_GF, Assessment Score: 92.86
# Matched file: E06_P23_AR_VLL_GM, Assessment Score: 84.29
# Matched file: E06_P08_AR_VLJ_GM, Assessment Score: 84.29
# Matched file: E06_P08_AR_VLL_GM, Assessment Score: 84.29
# Matched file: E06_P21_AL_VO_GM, Assessment Score: 67.62
# Matched file: E06_P10_AF_VML_GF, Assessment Score: 97.62
# Matched file: E06_P19_AR_VHJ_GM, Assessment Score: 97.62
# Matched file: E06_P21_AF_VML_GM, Assessment Score: 83.33
# Matched file: E06_P20_AL_VLL_GM, Assessment Score: 90.48
# Matched file: E06_P10_AL_VML_GF, Assessment Score: 97.62
# Matched file: E06_P04_AL_VHJ_GM, Assessment Score: 95.24
# Matched file: E06_P16_AL_VLL_GF, Assessment Score: 75.71
# Matched file: E06_P18_AL_VLJ_GM, Assessment Score: 82.86
# Matched file: E06_P07_AF_VLJ_GM, Assessment Score: 76.19
# Total matching files: 80
# Features shape: (80, 30, 128, 128, 3)
# Labels shape: (80,)
# Matching files count: 80
# Number of video files: 80

# %%
np.save("features.npy", features)
np.save("labels.npy", labels)
np.save("video_files_paths.npy", video_files_paths)

# %%
features, labels, video_files_paths = np.load("features.npy"), np.load("labels.npy"), np.load("video_files_paths.npy")

# %%
print(f'Number of features: {len(features)}, Number of labels: {len(labels)}, Number of video_files_paths: {len(video_files_paths)}')
# Out:
# Number of features: 80, Number of labels: 80, Number of video_files_paths: 80

# %%
features_train, features_test, labels_train, labels_test = train_test_split(
    features, labels, test_size=0.20, shuffle=True, random_state=42
)

print(f"Training features: {features_train.shape}, Training labels: {labels_train.shape}")
print(f"Testing features: {features_test.shape}, Testing labels: {labels_test.shape}")
# Out:
# Training features: (64, 30, 128, 128, 3), Training labels: (64,)
# Testing features: (16, 30, 128, 128, 3), Testing labels: (16,)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler, ModelCheckpoint
import matplotlib.pyplot as plt
import numpy as np

# Define custom metrics: RMSE and MAD
def rmse(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)  # Ensure y_true is float32
    return tf.sqrt(tf.reduce_mean(tf.square(y_pred - y_true)))

def mad(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)  # Ensure y_true is float32
    return tf.reduce_mean(tf.abs(y_pred - tf.reduce_mean(y_pred)))

# Define the 3D CNN model
def create_3d_cnn_model(SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH):
    """
    A 3D CNN model for spatiotemporal feature extraction and regression.
    """
    # Define the video input (4D input for 3D CNN)
    video_input = layers.Input(shape=(SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3))
    
    # 3D CNN layers for spatiotemporal feature extraction
    x = layers.Conv3D(32, (3, 3, 3), padding='same', activation='relu')(video_input)
    x = layers.MaxPooling3D((2, 2, 2))(x)
    x = layers.Dropout(0.4)(x)
    x = layers.BatchNormalization()(x)
    
    x = layers.Conv3D(64, (3, 3, 3), padding='same', activation='relu')(x)
    x = layers.MaxPooling3D((2, 2, 2))(x)
    x = layers.Dropout(0.4)(x)
    x = layers.BatchNormalization()(x)
    
    x = layers.Conv3D(128, (3, 3, 3), padding='same', activation='relu')(x)
    x = layers.MaxPooling3D((2, 2, 2))(x)
    x = layers.Dropout(0.4)(x)
    x = layers.BatchNormalization()(x)

    # Flatten the output of the 3D CNN
    x = layers.GlobalAveragePooling3D()(x)

    # Dense layer for regression output
    regression_output = layers.Dense(1, activation='sigmoid', name='regression_output')(x)
    
    # Build the model
    model = models.Model(inputs=video_input, outputs=[regression_output])
    model.summary()
    
    return model

# %%
# Define hyperparameters
SEQUENCE_LENGTH = 30  # Set according to your input data
IMAGE_HEIGHT = 128  # Set the height of your input images
IMAGE_WIDTH = 128  # Set the width of your input images

# Create the model
model = create_3d_cnn_model(SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 30, 128, 128,   │             0 │
# │                                 │ 3)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d (Conv3D)                 │ (None, 30, 128, 128,   │         2,624 │
# │                                 │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d (MaxPooling3D)    │ (None, 15, 64, 64, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 15, 64, 64, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 15, 64, 64, 32) │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_1 (Conv3D)               │ (None, 15, 64, 64, 64) │        55,360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_1 (MaxPooling3D)  │ (None, 7, 32, 32, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 7, 32, 32, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 7, 32, 32, 64)  │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_2 (Conv3D)               │ (None, 7, 32, 32, 128) │       221,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_2 (MaxPooling3D)  │ (None, 3, 16, 16, 128) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 3, 16, 16, 128) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 3, 16, 16, 128) │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling3d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling3D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ regression_output (Dense)       │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 280,321 (1.07 MB)
#  Trainable params: 279,873 (1.07 MB)
#  Non-trainable params: 448 (1.75 KB)

# %%
# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='mean_squared_error',  # Use MSE for regression
              metrics=['mean_absolute_error', rmse, mad])

# Define Early Stopping and Learning Rate Scheduler callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

lr_scheduler = LearningRateScheduler(lambda epoch, lr: lr * 0.5 if epoch % 10 == 0 and epoch > 0 else lr, verbose=1)



# Callbacks list
callbacks = [early_stopping, lr_scheduler]
# Train the model
history = model.fit(features_train, labels_train,
                    validation_data=(features_test, labels_test),
                    epochs=60, batch_size=8, verbose=1, 
                    callbacks=callbacks)
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 1/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 160s 19s/step - loss: 0.2539 - mad: 0.0487 - mean_absolute_error: 0.4993 - rmse: 0.5038 - val_loss: 0.2602 - val_mad: 9.2162e-04 - val_mean_absolute_error: 0.5101 - val_rmse: 0.5101 - learning_rate: 1.0000e-04
#
# Epoch 2: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 2/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 153s 19s/step - loss: 0.2472 - mad: 0.0219 - mean_absolute_error: 0.4965 - rmse: 0.4972 - val_loss: 0.2569 - val_mad: 0.0020 - val_mean_absolute_error: 0.5069 - val_rmse: 0.5069 - learning_rate: 1.0000e-04
#
# Epoch 3: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 3/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 148s 19s/step - loss: 0.2440 - mad: 0.0103 - mean_absolute_error: 0.4937 - rmse: 0.4939 - val_loss: 0.2435 - val_mad: 0.0014 - val_mean_absolute_error: 0.4935 - val_rmse: 0.4935 - learning_rate: 1.0000e-04
#
# Epoch 4: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 4/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 148s 19s/step - loss: 0.2412 - mad: 0.0104 - mean_absolute_error: 0.4910 - rmse: 0.4911 - val_loss: 0.2411 - val_mad: 0.0020 - val_mean_absolute_error: 0.4910 - val_rmse: 0.4910 - learning_rate: 1.0000e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 5/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 152s 19s/step - loss: 0.2384 - mad: 0.0088 - mean_absolute_error: 0.4882 - rmse: 0.4883 - val_loss: 0.2470 - val_mad: 0.0020 - val_mean_absolute_error: 0.4970 - val_rmse: 0.4970 - learning_rate: 1.0000e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 6/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 152s 19s/step - loss: 0.2357 - mad: 0.0091 - mean_absolute_error: 0.4854 - rmse: 0.4855 - val_loss: 0.2456 - val_mad: 0.0027 - val_mean_absolute_error: 0.4956 - val_rmse: 0.4956 - learning_rate: 1.0000e-04
#
# Epoch 7: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 7/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 148s 19s/step - loss: 0.2331 - mad: 0.0116 - mean_absolute_error: 0.4825 - rmse: 0.4828 - val_loss: 0.2326 - val_mad: 0.0022 - val_mean_absolute_error: 0.4823 - val_rmse: 0.4823 - learning_rate: 1.0000e-04
#
# Epoch 8: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 8/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 148s 19s/step - loss: 0.2302 - mad: 0.0079 - mean_absolute_error: 0.4797 - rmse: 0.4798 - val_loss: 0.2289 - val_mad: 0.0019 - val_mean_absolute_error: 0.4785 - val_rmse: 0.4785 - learning_rate: 1.0000e-04
#
# Epoch 9: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 9/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 202s 19s/step - loss: 0.2275 - mad: 0.0083 - mean_absolute_error: 0.4768 - rmse: 0.4769 - val_loss: 0.2285 - val_mad: 0.0017 - val_mean_absolute_error: 0.4780 - val_rmse: 0.4780 - learning_rate: 1.0000e-04
#
# Epoch 10: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 10/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 148s 19s/step - loss: 0.2249 - mad: 0.0129 - mean_absolute_error: 0.4739 - rmse: 0.4742 - val_loss: 0.2329 - val_mad: 0.0016 - val_mean_absolute_error: 0.4826 - val_rmse: 0.4826 - learning_rate: 1.0000e-04
#
# Epoch 11: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 11/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 154s 19s/step - loss: 0.2224 - mad: 0.0109 - mean_absolute_error: 0.4713 - rmse: 0.4715 - val_loss: 0.2117 - val_mad: 0.0025 - val_mean_absolute_error: 0.4601 - val_rmse: 0.4601 - learning_rate: 5.0000e-05
#
# Epoch 12: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 12/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 154s 19s/step - loss: 0.2209 - mad: 0.0092 - mean_absolute_error: 0.4698 - rmse: 0.4700 - val_loss: 0.2098 - val_mad: 0.0021 - val_mean_absolute_error: 0.4581 - val_rmse: 0.4581 - learning_rate: 5.0000e-05
#
# Epoch 13: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 13/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 150s 19s/step - loss: 0.2194 - mad: 0.0081 - mean_absolute_error: 0.4683 - rmse: 0.4684 - val_loss: 0.2214 - val_mad: 0.0016 - val_mean_absolute_error: 0.4705 - val_rmse: 0.4705 - learning_rate: 5.0000e-05
#
# Epoch 14: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 14/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 149s 19s/step - loss: 0.2181 - mad: 0.0092 - mean_absolute_error: 0.4668 - rmse: 0.4670 - val_loss: 0.2138 - val_mad: 0.0026 - val_mean_absolute_error: 0.4624 - val_rmse: 0.4624 - learning_rate: 5.0000e-05
#
# Epoch 15: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 15/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 201s 19s/step - loss: 0.2167 - mad: 0.0098 - mean_absolute_error: 0.4653 - rmse: 0.4655 - val_loss: 0.2082 - val_mad: 0.0024 - val_mean_absolute_error: 0.4563 - val_rmse: 0.4563 - learning_rate: 5.0000e-05
#
# Epoch 16: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 16/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 207s 19s/step - loss: 0.2152 - mad: 0.0091 - mean_absolute_error: 0.4638 - rmse: 0.4639 - val_loss: 0.1981 - val_mad: 0.0017 - val_mean_absolute_error: 0.4451 - val_rmse: 0.4451 - learning_rate: 5.0000e-05
#
# Epoch 17: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 17/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 148s 19s/step - loss: 0.2138 - mad: 0.0105 - mean_absolute_error: 0.4622 - rmse: 0.4624 - val_loss: 0.1877 - val_mad: 0.0022 - val_mean_absolute_error: 0.4333 - val_rmse: 0.4333 - learning_rate: 5.0000e-05
#
# Epoch 18: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 18/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 152s 19s/step - loss: 0.2124 - mad: 0.0102 - mean_absolute_error: 0.4607 - rmse: 0.4608 - val_loss: 0.2071 - val_mad: 0.0014 - val_mean_absolute_error: 0.4550 - val_rmse: 0.4550 - learning_rate: 5.0000e-05
#
# Epoch 19: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 19/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 148s 19s/step - loss: 0.2109 - mad: 0.0092 - mean_absolute_error: 0.4591 - rmse: 0.4592 - val_loss: 0.2055 - val_mad: 9.0223e-04 - val_mean_absolute_error: 0.4533 - val_rmse: 0.4533 - learning_rate: 5.0000e-05
#
# Epoch 20: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 20/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 207s 19s/step - loss: 0.2094 - mad: 0.0085 - mean_absolute_error: 0.4575 - rmse: 0.4576 - val_loss: 0.1791 - val_mad: 0.0011 - val_mean_absolute_error: 0.4233 - val_rmse: 0.4233 - learning_rate: 5.0000e-05
#
# Epoch 21: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 21/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 148s 19s/step - loss: 0.2083 - mad: 0.0113 - mean_absolute_error: 0.4561 - rmse: 0.4564 - val_loss: 0.1824 - val_mad: 0.0011 - val_mean_absolute_error: 0.4271 - val_rmse: 0.4271 - learning_rate: 2.5000e-05
#
# Epoch 22: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 22/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 148s 18s/step - loss: 0.2075 - mad: 0.0104 - mean_absolute_error: 0.4553 - rmse: 0.4555 - val_loss: 0.1868 - val_mad: 0.0011 - val_mean_absolute_error: 0.4322 - val_rmse: 0.4322 - learning_rate: 2.5000e-05
#
# Epoch 23: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 23/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 147s 18s/step - loss: 0.2067 - mad: 0.0105 - mean_absolute_error: 0.4545 - rmse: 0.4547 - val_loss: 0.1852 - val_mad: 0.0012 - val_mean_absolute_error: 0.4304 - val_rmse: 0.4304 - learning_rate: 2.5000e-05
#
# Epoch 24: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 24/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 203s 19s/step - loss: 0.2060 - mad: 0.0114 - mean_absolute_error: 0.4537 - rmse: 0.4539 - val_loss: 0.1963 - val_mad: 0.0016 - val_mean_absolute_error: 0.4431 - val_rmse: 0.4431 - learning_rate: 2.5000e-05
#
# Epoch 25: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 25/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 148s 19s/step - loss: 0.2053 - mad: 0.0131 - mean_absolute_error: 0.4529 - rmse: 0.4531 - val_loss: 0.1696 - val_mad: 0.0015 - val_mean_absolute_error: 0.4118 - val_rmse: 0.4118 - learning_rate: 2.5000e-05
#
# Epoch 26: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 26/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 148s 19s/step - loss: 0.2046 - mad: 0.0114 - mean_absolute_error: 0.4521 - rmse: 0.4523 - val_loss: 0.1796 - val_mad: 0.0019 - val_mean_absolute_error: 0.4237 - val_rmse: 0.4237 - learning_rate: 2.5000e-05
#
# Epoch 27: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 27/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 148s 19s/step - loss: 0.2037 - mad: 0.0102 - mean_absolute_error: 0.4512 - rmse: 0.4514 - val_loss: 0.1851 - val_mad: 0.0020 - val_mean_absolute_error: 0.4302 - val_rmse: 0.4302 - learning_rate: 2.5000e-05
#
# Epoch 28: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 28/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 147s 19s/step - loss: 0.2031 - mad: 0.0117 - mean_absolute_error: 0.4504 - rmse: 0.4507 - val_loss: 0.1689 - val_mad: 0.0021 - val_mean_absolute_error: 0.4109 - val_rmse: 0.4110 - learning_rate: 2.5000e-05
#
# Epoch 29: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 29/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 208s 19s/step - loss: 0.2023 - mad: 0.0097 - mean_absolute_error: 0.4496 - rmse: 0.4497 - val_loss: 0.1765 - val_mad: 0.0031 - val_mean_absolute_error: 0.4201 - val_rmse: 0.4201 - learning_rate: 2.5000e-05
#
# Epoch 30: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 30/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 148s 19s/step - loss: 0.2015 - mad: 0.0080 - mean_absolute_error: 0.4487 - rmse: 0.4489 - val_loss: 0.1597 - val_mad: 0.0032 - val_mean_absolute_error: 0.3996 - val_rmse: 0.3996 - learning_rate: 2.5000e-05
#
# Epoch 31: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 31/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 150s 19s/step - loss: 0.2008 - mad: 0.0085 - mean_absolute_error: 0.4480 - rmse: 0.4482 - val_loss: 0.1751 - val_mad: 0.0039 - val_mean_absolute_error: 0.4184 - val_rmse: 0.4184 - learning_rate: 1.2500e-05
#
# Epoch 32: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 32/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 154s 19s/step - loss: 0.2005 - mad: 0.0102 - mean_absolute_error: 0.4476 - rmse: 0.4478 - val_loss: 0.1559 - val_mad: 0.0035 - val_mean_absolute_error: 0.3948 - val_rmse: 0.3948 - learning_rate: 1.2500e-05
#
# Epoch 33: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 33/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 152s 19s/step - loss: 0.2001 - mad: 0.0090 - mean_absolute_error: 0.4472 - rmse: 0.4473 - val_loss: 0.1723 - val_mad: 0.0039 - val_mean_absolute_error: 0.4150 - val_rmse: 0.4150 - learning_rate: 1.2500e-05
#
# Epoch 34: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 34/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 152s 19s/step - loss: 0.1999 - mad: 0.0131 - mean_absolute_error: 0.4468 - rmse: 0.4471 - val_loss: 0.1643 - val_mad: 0.0036 - val_mean_absolute_error: 0.4053 - val_rmse: 0.4053 - learning_rate: 1.2500e-05
#
# Epoch 35: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 35/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 152s 19s/step - loss: 0.1993 - mad: 0.0083 - mean_absolute_error: 0.4463 - rmse: 0.4465 - val_loss: 0.1646 - val_mad: 0.0038 - val_mean_absolute_error: 0.4056 - val_rmse: 0.4057 - learning_rate: 1.2500e-05
#
# Epoch 36: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 36/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 148s 19s/step - loss: 0.1990 - mad: 0.0091 - mean_absolute_error: 0.4459 - rmse: 0.4461 - val_loss: 0.1674 - val_mad: 0.0041 - val_mean_absolute_error: 0.4091 - val_rmse: 0.4091 - learning_rate: 1.2500e-05
#
# Epoch 37: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 37/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 148s 19s/step - loss: 0.1986 - mad: 0.0081 - mean_absolute_error: 0.4455 - rmse: 0.4456 - val_loss: 0.1671 - val_mad: 0.0042 - val_mean_absolute_error: 0.4087 - val_rmse: 0.4087 - learning_rate: 1.2500e-05
#
# Epoch 38: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 38/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 152s 19s/step - loss: 0.1982 - mad: 0.0088 - mean_absolute_error: 0.4451 - rmse: 0.4452 - val_loss: 0.1531 - val_mad: 0.0043 - val_mean_absolute_error: 0.3913 - val_rmse: 0.3913 - learning_rate: 1.2500e-05
#
# Epoch 39: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 39/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 152s 19s/step - loss: 0.1979 - mad: 0.0098 - mean_absolute_error: 0.4447 - rmse: 0.4448 - val_loss: 0.1611 - val_mad: 0.0048 - val_mean_absolute_error: 0.4013 - val_rmse: 0.4014 - learning_rate: 1.2500e-05
#
# Epoch 40: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 40/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 198s 19s/step - loss: 0.1974 - mad: 0.0073 - mean_absolute_error: 0.4442 - rmse: 0.4443 - val_loss: 0.1662 - val_mad: 0.0051 - val_mean_absolute_error: 0.4076 - val_rmse: 0.4077 - learning_rate: 1.2500e-05
#
# Epoch 41: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 41/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 148s 19s/step - loss: 0.1972 - mad: 0.0104 - mean_absolute_error: 0.4439 - rmse: 0.4440 - val_loss: 0.1590 - val_mad: 0.0049 - val_mean_absolute_error: 0.3987 - val_rmse: 0.3987 - learning_rate: 6.2500e-06
#
# Epoch 42: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 42/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 148s 19s/step - loss: 0.1970 - mad: 0.0088 - mean_absolute_error: 0.4437 - rmse: 0.4438 - val_loss: 0.1570 - val_mad: 0.0047 - val_mean_absolute_error: 0.3962 - val_rmse: 0.3963 - learning_rate: 6.2500e-06
#
# Epoch 43: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 43/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 147s 18s/step - loss: 0.1968 - mad: 0.0092 - mean_absolute_error: 0.4434 - rmse: 0.4436 - val_loss: 0.1680 - val_mad: 0.0051 - val_mean_absolute_error: 0.4098 - val_rmse: 0.4099 - learning_rate: 6.2500e-06
#
# Epoch 44: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 44/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 206s 19s/step - loss: 0.1967 - mad: 0.0114 - mean_absolute_error: 0.4432 - rmse: 0.4435 - val_loss: 0.1597 - val_mad: 0.0051 - val_mean_absolute_error: 0.3996 - val_rmse: 0.3996 - learning_rate: 6.2500e-06
#
# Epoch 45: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 45/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 151s 19s/step - loss: 0.1964 - mad: 0.0091 - mean_absolute_error: 0.4430 - rmse: 0.4432 - val_loss: 0.1672 - val_mad: 0.0055 - val_mean_absolute_error: 0.4088 - val_rmse: 0.4089 - learning_rate: 6.2500e-06
#
# Epoch 46: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 46/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 152s 19s/step - loss: 0.1962 - mad: 0.0099 - mean_absolute_error: 0.4428 - rmse: 0.4430 - val_loss: 0.1611 - val_mad: 0.0054 - val_mean_absolute_error: 0.4013 - val_rmse: 0.4014 - learning_rate: 6.2500e-06
#
# Epoch 47: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 47/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 153s 19s/step - loss: 0.1960 - mad: 0.0086 - mean_absolute_error: 0.4426 - rmse: 0.4427 - val_loss: 0.1656 - val_mad: 0.0054 - val_mean_absolute_error: 0.4068 - val_rmse: 0.4069 - learning_rate: 6.2500e-06
#
# Epoch 48: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 48/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 149s 19s/step - loss: 0.1958 - mad: 0.0086 - mean_absolute_error: 0.4424 - rmse: 0.4425 - val_loss: 0.1672 - val_mad: 0.0055 - val_mean_absolute_error: 0.4089 - val_rmse: 0.4089 - learning_rate: 6.2500e-06
#
# Epoch 49: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 49/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 152s 19s/step - loss: 0.1956 - mad: 0.0084 - mean_absolute_error: 0.4422 - rmse: 0.4423 - val_loss: 0.1655 - val_mad: 0.0056 - val_mean_absolute_error: 0.4067 - val_rmse: 0.4068 - learning_rate: 6.2500e-06
#
# Epoch 50: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 50/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 152s 19s/step - loss: 0.1954 - mad: 0.0080 - mean_absolute_error: 0.4420 - rmse: 0.4421 - val_loss: 0.1657 - val_mad: 0.0057 - val_mean_absolute_error: 0.4070 - val_rmse: 0.4070 - learning_rate: 6.2500e-06
#
# Epoch 51: LearningRateScheduler setting learning rate to 3.12499992105586e-06.
# Epoch 51/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 151s 19s/step - loss: 0.1953 - mad: 0.0078 - mean_absolute_error: 0.4418 - rmse: 0.4419 - val_loss: 0.1655 - val_mad: 0.0059 - val_mean_absolute_error: 0.4068 - val_rmse: 0.4068 - learning_rate: 3.1250e-06
#
# Epoch 52: LearningRateScheduler setting learning rate to 3.12499992105586e-06.
# Epoch 52/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 152s 19s/step - loss: 0.1952 - mad: 0.0074 - mean_absolute_error: 0.4417 - rmse: 0.4418 - val_loss: 0.1659 - val_mad: 0.0060 - val_mean_absolute_error: 0.4072 - val_rmse: 0.4073 - learning_rate: 3.1250e-06
#
# Epoch 53: LearningRateScheduler setting learning rate to 3.12499992105586e-06.
# Epoch 53/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 151s 19s/step - loss: 0.1951 - mad: 0.0096 - mean_absolute_error: 0.4416 - rmse: 0.4417 - val_loss: 0.1624 - val_mad: 0.0060 - val_mean_absolute_error: 0.4030 - val_rmse: 0.4030 - learning_rate: 3.1250e-06
#
# Epoch 54: LearningRateScheduler setting learning rate to 3.12499992105586e-06.
# Epoch 54/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 148s 19s/step - loss: 0.1950 - mad: 0.0078 - mean_absolute_error: 0.4414 - rmse: 0.4416 - val_loss: 0.1596 - val_mad: 0.0062 - val_mean_absolute_error: 0.3994 - val_rmse: 0.3995 - learning_rate: 3.1250e-06
#
# Epoch 55: LearningRateScheduler setting learning rate to 3.12499992105586e-06.
# Epoch 55/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 148s 19s/step - loss: 0.1949 - mad: 0.0072 - mean_absolute_error: 0.4413 - rmse: 0.4414 - val_loss: 0.1665 - val_mad: 0.0065 - val_mean_absolute_error: 0.4080 - val_rmse: 0.4081 - learning_rate: 3.1250e-06
#
# Epoch 56: LearningRateScheduler setting learning rate to 3.12499992105586e-06.
# Epoch 56/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 152s 19s/step - loss: 0.1948 - mad: 0.0095 - mean_absolute_error: 0.4412 - rmse: 0.4414 - val_loss: 0.1675 - val_mad: 0.0066 - val_mean_absolute_error: 0.4092 - val_rmse: 0.4092 - learning_rate: 3.1250e-06
#
# Epoch 57: LearningRateScheduler setting learning rate to 3.12499992105586e-06.
# Epoch 57/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 148s 19s/step - loss: 0.1947 - mad: 0.0074 - mean_absolute_error: 0.4411 - rmse: 0.4412 - val_loss: 0.1672 - val_mad: 0.0065 - val_mean_absolute_error: 0.4089 - val_rmse: 0.4089 - learning_rate: 3.1250e-06
#
# Epoch 58: LearningRateScheduler setting learning rate to 3.12499992105586e-06.
# Epoch 58/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 149s 19s/step - loss: 0.1946 - mad: 0.0074 - mean_absolute_error: 0.4410 - rmse: 0.4411 - val_loss: 0.1689 - val_mad: 0.0065 - val_mean_absolute_error: 0.4109 - val_rmse: 0.4110 - learning_rate: 3.1250e-06

# %%
# Evaluate the model on the test data
evaluation = model.evaluate(features_test, labels_test)

# Print the evaluation results with four decimal places
print(f"Evaluation Loss (MSE): {evaluation[0]:.5f}")
print(f"Evaluation MAE: {evaluation[1]:.5f}")
print(f"Evaluation RMSE: {evaluation[2]:.5f}")
print(f"Evaluation MAD: {evaluation[3]:.5f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - loss: 0.1531 - mad: 0.0041 - mean_absolute_error: 0.3913 - rmse: 0.3913
# Evaluation Loss (MSE): 0.15312
# Evaluation MAE: 0.39128
# Evaluation RMSE: 0.39131
# Evaluation MAD: 0.00408

# %%
# Plot the Train loss and validation loss
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss and validation loss')
plt.xlabel('Epoch')
plt.ylabel('Metric Value')
plt.legend()
plt.show()

# %%
# Plot the train rmse and validation rmse
plt.figure(figsize=(12, 6))
plt.plot(history.history['rmse'], label='Train RMSE')
plt.plot(history.history['val_rmse'], label='Validation RMSE')
plt.title('Train RMSE Vs Validation RMSE')
plt.xlabel('Epoch')
plt.ylabel('Metric Value')
plt.legend()
plt.show()

# %%
# Plot the tain MAD and validation MAD
plt.figure(figsize=(12, 6))
plt.plot(history.history['mad'], label='Train MAD')
plt.plot(history.history['val_mad'], label='Validation MAD')
plt.title('Train MAD Vs Validation MAD')
plt.xlabel('Epoch')
plt.ylabel('Metric Value')
plt.legend()
plt.show()

# %%
model.save('CNN3d(E06).h5')

# %%
import os
import cv2
import numpy as np

# Function to save all split videos from the test set to a folder
def save_all_split_videos(video_data, save_dir, SEQUENCE_LENGTH=30, IMAGE_HEIGHT=128, IMAGE_WIDTH=128, fps=30):
    """
    Save all split videos from the video data as individual video files in the specified directory.

    Args:
        video_data: Numpy array containing video data of shape (num_videos, SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3).
        save_dir: Directory to save the videos.
        SEQUENCE_LENGTH: Number of frames per video (default is 16).
        IMAGE_HEIGHT: Height of the frames (default is 64).
        IMAGE_WIDTH: Width of the frames (default is 64).
        fps: Frames per second for the output videos (default is 30).
    """
    # Create the save directory if it doesn't exist
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    # Iterate over all videos in the dataset
    for video_index in range(video_data.shape[0]):
        video_frames = video_data[video_index]  # Shape: (SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3)

        # Prepare the VideoWriter object to save the video
        video_filename = os.path.join(save_dir, f"split_video_{video_index + 1}.mp4")
        fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Use 'mp4v' for .mp4 format
        video_writer = cv2.VideoWriter(video_filename, fourcc, fps, (IMAGE_WIDTH, IMAGE_HEIGHT))

        # Add frames to the video
        for frame in video_frames:
            # Ensure the frame has values in the range [0, 255] and convert to uint8
            frame_rgb = (frame * 255).astype(np.uint8)
            # Convert RGB to BGR for OpenCV
            frame_bgr = cv2.cvtColor(frame_rgb, cv2.COLOR_RGB2BGR)
            # Write the frame to the video
            video_writer.write(frame_bgr)

        # Release the video writer
        video_writer.release()
        print(f"Video {video_index + 1} saved to: {video_filename}")

# Example usage: Save all split videos from the test set
# Make sure `features_test` is defined before calling this function
save_all_split_videos(features_test, save_dir="/kaggle/working/split_videos")
# Out:
# Video 1 saved to: /kaggle/working/split_videos/split_video_1.mp4
# Video 2 saved to: /kaggle/working/split_videos/split_video_2.mp4
# Video 3 saved to: /kaggle/working/split_videos/split_video_3.mp4
# Video 4 saved to: /kaggle/working/split_videos/split_video_4.mp4
# Video 5 saved to: /kaggle/working/split_videos/split_video_5.mp4
# Video 6 saved to: /kaggle/working/split_videos/split_video_6.mp4
# Video 7 saved to: /kaggle/working/split_videos/split_video_7.mp4
# Video 8 saved to: /kaggle/working/split_videos/split_video_8.mp4
# Video 9 saved to: /kaggle/working/split_videos/split_video_9.mp4
# Video 10 saved to: /kaggle/working/split_videos/split_video_10.mp4
# Video 11 saved to: /kaggle/working/split_videos/split_video_11.mp4
# Video 12 saved to: /kaggle/working/split_videos/split_video_12.mp4
# Video 13 saved to: /kaggle/working/split_videos/split_video_13.mp4
# Video 14 saved to: /kaggle/working/split_videos/split_video_14.mp4
# Video 15 saved to: /kaggle/working/split_videos/split_video_15.mp4
# Video 16 saved to: /kaggle/working/split_videos/split_video_16.mp4

# %%
# Example prediction for a new video
video_path = '/kaggle/working/split_videos/split_video_12.mp4'

# Assuming `process_video` function is implemented, use it to preprocess the video input
def process_video(video_path):
    # Example: Preprocessing video to match the input shape of (SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3)
    # You should implement this based on your dataset and requirements
    video_data = np.random.random((SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3))  # Replace with real video processing code
    return np.expand_dims(video_data, axis=0)  # Expand dims to add batch dimension

# Predict for a new video
predicted_score = model.predict(process_video(video_path))
scaled_score = predicted_score * 99 + 1
print(f"Predicted Score: {scaled_score[0][0]:.2f}")  # Assuming `predicted_score` is a 2D array
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step
# Predicted Score: 47.93
