# %%
import os
import shutil
import cv2
import math
import random
import numpy as np
import tensorflow as tf
from tensorflow import keras
from collections import deque
import matplotlib.pyplot as plt
plt.style.use("seaborn")
import tqdm
# %matplotlib inline
from tensorflow.keras import Model
from sklearn.model_selection import train_test_split
from keras.applications.mobilenet_v2 import MobileNetV2
from keras.layers import *
from keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.utils import plot_model

from IPython.display import HTML
from base64 import b64encode
from tensorflow.keras.layers import Input,Dense, Flatten, ReLU, Conv2D, DepthwiseConv2D,AvgPool2D, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.optimizers import Adam
import keras.backend as K
from typing import Optional
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings('ignore')

# %%
IMAGE_HEIGHT, IMAGE_WIDTH = 128, 128
SEQUENCE_LENGTH = 30

# %%
CLASSES_LIST = ["E07(Hip_Joint_Flexion)"]

# %%
def frames_extraction(video_path):
    frames_list = []
    video_reader = cv2.VideoCapture(video_path)
    video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))
    skip_frames_window = max(int(video_frames_count/SEQUENCE_LENGTH), 1)

    for frame_counter in range(SEQUENCE_LENGTH):
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)
        success, frame = video_reader.read()

        if not success:
            break

        resized_frame = cv2.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))
        normalized_frame = resized_frame / 255
        frames_list.append(normalized_frame)

    video_reader.release()
    return frames_list

# %%
def create_dataset(video_dir, csv_file_path):
    features = []
    labels = []
    video_files_paths = []
    matching_files_count = 0

    # Read the CSV file
    csv_data = pd.read_csv(csv_file_path)

    for class_index, class_name in enumerate(CLASSES_LIST):
        print(f'Extracting Data of Class: {class_name}')
        files_list = os.listdir(os.path.join(video_dir, class_name))

        for file_name in files_list:
            # Remove the .mp4 extension from the file name
            video_name = os.path.splitext(file_name)[0]

            video_file_path = os.path.join(video_dir, class_name, file_name)
            frames = frames_extraction(video_file_path)

            if len(frames) == SEQUENCE_LENGTH:
                # Search for the exercise name in the CSV data that matches with video file name
                matching_row = csv_data[csv_data['Excercise Name'].str.lower() == video_name.lower()]

                if not matching_row.empty:
                    assessment_score = matching_row['Assessment Score'].values[0]
                    features.append(frames)
                    labels.append(class_index)
                    video_files_paths.append(video_file_path)
                    matching_files_count += 1
                    print(f'Matched file: {video_name}, Assessment Score: {assessment_score}')
                else:
                    # Append None if no matching row is found
                    features.append(frames)
                    labels.append(class_index)
                    video_files_paths.append(video_file_path)
                    print(f'No matching row found for file: {video_name}')

    features = np.asarray(features)
    labels = np.asarray(labels)

    print(f'Total matching files: {matching_files_count}')

    return features, labels, matching_files_count, video_files_paths

# %%
import pandas as pd

video_dir = '/kaggle/input/regression-folders/dataset_regression'
csv_file_path = '/kaggle/input/csv-files-regression/Ex_07_sub.csv'
features, labels, matching_files_count, video_files_paths =  create_dataset(video_dir, csv_file_path)
print("Features shape:", features.shape)
print("Labels shape:", labels.shape)
print("Matching files count:", matching_files_count)
print("Number of video files:", len(video_files_paths))
# Out:
# Extracting Data of Class: E07(Hip_Joint_Flexion)
# Matched file: E07_P02_AR_VO_GM, Assessment Score: 70.0
# Matched file: E07_P07_AF_VLL_GM, Assessment Score: 60.48
# Matched file: E07_P23_AR_VML_GM, Assessment Score: 95.24
# Matched file: E07_P08_AR_VLL_GM, Assessment Score: 45.71
# Matched file: E07_P22_AR_VFL_GM, Assessment Score: 63.33
# Matched file: E07_P07_AF_VHJ_GM, Assessment Score: 78.57
# Matched file: E07_P04_AL_VHJ_GM, Assessment Score: 72.38
# Matched file: E07_P22_AR_VML_GM, Assessment Score: 60.0
# Matched file: E07_P02_AL_VLL_GM, Assessment Score: 83.33
# Matched file: E07_P21_AL_VLJ_GM, Assessment Score: 58.57
# Matched file: E07_P22_AR_VHJ_GM, Assessment Score: 61.43
# Matched file: E07_P23_AR_VO_GM, Assessment Score: 85.71
# Matched file: E07_P18_AL_VML_GM, Assessment Score: 85.71
# Matched file: E07_P02_AR_VLJ_GM, Assessment Score: 97.62
# Matched file: E07_P07_AR_VO_GM, Assessment Score: 84.29
# Matched file: E07_P17_AL_VML_GM, Assessment Score: 65.71
# Matched file: E07_P19_AF_VLL_GM, Assessment Score: 78.57
# Matched file: E07_P06_AL_VML_GM, Assessment Score: 76.19
# Matched file: E07_P19_AF_VFL_GM, Assessment Score: 100.0
# Matched file: E07_P04_AF_VHJ_GM, Assessment Score: 72.38
# Matched file: E07_P23_AF_VHJ_GM, Assessment Score: 92.86
# Matched file: E07_P02_AF_VFL_GM, Assessment Score: 80.95
# Matched file: E07_P19_AR_VLL_GM, Assessment Score: 78.57
# Matched file: E07_P08_AF_VLL_GM, Assessment Score: 44.29
# Matched file: E07_P18_AR_VML_GM, Assessment Score: 85.71
# Matched file: E07_P02_AL_VO_GM, Assessment Score: 70.0
# Matched file: E07_P02_AR_VHJ_GM, Assessment Score: 65.24
# Matched file: E07_P21_AF_VHJ_GM, Assessment Score: 67.14
# Matched file: E07_P04_AR_VML_GM, Assessment Score: 88.1
# Matched file: E07_P07_AF_VO_GM, Assessment Score: 84.29
# Matched file: E07_P18_AR_VO_GM, Assessment Score: 90.48
# Matched file: E07_P08_AL_VLL_GM, Assessment Score: 45.71
# Matched file: E07_P02_AR_VLL_GM, Assessment Score: 83.33
# Matched file: E07_P07_AL_VFL_GM, Assessment Score: 75.71
# Matched file: E07_P08_AF_VHJ_GM, Assessment Score: 71.43
# Matched file: E07_P04_AF_VLJ_GM, Assessment Score: 88.1
# Matched file: E07_P22_AF_VLL_GM, Assessment Score: 67.14
# Matched file: E07_P07_AL_VO_GM, Assessment Score: 84.29
# Matched file: E07_P22_AF_VFL_GM, Assessment Score: 66.19
# Matched file: E07_P23_AL_VO_GM, Assessment Score: 70.0
# Matched file: E07_P02_AL_VLJ_GM, Assessment Score: 97.62
# Matched file: E07_P06_AR_VLL_GM, Assessment Score: 61.43
# Matched file: E07_P23_AF_VML_GM, Assessment Score: 95.24
# Matched file: E07_P05_AF_VHJ_GM, Assessment Score: 77.14
# Matched file: E07_P04_AF_VFL_GM, Assessment Score: 88.1
# Matched file: E07_P03_AF_VFL_GM, Assessment Score: 100.0
# Matched file: E07_P06_AL_VLL_GM, Assessment Score: 60.0
# Matched file: E07_P07_AR_VLJ_GM, Assessment Score: 76.19
# Matched file: E07_P22_AF_VLJ_GM, Assessment Score: 68.57
# Matched file: E07_P02_AR_VFL_GM, Assessment Score: 80.95
# Matched file: E07_P22_AL_VLJ_GM, Assessment Score: 68.57
# Matched file: E07_P23_AL_VML_GM, Assessment Score: 95.24
# Matched file: E07_P22_AF_VO_GM, Assessment Score: 64.29
# Matched file: E07_P17_AF_VML_GM, Assessment Score: 68.57
# Matched file: E07_P22_AL_VHJ_GM, Assessment Score: 67.14
# Matched file: E07_P07_AF_VFL_GM, Assessment Score: 75.71
# Matched file: E07_P05_AL_VHJ_GM, Assessment Score: 77.14
# Matched file: E07_P07_AR_VLL_GM, Assessment Score: 76.19
# Matched file: E07_P04_AR_VLL_GM, Assessment Score: 88.1
# Matched file: E07_P08_AR_VML_GM, Assessment Score: 44.76
# Matched file: E07_P02_AL_VFL_GM, Assessment Score: 80.95
# Matched file: E07_P19_AL_VLL_GM, Assessment Score: 78.57
# Matched file: E07_P02_AF_VLJ_GM, Assessment Score: 97.62
# Matched file: E07_P23_AL_VHJ_GM, Assessment Score: 92.86
# Matched file: E07_P08_AL_VHJ_GM, Assessment Score: 71.43
# Matched file: E07_P17_AR_VHJ_GM, Assessment Score: 75.71
# Matched file: E07_P06_AF_VLL_GM, Assessment Score: 60.0
# Matched file: E07_P04_AR_VHJ_GM, Assessment Score: 72.38
# Matched file: E07_P23_AR_VHJ_GM, Assessment Score: 92.86
# Matched file: E07_P17_AF_VLL_GM, Assessment Score: 92.86
# Matched file: E07_P07_AF_VML_GM, Assessment Score: 90.48
# Matched file: E07_P23_AR_VLJ_GM, Assessment Score: 100.0
# Matched file: E07_P19_AL_VO_GM, Assessment Score: 65.24
# Matched file: E07_P08_AF_VLJ_GM, Assessment Score: 44.29
# Matched file: E07_P18_AF_VML_GM, Assessment Score: 85.71
# Matched file: E07_P22_AR_VLL_GM, Assessment Score: 62.86
# Matched file: E07_P21_AL_VO_GM, Assessment Score: 61.43
# Matched file: E07_P22_AL_VML_GM, Assessment Score: 62.86
# Matched file: E07_P07_AL_VML_GM, Assessment Score: 90.48
# Matched file: E07_P21_AR_VLJ_GM, Assessment Score: 58.57
# Total matching files: 80
# Features shape: (80, 30, 128, 128, 3)
# Labels shape: (80,)
# Matching files count: 80
# Number of video files: 80

# %%
np.save("features.npy", features)
np.save("labels.npy", labels)
np.save("video_files_paths.npy", video_files_paths)

# %%
features, labels, video_files_paths = np.load("features.npy"), np.load("labels.npy"), np.load("video_files_paths.npy")

# %%
print(f'Number of features: {len(features)}, Number of labels: {len(labels)}, Number of video_files_paths: {len(video_files_paths)}')
# Out:
# Number of features: 80, Number of labels: 80, Number of video_files_paths: 80

# %%
features_train, features_test, labels_train, labels_test = train_test_split(
    features, labels, test_size=0.20, shuffle=True, random_state=42
)

print(f"Training features: {features_train.shape}, Training labels: {labels_train.shape}")
print(f"Testing features: {features_test.shape}, Testing labels: {labels_test.shape}")
# Out:
# Training features: (64, 30, 128, 128, 3), Training labels: (64,)
# Testing features: (16, 30, 128, 128, 3), Testing labels: (16,)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler, ModelCheckpoint
import matplotlib.pyplot as plt
import numpy as np

# Define custom metrics: RMSE and MAD
def rmse(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)  # Ensure y_true is float32
    return tf.sqrt(tf.reduce_mean(tf.square(y_pred - y_true)))

def mad(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)  # Ensure y_true is float32
    return tf.reduce_mean(tf.abs(y_pred - tf.reduce_mean(y_pred)))

# Define the 3D CNN model
def create_3d_cnn_model(SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH):
    """
    A 3D CNN model for spatiotemporal feature extraction and regression.
    """
    # Define the video input (4D input for 3D CNN)
    video_input = layers.Input(shape=(SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3))
    
    # 3D CNN layers for spatiotemporal feature extraction
    x = layers.Conv3D(32, (3, 3, 3), padding='same', activation='relu')(video_input)
    x = layers.MaxPooling3D((2, 2, 2))(x)
    x = layers.Dropout(0.4)(x)
    x = layers.BatchNormalization()(x)
    
    x = layers.Conv3D(64, (3, 3, 3), padding='same', activation='relu')(x)
    x = layers.MaxPooling3D((2, 2, 2))(x)
    x = layers.Dropout(0.4)(x)
    x = layers.BatchNormalization()(x)
    
    x = layers.Conv3D(128, (3, 3, 3), padding='same', activation='relu')(x)
    x = layers.MaxPooling3D((2, 2, 2))(x)
    x = layers.Dropout(0.4)(x)
    x = layers.BatchNormalization()(x)

    # Flatten the output of the 3D CNN
    x = layers.GlobalAveragePooling3D()(x)

    # Dense layer for regression output
    regression_output = layers.Dense(1, activation='sigmoid', name='regression_output')(x)
    
    # Build the model
    model = models.Model(inputs=video_input, outputs=[regression_output])
    model.summary()
    
    return model

# %%
# Define hyperparameters
SEQUENCE_LENGTH = 30  # Set according to your input data
IMAGE_HEIGHT = 128  # Set the height of your input images
IMAGE_WIDTH = 128  # Set the width of your input images

# Create the model
model = create_3d_cnn_model(SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 30, 128, 128,   │             0 │
# │                                 │ 3)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d (Conv3D)                 │ (None, 30, 128, 128,   │         2,624 │
# │                                 │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d (MaxPooling3D)    │ (None, 15, 64, 64, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 15, 64, 64, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 15, 64, 64, 32) │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_1 (Conv3D)               │ (None, 15, 64, 64, 64) │        55,360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_1 (MaxPooling3D)  │ (None, 7, 32, 32, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 7, 32, 32, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 7, 32, 32, 64)  │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_2 (Conv3D)               │ (None, 7, 32, 32, 128) │       221,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_2 (MaxPooling3D)  │ (None, 3, 16, 16, 128) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 3, 16, 16, 128) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 3, 16, 16, 128) │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling3d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling3D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ regression_output (Dense)       │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 280,321 (1.07 MB)
#  Trainable params: 279,873 (1.07 MB)
#  Non-trainable params: 448 (1.75 KB)

# %%
# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='mean_squared_error',  # Use MSE for regression
              metrics=['mean_absolute_error', rmse, mad])

# Define Early Stopping and Learning Rate Scheduler callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

lr_scheduler = LearningRateScheduler(lambda epoch, lr: lr * 0.5 if epoch % 10 == 0 and epoch > 0 else lr, verbose=1)



# Callbacks list
callbacks = [early_stopping, lr_scheduler]
# Train the model
history = model.fit(features_train, labels_train,
                    validation_data=(features_test, labels_test),
                    epochs=60, batch_size=8, verbose=1, 
                    callbacks=callbacks)
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 1/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 145s 18s/step - loss: 0.2059 - mad: 0.0351 - mean_absolute_error: 0.4511 - rmse: 0.4538 - val_loss: 0.0598 - val_mad: 0.0075 - val_mean_absolute_error: 0.2443 - val_rmse: 0.2446 - learning_rate: 1.0000e-04
#
# Epoch 2: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 2/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 142s 18s/step - loss: 0.2011 - mad: 0.0230 - mean_absolute_error: 0.4475 - rmse: 0.4485 - val_loss: 0.1346 - val_mad: 0.0074 - val_mean_absolute_error: 0.3668 - val_rmse: 0.3669 - learning_rate: 1.0000e-04
#
# Epoch 3: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 3/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 137s 17s/step - loss: 0.1973 - mad: 0.0127 - mean_absolute_error: 0.4439 - rmse: 0.4442 - val_loss: 0.1216 - val_mad: 0.0058 - val_mean_absolute_error: 0.3486 - val_rmse: 0.3487 - learning_rate: 1.0000e-04
#
# Epoch 4: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 4/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 144s 18s/step - loss: 0.1943 - mad: 0.0135 - mean_absolute_error: 0.4405 - rmse: 0.4408 - val_loss: 0.1264 - val_mad: 0.0068 - val_mean_absolute_error: 0.3554 - val_rmse: 0.3556 - learning_rate: 1.0000e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 5/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 137s 17s/step - loss: 0.1912 - mad: 0.0104 - mean_absolute_error: 0.4370 - rmse: 0.4372 - val_loss: 0.1113 - val_mad: 0.0069 - val_mean_absolute_error: 0.3334 - val_rmse: 0.3336 - learning_rate: 1.0000e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 6/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 136s 17s/step - loss: 0.1880 - mad: 0.0097 - mean_absolute_error: 0.4335 - rmse: 0.4336 - val_loss: 0.1057 - val_mad: 0.0076 - val_mean_absolute_error: 0.3250 - val_rmse: 0.3252 - learning_rate: 1.0000e-04
#
# Epoch 7: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 7/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 138s 17s/step - loss: 0.1850 - mad: 0.0105 - mean_absolute_error: 0.4299 - rmse: 0.4301 - val_loss: 0.1237 - val_mad: 0.0064 - val_mean_absolute_error: 0.3516 - val_rmse: 0.3517 - learning_rate: 1.0000e-04
#
# Epoch 8: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 8/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 139s 17s/step - loss: 0.1819 - mad: 0.0110 - mean_absolute_error: 0.4263 - rmse: 0.4265 - val_loss: 0.1446 - val_mad: 0.0067 - val_mean_absolute_error: 0.3802 - val_rmse: 0.3803 - learning_rate: 1.0000e-04
#
# Epoch 9: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 9/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 137s 17s/step - loss: 0.1789 - mad: 0.0116 - mean_absolute_error: 0.4227 - rmse: 0.4229 - val_loss: 0.1224 - val_mad: 0.0085 - val_mean_absolute_error: 0.3497 - val_rmse: 0.3499 - learning_rate: 1.0000e-04
#
# Epoch 10: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 10/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 137s 17s/step - loss: 0.1757 - mad: 0.0096 - mean_absolute_error: 0.4190 - rmse: 0.4191 - val_loss: 0.1003 - val_mad: 0.0086 - val_mean_absolute_error: 0.3164 - val_rmse: 0.3166 - learning_rate: 1.0000e-04
#
# Epoch 11: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 11/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 138s 17s/step - loss: 0.1731 - mad: 0.0128 - mean_absolute_error: 0.4157 - rmse: 0.4160 - val_loss: 0.1495 - val_mad: 0.0069 - val_mean_absolute_error: 0.3866 - val_rmse: 0.3867 - learning_rate: 5.0000e-05
#
# Epoch 12: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 12/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 141s 18s/step - loss: 0.1714 - mad: 0.0089 - mean_absolute_error: 0.4138 - rmse: 0.4140 - val_loss: 0.1312 - val_mad: 0.0060 - val_mean_absolute_error: 0.3622 - val_rmse: 0.3623 - learning_rate: 5.0000e-05
#
# Epoch 13: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 13/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 143s 18s/step - loss: 0.1699 - mad: 0.0093 - mean_absolute_error: 0.4120 - rmse: 0.4121 - val_loss: 0.1277 - val_mad: 0.0076 - val_mean_absolute_error: 0.3572 - val_rmse: 0.3574 - learning_rate: 5.0000e-05
#
# Epoch 14: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 14/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 143s 18s/step - loss: 0.1684 - mad: 0.0105 - mean_absolute_error: 0.4101 - rmse: 0.4103 - val_loss: 0.1133 - val_mad: 0.0075 - val_mean_absolute_error: 0.3364 - val_rmse: 0.3366 - learning_rate: 5.0000e-05
#
# Epoch 15: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 15/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 142s 18s/step - loss: 0.1669 - mad: 0.0113 - mean_absolute_error: 0.4082 - rmse: 0.4085 - val_loss: 0.1172 - val_mad: 0.0085 - val_mean_absolute_error: 0.3421 - val_rmse: 0.3423 - learning_rate: 5.0000e-05
#
# Epoch 16: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 16/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 136s 17s/step - loss: 0.1653 - mad: 0.0125 - mean_absolute_error: 0.4063 - rmse: 0.4066 - val_loss: 0.1119 - val_mad: 0.0076 - val_mean_absolute_error: 0.3343 - val_rmse: 0.3345 - learning_rate: 5.0000e-05
#
# Epoch 17: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 17/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 144s 18s/step - loss: 0.1638 - mad: 0.0118 - mean_absolute_error: 0.4044 - rmse: 0.4047 - val_loss: 0.1045 - val_mad: 0.0088 - val_mean_absolute_error: 0.3230 - val_rmse: 0.3233 - learning_rate: 5.0000e-05
#
# Epoch 18: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 18/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 142s 18s/step - loss: 0.1622 - mad: 0.0116 - mean_absolute_error: 0.4025 - rmse: 0.4028 - val_loss: 0.0935 - val_mad: 0.0075 - val_mean_absolute_error: 0.3055 - val_rmse: 0.3057 - learning_rate: 5.0000e-05
#
# Epoch 19: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 19/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 136s 17s/step - loss: 0.1607 - mad: 0.0123 - mean_absolute_error: 0.4006 - rmse: 0.4009 - val_loss: 0.1218 - val_mad: 0.0074 - val_mean_absolute_error: 0.3489 - val_rmse: 0.3491 - learning_rate: 5.0000e-05
#
# Epoch 20: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 20/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 138s 17s/step - loss: 0.1591 - mad: 0.0113 - mean_absolute_error: 0.3987 - rmse: 0.3989 - val_loss: 0.1013 - val_mad: 0.0095 - val_mean_absolute_error: 0.3180 - val_rmse: 0.3183 - learning_rate: 5.0000e-05
#
# Epoch 21: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 21/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 137s 17s/step - loss: 0.1577 - mad: 0.0094 - mean_absolute_error: 0.3969 - rmse: 0.3971 - val_loss: 0.0845 - val_mad: 0.0098 - val_mean_absolute_error: 0.2903 - val_rmse: 0.2906 - learning_rate: 2.5000e-05

# %%
# Evaluate the model on the test data
evaluation = model.evaluate(features_test, labels_test)

# Print the evaluation results with four decimal places
print(f"Evaluation Loss (MSE): {evaluation[0]:.5f}")
print(f"Evaluation MAE: {evaluation[1]:.5f}")
print(f"Evaluation RMSE: {evaluation[2]:.5f}")
print(f"Evaluation MAD: {evaluation[3]:.5f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - loss: 0.0598 - mad: 0.0078 - mean_absolute_error: 0.2443 - rmse: 0.2446
# Evaluation Loss (MSE): 0.05982
# Evaluation MAE: 0.24435
# Evaluation RMSE: 0.24458
# Evaluation MAD: 0.00776

# %%
# Plot the Train loss and validation loss
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss and validation loss')
plt.xlabel('Epoch')
plt.ylabel('Metric Value')
plt.legend()
plt.show()

# %%
# Plot the train rmse and validation rmse
plt.figure(figsize=(12, 6))
plt.plot(history.history['rmse'], label='Train RMSE')
plt.plot(history.history['val_rmse'], label='Validation RMSE')
plt.title('Train RMSE Vs Validation RMSE')
plt.xlabel('Epoch')
plt.ylabel('Metric Value')
plt.legend()
plt.show()

# %%
# Plot the tain MAD and validation MAD
plt.figure(figsize=(12, 6))
plt.plot(history.history['mad'], label='Train MAD')
plt.plot(history.history['val_mad'], label='Validation MAD')
plt.title('Train MAD Vs Validation MAD')
plt.xlabel('Epoch')
plt.ylabel('Metric Value')
plt.legend()
plt.show()

# %%
model.save('CNN3d(E07).h5')

# %%
import os
import cv2
import numpy as np

# Function to save all split videos from the test set to a folder
def save_all_split_videos(video_data, save_dir, SEQUENCE_LENGTH=30, IMAGE_HEIGHT=128, IMAGE_WIDTH=128, fps=30):
    """
    Save all split videos from the video data as individual video files in the specified directory.

    Args:
        video_data: Numpy array containing video data of shape (num_videos, SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3).
        save_dir: Directory to save the videos.
        SEQUENCE_LENGTH: Number of frames per video (default is 16).
        IMAGE_HEIGHT: Height of the frames (default is 64).
        IMAGE_WIDTH: Width of the frames (default is 64).
        fps: Frames per second for the output videos (default is 30).
    """
    # Create the save directory if it doesn't exist
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    # Iterate over all videos in the dataset
    for video_index in range(video_data.shape[0]):
        video_frames = video_data[video_index]  # Shape: (SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3)

        # Prepare the VideoWriter object to save the video
        video_filename = os.path.join(save_dir, f"split_video_{video_index + 1}.mp4")
        fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Use 'mp4v' for .mp4 format
        video_writer = cv2.VideoWriter(video_filename, fourcc, fps, (IMAGE_WIDTH, IMAGE_HEIGHT))

        # Add frames to the video
        for frame in video_frames:
            # Ensure the frame has values in the range [0, 255] and convert to uint8
            frame_rgb = (frame * 255).astype(np.uint8)
            # Convert RGB to BGR for OpenCV
            frame_bgr = cv2.cvtColor(frame_rgb, cv2.COLOR_RGB2BGR)
            # Write the frame to the video
            video_writer.write(frame_bgr)

        # Release the video writer
        video_writer.release()
        print(f"Video {video_index + 1} saved to: {video_filename}")

# Example usage: Save all split videos from the test set
# Make sure `features_test` is defined before calling this function
save_all_split_videos(features_test, save_dir="/kaggle/working/split_videos")
# Out:
# Video 1 saved to: /kaggle/working/split_videos/split_video_1.mp4
# Video 2 saved to: /kaggle/working/split_videos/split_video_2.mp4
# Video 3 saved to: /kaggle/working/split_videos/split_video_3.mp4
# Video 4 saved to: /kaggle/working/split_videos/split_video_4.mp4
# Video 5 saved to: /kaggle/working/split_videos/split_video_5.mp4
# Video 6 saved to: /kaggle/working/split_videos/split_video_6.mp4
# Video 7 saved to: /kaggle/working/split_videos/split_video_7.mp4
# Video 8 saved to: /kaggle/working/split_videos/split_video_8.mp4
# Video 9 saved to: /kaggle/working/split_videos/split_video_9.mp4
# Video 10 saved to: /kaggle/working/split_videos/split_video_10.mp4
# Video 11 saved to: /kaggle/working/split_videos/split_video_11.mp4
# Video 12 saved to: /kaggle/working/split_videos/split_video_12.mp4
# Video 13 saved to: /kaggle/working/split_videos/split_video_13.mp4
# Video 14 saved to: /kaggle/working/split_videos/split_video_14.mp4
# Video 15 saved to: /kaggle/working/split_videos/split_video_15.mp4
# Video 16 saved to: /kaggle/working/split_videos/split_video_16.mp4

# %%
# Example prediction for a new video
video_path = '/kaggle/working/split_videos/split_video_11.mp4'

# Assuming `process_video` function is implemented, use it to preprocess the video input
def process_video(video_path):
    # Example: Preprocessing video to match the input shape of (SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3)
    # You should implement this based on your dataset and requirements
    video_data = np.random.random((SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3))  # Replace with real video processing code
    return np.expand_dims(video_data, axis=0)  # Expand dims to add batch dimension

# Predict for a new video
predicted_score = model.predict(process_video(video_path))
scaled_score = predicted_score * 99 + 1
print(f"Predicted Score: {scaled_score[0][0]:.2f}")  # Assuming `predicted_score` is a 2D array
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step
# Predicted Score: 24.76
