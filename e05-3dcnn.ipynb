# %%
import os
import shutil
import cv2
import math
import random
import numpy as np
import tensorflow as tf
from tensorflow import keras
from collections import deque
import matplotlib.pyplot as plt
plt.style.use("seaborn")
import tqdm
# %matplotlib inline
from tensorflow.keras import Model
from sklearn.model_selection import train_test_split
from keras.applications.mobilenet_v2 import MobileNetV2
from keras.layers import *
from keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.utils import plot_model

from IPython.display import HTML
from base64 import b64encode
from tensorflow.keras.layers import Input,Dense, Flatten, ReLU, Conv2D, DepthwiseConv2D,AvgPool2D, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.optimizers import Adam
import keras.backend as K
from typing import Optional
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings('ignore')

# %%
IMAGE_HEIGHT, IMAGE_WIDTH = 128, 128
SEQUENCE_LENGTH = 30

# %%
CLASSES_LIST = ["E05(Circumduction)"]

# %%
def frames_extraction(video_path):
    frames_list = []
    video_reader = cv2.VideoCapture(video_path)
    video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))
    skip_frames_window = max(int(video_frames_count/SEQUENCE_LENGTH), 1)

    for frame_counter in range(SEQUENCE_LENGTH):
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)
        success, frame = video_reader.read()

        if not success:
            break

        resized_frame = cv2.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))
        normalized_frame = resized_frame / 255
        frames_list.append(normalized_frame)

    video_reader.release()
    return frames_list

# %%
def create_dataset(video_dir, csv_file_path):
    features = []
    labels = []
    video_files_paths = []
    matching_files_count = 0

    # Read the CSV file
    csv_data = pd.read_csv(csv_file_path)

    for class_index, class_name in enumerate(CLASSES_LIST):
        print(f'Extracting Data of Class: {class_name}')
        files_list = os.listdir(os.path.join(video_dir, class_name))

        for file_name in files_list:
            # Remove the .mp4 extension from the file name
            video_name = os.path.splitext(file_name)[0]

            video_file_path = os.path.join(video_dir, class_name, file_name)
            frames = frames_extraction(video_file_path)

            if len(frames) == SEQUENCE_LENGTH:
                # Search for the exercise name in the CSV data that matches with video file name
                matching_row = csv_data[csv_data['Excercise Name'].str.lower() == video_name.lower()]

                if not matching_row.empty:
                    assessment_score = matching_row['Assessment Score'].values[0]
                    features.append(frames)
                    labels.append(class_index)
                    video_files_paths.append(video_file_path)
                    matching_files_count += 1
                    print(f'Matched file: {video_name}, Assessment Score: {assessment_score}')
                else:
                    # Append None if no matching row is found
                    features.append(frames)
                    labels.append(class_index)
                    video_files_paths.append(video_file_path)
                    print(f'No matching row found for file: {video_name}')

    features = np.asarray(features)
    labels = np.asarray(labels)

    print(f'Total matching files: {matching_files_count}')

    return features, labels, matching_files_count, video_files_paths

# %%
import pandas as pd

video_dir = '/kaggle/input/regression-folders/dataset_regression'
csv_file_path = '/kaggle/input/csv-files-regression/Ex_05_sub.csv'
features, labels, matching_files_count, video_files_paths =  create_dataset(video_dir, csv_file_path)
print("Features shape:", features.shape)
print("Labels shape:", labels.shape)
print("Matching files count:", matching_files_count)
print("Number of video files:", len(video_files_paths))
# Out:
# Extracting Data of Class: E05(Circumduction)
# Matched file: E05_P36_AL_VFL_GM, Assessment Score: 53.81
# Matched file: E05_P32_AR_VFL_GM, Assessment Score: 19.05
# Matched file: E05_P29_AL_VFL_GM, Assessment Score: 33.33
# Matched file: E05_P31_AF_VML_GM, Assessment Score: 67.14
# Matched file: E05_P21_AF_VLL_GM, Assessment Score: 62.38
# Matched file: E05_P02_AF_VHJ_GM, Assessment Score: 70.48
# Matched file: E05_P12_AL_VML_GF, Assessment Score: 82.86
# Matched file: E05_P13_AR_VML_GF, Assessment Score: 78.1
# Matched file: E05_P01_AR_VFL_GM, Assessment Score: 75.71
# Matched file: E05_P31_AF_VLR_GM, Assessment Score: 67.14
# Matched file: E05_P01_AF_VHJ_GM, Assessment Score: 84.29
# Matched file: E05_P22_AF_VHJ_GM, Assessment Score: 76.67
# Matched file: E05_P07_AR_VHJ_GM, Assessment Score: 60.0
# Matched file: E05_P34_AF_VHJ_GF, Assessment Score: 16.67
# Matched file: E05_P36_AF_VML_GM, Assessment Score: 50.0
# Matched file: E05_P01_AF_VFL_GM, Assessment Score: 78.57
# Matched file: E05_P22_AR_VLJ_GM, Assessment Score: 77.62
# Matched file: E05_P01_AF_VO_GM, Assessment Score: 81.43
# Matched file: E05_P14_AF_VML_GF, Assessment Score: 63.33
# Matched file: E05_P02_AF_VLL_GM, Assessment Score: 74.29
# Matched file: E05_P26_AL_VFL_GF, Assessment Score: 51.43
# Matched file: E05_P36_AF_VHJ_GM, Assessment Score: 47.62
# Matched file: E05_P21_AL_VO_GM, Assessment Score: 63.81
# Matched file: E05_P21_AF_VO_GM, Assessment Score: 65.24
# Matched file: E05_P13_AF_VLL_GF, Assessment Score: 92.86
# Matched file: E05_P07_AL_VHJ_GM, Assessment Score: 57.14
# Matched file: E05_P16_AL_VLL_GF, Assessment Score: 74.76
# Matched file: E05_P32_AF_VFL_GM, Assessment Score: 45.24
# Matched file: E05_P14_AF_VFL_GF, Assessment Score: 63.33
# Matched file: E05_P23_AL_VO_GM, Assessment Score: 71.9
# Matched file: E05_P23_AF_VLL_GM, Assessment Score: 72.86
# Matched file: E05_P06_AL_VLJ_GM, Assessment Score: 77.62
# Matched file: E05_P07_AF_VML_GM, Assessment Score: 79.52
# Matched file: E05_P18_AL_VML_GM, Assessment Score: 95.24
# Matched file: E05_P35_AF_VLJ_GM, Assessment Score: 38.57
# Matched file: E05_P26_AF_VLJ_GF, Assessment Score: 57.62
# Matched file: E05_P36_AR_VFL_GM, Assessment Score: 53.81
# Matched file: E05_P01_AL_VML_GM, Assessment Score: 80.0
# Matched file: E05_P22_AF_VLJ_GM, Assessment Score: 76.19
# Matched file: E05_P07_AR_VO_GM, Assessment Score: 77.14
# Matched file: E05_P36_AF_VO_GM, Assessment Score: 45.24
# Matched file: E05_P29_AF_VLR_GM, Assessment Score: 30.95
# Matched file: E05_P23_AF_VO_GM, Assessment Score: 70.48
# Matched file: E05_P06_AL_VHJ_GM, Assessment Score: 73.81
# Matched file: E05_P07_AL_VLJ_GM, Assessment Score: 92.86
# Matched file: E05_P35_AF_VML_GM, Assessment Score: 37.14
# Matched file: E05_P35_AF_VFL_GM, Assessment Score: 35.71
# Matched file: E05_P31_AL_VFL_GM, Assessment Score: 65.71
# Matched file: E05_P04_AF_VLJ_GM, Assessment Score: 60.0
# Matched file: E05_P04_AR_VHJ_GM, Assessment Score: 68.1
# Matched file: E05_P21_AF_VML_GM, Assessment Score: 68.1
# Matched file: E05_P14_AF_VLL_GF, Assessment Score: 72.86
# Matched file: E05_P02_AR_VLL_GM, Assessment Score: 78.57
# Matched file: E05_P05_AF_VML_GM, Assessment Score: 100.0
# Matched file: E05_P14_AR_VFL_GF, Assessment Score: 64.76
# Matched file: E05_P04_AR_VLJ_GM, Assessment Score: 61.43
# Matched file: E05_P35_AF_VLR_GM, Assessment Score: 38.57
# Matched file: E05_P11_AR_VO_GF, Assessment Score: 100.0
# Matched file: E05_P02_AF_VO_GM, Assessment Score: 74.29
# Matched file: E05_P21_AR_VFL_GM, Assessment Score: 88.1
# Matched file: E05_P06_AR_VO_GM, Assessment Score: 80.48
# Matched file: E05_P08_AF_VHJ_GM, Assessment Score: 85.71
# Matched file: E05_P06_AF_VLJ_GM, Assessment Score: 73.33
# Matched file: E05_P30_AR_VFL_GF, Assessment Score: 45.71
# Matched file: E05_P12_AF_VLL_GF, Assessment Score: 81.9
# Matched file: E05_P16_AR_VO_GF, Assessment Score: 72.38
# Matched file: E05_P22_AF_VML_GM, Assessment Score: 84.76
# Matched file: E05_P14_AL_VFL_GF, Assessment Score: 64.76
# Matched file: E05_P20_AR_VML_GM, Assessment Score: 90.48
# Matched file: E05_P03_AF_VO_GM, Assessment Score: 97.62
# Matched file: E05_P07_AF_VO_GM, Assessment Score: 71.43
# Matched file: E05_P08_AL_VHJ_GM, Assessment Score: 85.71
# Matched file: E05_P30_AF_VHJ_GF, Assessment Score: 35.71
# Matched file: E05_P32_AL_VFL_GM, Assessment Score: 26.19
# Matched file: E05_P19_AR_VLJ_GM, Assessment Score: 90.48
# Matched file: E05_P32_AF_VLR_GM, Assessment Score: 26.19
# Matched file: E05_P02_AL_VML_GM, Assessment Score: 81.43
# Matched file: E05_P06_AF_VML_GM, Assessment Score: 75.24
# Matched file: E05_P21_AL_VML_GM, Assessment Score: 70.95
# Matched file: E05_P30_AF_VLR_GF, Assessment Score: 44.29
# Total matching files: 80
# Features shape: (80, 30, 128, 128, 3)
# Labels shape: (80,)
# Matching files count: 80
# Number of video files: 80

# %%
np.save("features.npy", features)
np.save("labels.npy", labels)
np.save("video_files_paths.npy", video_files_paths)

# %%
features, labels, video_files_paths = np.load("features.npy"), np.load("labels.npy"), np.load("video_files_paths.npy")

# %%
print(f'Number of features: {len(features)}, Number of labels: {len(labels)}, Number of video_files_paths: {len(video_files_paths)}')
# Out:
# Number of features: 80, Number of labels: 80, Number of video_files_paths: 80

# %%
features_train, features_test, labels_train, labels_test = train_test_split(
    features, labels, test_size=0.20, shuffle=True, random_state=42
)

print(f"Training features: {features_train.shape}, Training labels: {labels_train.shape}")
print(f"Testing features: {features_test.shape}, Testing labels: {labels_test.shape}")
# Out:
# Training features: (64, 30, 128, 128, 3), Training labels: (64,)
# Testing features: (16, 30, 128, 128, 3), Testing labels: (16,)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler, ModelCheckpoint
import matplotlib.pyplot as plt
import numpy as np

# Define custom metrics: RMSE and MAD
def rmse(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)  # Ensure y_true is float32
    return tf.sqrt(tf.reduce_mean(tf.square(y_pred - y_true)))

def mad(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)  # Ensure y_true is float32
    return tf.reduce_mean(tf.abs(y_pred - tf.reduce_mean(y_pred)))

# Define the 3D CNN model
def create_3d_cnn_model(SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH):
    """
    A 3D CNN model for spatiotemporal feature extraction and regression.
    """
    # Define the video input (4D input for 3D CNN)
    video_input = layers.Input(shape=(SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3))
    
    # 3D CNN layers for spatiotemporal feature extraction
    x = layers.Conv3D(32, (3, 3, 3), padding='same', activation='relu')(video_input)
    x = layers.MaxPooling3D((2, 2, 2))(x)
    x = layers.Dropout(0.4)(x)
    x = layers.BatchNormalization()(x)
    
    x = layers.Conv3D(64, (3, 3, 3), padding='same', activation='relu')(x)
    x = layers.MaxPooling3D((2, 2, 2))(x)
    x = layers.Dropout(0.4)(x)
    x = layers.BatchNormalization()(x)
    
    x = layers.Conv3D(128, (3, 3, 3), padding='same', activation='relu')(x)
    x = layers.MaxPooling3D((2, 2, 2))(x)
    x = layers.Dropout(0.4)(x)
    x = layers.BatchNormalization()(x)

    # Flatten the output of the 3D CNN
    x = layers.GlobalAveragePooling3D()(x)

    # Dense layer for regression output
    regression_output = layers.Dense(1, activation='sigmoid', name='regression_output')(x)
    
    # Build the model
    model = models.Model(inputs=video_input, outputs=[regression_output])
    model.summary()
    
    return model

# %%
# Define hyperparameters
SEQUENCE_LENGTH = 30  # Set according to your input data
IMAGE_HEIGHT = 128  # Set the height of your input images
IMAGE_WIDTH = 128  # Set the width of your input images

# Create the model
model = create_3d_cnn_model(SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 30, 128, 128,   │             0 │
# │                                 │ 3)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d (Conv3D)                 │ (None, 30, 128, 128,   │         2,624 │
# │                                 │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d (MaxPooling3D)    │ (None, 15, 64, 64, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 15, 64, 64, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 15, 64, 64, 32) │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_1 (Conv3D)               │ (None, 15, 64, 64, 64) │        55,360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_1 (MaxPooling3D)  │ (None, 7, 32, 32, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 7, 32, 32, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 7, 32, 32, 64)  │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_2 (Conv3D)               │ (None, 7, 32, 32, 128) │       221,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_2 (MaxPooling3D)  │ (None, 3, 16, 16, 128) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 3, 16, 16, 128) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 3, 16, 16, 128) │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling3d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling3D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ regression_output (Dense)       │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 280,321 (1.07 MB)
#  Trainable params: 279,873 (1.07 MB)
#  Non-trainable params: 448 (1.75 KB)

# %%
# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='mean_squared_error',  # Use MSE for regression
              metrics=['mean_absolute_error', rmse, mad])

# Define Early Stopping and Learning Rate Scheduler callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

lr_scheduler = LearningRateScheduler(lambda epoch, lr: lr * 0.5 if epoch % 10 == 0 and epoch > 0 else lr, verbose=1)



# Callbacks list
callbacks = [early_stopping, lr_scheduler]
# Train the model
history = model.fit(features_train, labels_train,
                    validation_data=(features_test, labels_test),
                    epochs=60, batch_size=8, verbose=1, 
                    callbacks=callbacks)
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 1/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 158s 19s/step - loss: 0.2497 - mad: 0.0222 - mean_absolute_error: 0.4989 - rmse: 0.4997 - val_loss: 0.2351 - val_mad: 0.0019 - val_mean_absolute_error: 0.4849 - val_rmse: 0.4849 - learning_rate: 1.0000e-04
#
# Epoch 2: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 2/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 153s 19s/step - loss: 0.2461 - mad: 0.0112 - mean_absolute_error: 0.4958 - rmse: 0.4960 - val_loss: 0.2283 - val_mad: 0.0049 - val_mean_absolute_error: 0.4778 - val_rmse: 0.4778 - learning_rate: 1.0000e-04
#
# Epoch 3: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 3/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 148s 19s/step - loss: 0.2432 - mad: 0.0136 - mean_absolute_error: 0.4928 - rmse: 0.4931 - val_loss: 0.2334 - val_mad: 0.0068 - val_mean_absolute_error: 0.4830 - val_rmse: 0.4831 - learning_rate: 1.0000e-04
#
# Epoch 4: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 4/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 202s 19s/step - loss: 0.2403 - mad: 0.0160 - mean_absolute_error: 0.4897 - rmse: 0.4902 - val_loss: 0.2360 - val_mad: 0.0049 - val_mean_absolute_error: 0.4857 - val_rmse: 0.4857 - learning_rate: 1.0000e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 5/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 154s 20s/step - loss: 0.2370 - mad: 0.0119 - mean_absolute_error: 0.4866 - rmse: 0.4868 - val_loss: 0.2193 - val_mad: 0.0058 - val_mean_absolute_error: 0.4682 - val_rmse: 0.4683 - learning_rate: 1.0000e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 6/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 149s 19s/step - loss: 0.2339 - mad: 0.0097 - mean_absolute_error: 0.4835 - rmse: 0.4836 - val_loss: 0.2089 - val_mad: 0.0061 - val_mean_absolute_error: 0.4570 - val_rmse: 0.4571 - learning_rate: 1.0000e-04
#
# Epoch 7: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 7/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 153s 19s/step - loss: 0.2309 - mad: 0.0116 - mean_absolute_error: 0.4803 - rmse: 0.4806 - val_loss: 0.2171 - val_mad: 0.0060 - val_mean_absolute_error: 0.4659 - val_rmse: 0.4659 - learning_rate: 1.0000e-04
#
# Epoch 8: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 8/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 150s 19s/step - loss: 0.2278 - mad: 0.0096 - mean_absolute_error: 0.4771 - rmse: 0.4773 - val_loss: 0.1940 - val_mad: 0.0063 - val_mean_absolute_error: 0.4403 - val_rmse: 0.4404 - learning_rate: 1.0000e-04
#
# Epoch 9: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 9/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 153s 19s/step - loss: 0.2249 - mad: 0.0149 - mean_absolute_error: 0.4739 - rmse: 0.4742 - val_loss: 0.2240 - val_mad: 0.0056 - val_mean_absolute_error: 0.4732 - val_rmse: 0.4732 - learning_rate: 1.0000e-04
#
# Epoch 10: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 10/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 148s 19s/step - loss: 0.2217 - mad: 0.0130 - mean_absolute_error: 0.4705 - rmse: 0.4708 - val_loss: 0.2057 - val_mad: 0.0069 - val_mean_absolute_error: 0.4534 - val_rmse: 0.4535 - learning_rate: 1.0000e-04
#
# Epoch 11: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 11/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 149s 19s/step - loss: 0.2189 - mad: 0.0132 - mean_absolute_error: 0.4676 - rmse: 0.4679 - val_loss: 0.2087 - val_mad: 0.0071 - val_mean_absolute_error: 0.4567 - val_rmse: 0.4568 - learning_rate: 5.0000e-05
#
# Epoch 12: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 12/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 153s 19s/step - loss: 0.2172 - mad: 0.0109 - mean_absolute_error: 0.4658 - rmse: 0.4660 - val_loss: 0.2245 - val_mad: 0.0068 - val_mean_absolute_error: 0.4737 - val_rmse: 0.4737 - learning_rate: 5.0000e-05
#
# Epoch 13: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 13/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 152s 19s/step - loss: 0.2156 - mad: 0.0113 - mean_absolute_error: 0.4641 - rmse: 0.4643 - val_loss: 0.2179 - val_mad: 0.0077 - val_mean_absolute_error: 0.4666 - val_rmse: 0.4667 - learning_rate: 5.0000e-05
#
# Epoch 14: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 14/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 148s 19s/step - loss: 0.2142 - mad: 0.0157 - mean_absolute_error: 0.4624 - rmse: 0.4628 - val_loss: 0.1919 - val_mad: 0.0061 - val_mean_absolute_error: 0.4380 - val_rmse: 0.4381 - learning_rate: 5.0000e-05
#
# Epoch 15: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 15/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 149s 19s/step - loss: 0.2124 - mad: 0.0111 - mean_absolute_error: 0.4606 - rmse: 0.4608 - val_loss: 0.2229 - val_mad: 0.0055 - val_mean_absolute_error: 0.4721 - val_rmse: 0.4722 - learning_rate: 5.0000e-05
#
# Epoch 16: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 16/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 149s 19s/step - loss: 0.2108 - mad: 0.0106 - mean_absolute_error: 0.4589 - rmse: 0.4591 - val_loss: 0.2314 - val_mad: 0.0054 - val_mean_absolute_error: 0.4810 - val_rmse: 0.4810 - learning_rate: 5.0000e-05
#
# Epoch 17: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 17/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 153s 19s/step - loss: 0.2091 - mad: 0.0108 - mean_absolute_error: 0.4571 - rmse: 0.4573 - val_loss: 0.2375 - val_mad: 0.0053 - val_mean_absolute_error: 0.4872 - val_rmse: 0.4873 - learning_rate: 5.0000e-05
#
# Epoch 18: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 18/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 153s 19s/step - loss: 0.2076 - mad: 0.0140 - mean_absolute_error: 0.4553 - rmse: 0.4557 - val_loss: 0.1800 - val_mad: 0.0047 - val_mean_absolute_error: 0.4242 - val_rmse: 0.4243 - learning_rate: 5.0000e-05
#
# Epoch 19: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 19/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 149s 19s/step - loss: 0.2058 - mad: 0.0103 - mean_absolute_error: 0.4535 - rmse: 0.4537 - val_loss: 0.1894 - val_mad: 0.0056 - val_mean_absolute_error: 0.4352 - val_rmse: 0.4352 - learning_rate: 5.0000e-05
#
# Epoch 20: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 20/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 148s 19s/step - loss: 0.2042 - mad: 0.0106 - mean_absolute_error: 0.4517 - rmse: 0.4519 - val_loss: 0.2139 - val_mad: 0.0053 - val_mean_absolute_error: 0.4624 - val_rmse: 0.4624 - learning_rate: 5.0000e-05
#
# Epoch 21: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 21/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 148s 19s/step - loss: 0.2028 - mad: 0.0128 - mean_absolute_error: 0.4501 - rmse: 0.4504 - val_loss: 0.1887 - val_mad: 0.0047 - val_mean_absolute_error: 0.4344 - val_rmse: 0.4344 - learning_rate: 2.5000e-05
#
# Epoch 22: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 22/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 202s 19s/step - loss: 0.2020 - mad: 0.0102 - mean_absolute_error: 0.4492 - rmse: 0.4494 - val_loss: 0.1927 - val_mad: 0.0051 - val_mean_absolute_error: 0.4389 - val_rmse: 0.4389 - learning_rate: 2.5000e-05
#
# Epoch 23: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 23/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 154s 19s/step - loss: 0.2011 - mad: 0.0114 - mean_absolute_error: 0.4483 - rmse: 0.4485 - val_loss: 0.1807 - val_mad: 0.0050 - val_mean_absolute_error: 0.4250 - val_rmse: 0.4251 - learning_rate: 2.5000e-05
#
# Epoch 24: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 24/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 149s 19s/step - loss: 0.2002 - mad: 0.0090 - mean_absolute_error: 0.4473 - rmse: 0.4475 - val_loss: 0.1912 - val_mad: 0.0051 - val_mean_absolute_error: 0.4372 - val_rmse: 0.4373 - learning_rate: 2.5000e-05
#
# Epoch 25: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 25/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 150s 19s/step - loss: 0.1994 - mad: 0.0081 - mean_absolute_error: 0.4464 - rmse: 0.4465 - val_loss: 0.2006 - val_mad: 0.0054 - val_mean_absolute_error: 0.4478 - val_rmse: 0.4479 - learning_rate: 2.5000e-05
#
# Epoch 26: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 26/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 149s 19s/step - loss: 0.1987 - mad: 0.0118 - mean_absolute_error: 0.4455 - rmse: 0.4457 - val_loss: 0.1747 - val_mad: 0.0052 - val_mean_absolute_error: 0.4178 - val_rmse: 0.4179 - learning_rate: 2.5000e-05
#
# Epoch 27: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 27/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 149s 19s/step - loss: 0.1978 - mad: 0.0107 - mean_absolute_error: 0.4446 - rmse: 0.4448 - val_loss: 0.2030 - val_mad: 0.0057 - val_mean_absolute_error: 0.4504 - val_rmse: 0.4505 - learning_rate: 2.5000e-05
#
# Epoch 28: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 28/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 149s 19s/step - loss: 0.1970 - mad: 0.0100 - mean_absolute_error: 0.4436 - rmse: 0.4438 - val_loss: 0.1755 - val_mad: 0.0054 - val_mean_absolute_error: 0.4188 - val_rmse: 0.4189 - learning_rate: 2.5000e-05
#
# Epoch 29: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 29/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 154s 19s/step - loss: 0.1962 - mad: 0.0110 - mean_absolute_error: 0.4427 - rmse: 0.4429 - val_loss: 0.2064 - val_mad: 0.0060 - val_mean_absolute_error: 0.4542 - val_rmse: 0.4543 - learning_rate: 2.5000e-05
#
# Epoch 30: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 30/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 148s 19s/step - loss: 0.1954 - mad: 0.0105 - mean_absolute_error: 0.4418 - rmse: 0.4420 - val_loss: 0.2110 - val_mad: 0.0068 - val_mean_absolute_error: 0.4592 - val_rmse: 0.4593 - learning_rate: 2.5000e-05
#
# Epoch 31: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 31/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 149s 19s/step - loss: 0.1946 - mad: 0.0102 - mean_absolute_error: 0.4409 - rmse: 0.4411 - val_loss: 0.2167 - val_mad: 0.0076 - val_mean_absolute_error: 0.4654 - val_rmse: 0.4655 - learning_rate: 1.2500e-05
#
# Epoch 32: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 32/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 148s 19s/step - loss: 0.1941 - mad: 0.0084 - mean_absolute_error: 0.4405 - rmse: 0.4406 - val_loss: 0.2120 - val_mad: 0.0081 - val_mean_absolute_error: 0.4603 - val_rmse: 0.4604 - learning_rate: 1.2500e-05
#
# Epoch 33: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 33/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 153s 19s/step - loss: 0.1938 - mad: 0.0110 - mean_absolute_error: 0.4400 - rmse: 0.4402 - val_loss: 0.2326 - val_mad: 0.0086 - val_mean_absolute_error: 0.4821 - val_rmse: 0.4823 - learning_rate: 1.2500e-05
#
# Epoch 34: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 34/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 154s 19s/step - loss: 0.1934 - mad: 0.0115 - mean_absolute_error: 0.4395 - rmse: 0.4397 - val_loss: 0.2081 - val_mad: 0.0086 - val_mean_absolute_error: 0.4560 - val_rmse: 0.4561 - learning_rate: 1.2500e-05
#
# Epoch 35: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 35/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 150s 19s/step - loss: 0.1929 - mad: 0.0104 - mean_absolute_error: 0.4391 - rmse: 0.4392 - val_loss: 0.2115 - val_mad: 0.0088 - val_mean_absolute_error: 0.4597 - val_rmse: 0.4599 - learning_rate: 1.2500e-05
#
# Epoch 36: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 36/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 149s 19s/step - loss: 0.1925 - mad: 0.0098 - mean_absolute_error: 0.4386 - rmse: 0.4388 - val_loss: 0.2078 - val_mad: 0.0085 - val_mean_absolute_error: 0.4557 - val_rmse: 0.4558 - learning_rate: 1.2500e-05
#
# Epoch 37: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 37/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 150s 19s/step - loss: 0.1921 - mad: 0.0084 - mean_absolute_error: 0.4381 - rmse: 0.4382 - val_loss: 0.1909 - val_mad: 0.0084 - val_mean_absolute_error: 0.4367 - val_rmse: 0.4369 - learning_rate: 1.2500e-05
#
# Epoch 38: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 38/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 153s 19s/step - loss: 0.1917 - mad: 0.0110 - mean_absolute_error: 0.4376 - rmse: 0.4378 - val_loss: 0.2080 - val_mad: 0.0091 - val_mean_absolute_error: 0.4559 - val_rmse: 0.4561 - learning_rate: 1.2500e-05
#
# Epoch 39: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 39/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 153s 19s/step - loss: 0.1913 - mad: 0.0092 - mean_absolute_error: 0.4372 - rmse: 0.4374 - val_loss: 0.1861 - val_mad: 0.0093 - val_mean_absolute_error: 0.4312 - val_rmse: 0.4313 - learning_rate: 1.2500e-05
#
# Epoch 40: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 40/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 149s 19s/step - loss: 0.1909 - mad: 0.0101 - mean_absolute_error: 0.4367 - rmse: 0.4369 - val_loss: 0.1956 - val_mad: 0.0094 - val_mean_absolute_error: 0.4421 - val_rmse: 0.4423 - learning_rate: 1.2500e-05
#
# Epoch 41: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 41/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 154s 19s/step - loss: 0.1905 - mad: 0.0098 - mean_absolute_error: 0.4363 - rmse: 0.4364 - val_loss: 0.1873 - val_mad: 0.0092 - val_mean_absolute_error: 0.4326 - val_rmse: 0.4327 - learning_rate: 6.2500e-06
#
# Epoch 42: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 42/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 154s 19s/step - loss: 0.1903 - mad: 0.0101 - mean_absolute_error: 0.4360 - rmse: 0.4362 - val_loss: 0.1753 - val_mad: 0.0089 - val_mean_absolute_error: 0.4185 - val_rmse: 0.4186 - learning_rate: 6.2500e-06
#
# Epoch 43: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 43/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 151s 19s/step - loss: 0.1902 - mad: 0.0123 - mean_absolute_error: 0.4358 - rmse: 0.4361 - val_loss: 0.1796 - val_mad: 0.0094 - val_mean_absolute_error: 0.4236 - val_rmse: 0.4238 - learning_rate: 6.2500e-06
#
# Epoch 44: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 44/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 154s 19s/step - loss: 0.1899 - mad: 0.0120 - mean_absolute_error: 0.4356 - rmse: 0.4358 - val_loss: 0.1959 - val_mad: 0.0100 - val_mean_absolute_error: 0.4424 - val_rmse: 0.4426 - learning_rate: 6.2500e-06
#
# Epoch 45: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 45/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 149s 19s/step - loss: 0.1897 - mad: 0.0108 - mean_absolute_error: 0.4353 - rmse: 0.4356 - val_loss: 0.1856 - val_mad: 0.0102 - val_mean_absolute_error: 0.4306 - val_rmse: 0.4308 - learning_rate: 6.2500e-06
#
# Epoch 46: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 46/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 149s 19s/step - loss: 0.1895 - mad: 0.0107 - mean_absolute_error: 0.4351 - rmse: 0.4353 - val_loss: 0.1807 - val_mad: 0.0105 - val_mean_absolute_error: 0.4249 - val_rmse: 0.4251 - learning_rate: 6.2500e-06

# %%
# Evaluate the model on the test data
evaluation = model.evaluate(features_test, labels_test)

# Print the evaluation results with four decimal places
print(f"Evaluation Loss (MSE): {evaluation[0]:.5f}")
print(f"Evaluation MAE: {evaluation[1]:.5f}")
print(f"Evaluation RMSE: {evaluation[2]:.5f}")
print(f"Evaluation MAD: {evaluation[3]:.5f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - loss: 0.1747 - mad: 0.0053 - mean_absolute_error: 0.4178 - rmse: 0.4179
# Evaluation Loss (MSE): 0.17466
# Evaluation MAE: 0.41785
# Evaluation RMSE: 0.41792
# Evaluation MAD: 0.00529

# %%
# Plot the Train loss and validation loss
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss and validation loss')
plt.xlabel('Epoch')
plt.ylabel('Metric Value')
plt.legend()
plt.show()

# %%
# Plot the train rmse and validation rmse
plt.figure(figsize=(12, 6))
plt.plot(history.history['rmse'], label='Train RMSE')
plt.plot(history.history['val_rmse'], label='Validation RMSE')
plt.title('Train RMSE Vs Validation RMSE')
plt.xlabel('Epoch')
plt.ylabel('Metric Value')
plt.legend()
plt.show()

# %%
# Plot the tain MAD and validation MAD
plt.figure(figsize=(12, 6))
plt.plot(history.history['mad'], label='Train MAD')
plt.plot(history.history['val_mad'], label='Validation MAD')
plt.title('Train MAD Vs Validation MAD')
plt.xlabel('Epoch')
plt.ylabel('Metric Value')
plt.legend()
plt.show()

# %%
model.save('CNN3d(E05).h5')

# %%
import os
import cv2
import numpy as np

# Function to save all split videos from the test set to a folder
def save_all_split_videos(video_data, save_dir, SEQUENCE_LENGTH=30, IMAGE_HEIGHT=128, IMAGE_WIDTH=128, fps=30):
    """
    Save all split videos from the video data as individual video files in the specified directory.

    Args:
        video_data: Numpy array containing video data of shape (num_videos, SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3).
        save_dir: Directory to save the videos.
        SEQUENCE_LENGTH: Number of frames per video (default is 16).
        IMAGE_HEIGHT: Height of the frames (default is 64).
        IMAGE_WIDTH: Width of the frames (default is 64).
        fps: Frames per second for the output videos (default is 30).
    """
    # Create the save directory if it doesn't exist
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    # Iterate over all videos in the dataset
    for video_index in range(video_data.shape[0]):
        video_frames = video_data[video_index]  # Shape: (SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3)

        # Prepare the VideoWriter object to save the video
        video_filename = os.path.join(save_dir, f"split_video_{video_index + 1}.mp4")
        fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Use 'mp4v' for .mp4 format
        video_writer = cv2.VideoWriter(video_filename, fourcc, fps, (IMAGE_WIDTH, IMAGE_HEIGHT))

        # Add frames to the video
        for frame in video_frames:
            # Ensure the frame has values in the range [0, 255] and convert to uint8
            frame_rgb = (frame * 255).astype(np.uint8)
            # Convert RGB to BGR for OpenCV
            frame_bgr = cv2.cvtColor(frame_rgb, cv2.COLOR_RGB2BGR)
            # Write the frame to the video
            video_writer.write(frame_bgr)

        # Release the video writer
        video_writer.release()
        print(f"Video {video_index + 1} saved to: {video_filename}")

# Example usage: Save all split videos from the test set
# Make sure `features_test` is defined before calling this function
save_all_split_videos(features_test, save_dir="/kaggle/working/split_videos")
# Out:
# Video 1 saved to: /kaggle/working/split_videos/split_video_1.mp4
# Video 2 saved to: /kaggle/working/split_videos/split_video_2.mp4
# Video 3 saved to: /kaggle/working/split_videos/split_video_3.mp4
# Video 4 saved to: /kaggle/working/split_videos/split_video_4.mp4
# Video 5 saved to: /kaggle/working/split_videos/split_video_5.mp4
# Video 6 saved to: /kaggle/working/split_videos/split_video_6.mp4
# Video 7 saved to: /kaggle/working/split_videos/split_video_7.mp4
# Video 8 saved to: /kaggle/working/split_videos/split_video_8.mp4
# Video 9 saved to: /kaggle/working/split_videos/split_video_9.mp4
# Video 10 saved to: /kaggle/working/split_videos/split_video_10.mp4
# Video 11 saved to: /kaggle/working/split_videos/split_video_11.mp4
# Video 12 saved to: /kaggle/working/split_videos/split_video_12.mp4
# Video 13 saved to: /kaggle/working/split_videos/split_video_13.mp4
# Video 14 saved to: /kaggle/working/split_videos/split_video_14.mp4
# Video 15 saved to: /kaggle/working/split_videos/split_video_15.mp4
# Video 16 saved to: /kaggle/working/split_videos/split_video_16.mp4

# %%
import cv2
import numpy as np

def process_video(video_path):
    """
    Preprocess a video for 3D-CNN model inference.
    Args:
        video_path (str): Path to the video file.
    Returns:
        np.ndarray: Preprocessed video data with shape (1, SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3).
    """
    cap = cv2.VideoCapture(video_path)
    frames = []
    
    # Read and preprocess frames
    while len(frames) < SEQUENCE_LENGTH:
        ret, frame = cap.read()
        if not ret:
            break
        # Resize frame to match model's expected input size
        frame = cv2.resize(frame, (IMAGE_WIDTH, IMAGE_HEIGHT))
        frame = frame / 255.0  # Normalize pixel values to [0, 1]
        frames.append(frame)

    cap.release()

    # Handle cases where video has fewer frames than SEQUENCE_LENGTH
    while len(frames) < SEQUENCE_LENGTH:
        frames.append(np.zeros((IMAGE_HEIGHT, IMAGE_WIDTH, 3)))  # Pad with black frames

    # Convert to numpy array and add batch dimension
    video_data = np.array(frames[:SEQUENCE_LENGTH])  # Ensure exactly SEQUENCE_LENGTH frames
    return np.expand_dims(video_data, axis=0)  # Shape becomes (1, SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3)

# Predict for a new video
video_path = '/kaggle/input/test-regre/test_regre/E05_P60_AF_VLL_GF.mp4'

video_data = process_video(video_path)
print(f"Video data shape: {video_data.shape}")  # Should output (1, 30, 128, 128, 3)

predicted_score = model.predict(video_data)
scaled_score = predicted_score * 99 + 1
print(f"Predicted Score: {scaled_score[0][0]:.2f}")  # Assuming `predicted_score` is a 2D array
# Out:
# Video data shape: (1, 30, 128, 128, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step
# Predicted Score: 41.40
