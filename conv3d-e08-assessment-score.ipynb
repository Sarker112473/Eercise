# %%
import os
import shutil
import cv2
import math
import random
import numpy as np
import tensorflow as tf
from tensorflow import keras
from collections import deque
import matplotlib.pyplot as plt
plt.style.use("seaborn")
import tqdm
# %matplotlib inline
from tensorflow.keras import Model
from sklearn.model_selection import train_test_split
from keras.applications.mobilenet_v2 import MobileNetV2
from keras.layers import *
from keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.utils import plot_model

from IPython.display import HTML
from base64 import b64encode
from tensorflow.keras.layers import Input,Dense, Flatten, ReLU, Conv2D, DepthwiseConv2D,AvgPool2D, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.optimizers import Adam
import keras.backend as K
from typing import Optional
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings('ignore')
# Out:
# /tmp/ipykernel_30/1542781770.py:11: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
def Play_Video(filepath):
    html = ''
    video = open(filepath, 'rb').read()
    src = 'data:video/mp4;base64,' + b64encode(video).decode()
    html += '<video width=640 muted controls autoplay loop><source src="%s" type="video/mp4"></video>' % src
    return HTML(html)

# %%
IMAGE_HEIGHT, IMAGE_WIDTH = 128, 128
SEQUENCE_LENGTH = 30

# %%
CLASSES_LIST = ["E08(Both_Leg_Flexion)"]

# %%
def frames_extraction(video_path):
    frames_list = []
    video_reader = cv2.VideoCapture(video_path)
    video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))
    skip_frames_window = max(int(video_frames_count/SEQUENCE_LENGTH), 1)

    for frame_counter in range(SEQUENCE_LENGTH):
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)
        success, frame = video_reader.read()

        if not success:
            break

        resized_frame = cv2.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))
        normalized_frame = resized_frame / 255
        frames_list.append(normalized_frame)

    video_reader.release()
    return frames_list

# %%
def create_dataset(video_dir, csv_file_path):
    features = []
    labels = []
    video_files_paths = []
    matching_files_count = 0

    # Read the CSV file
    csv_data = pd.read_csv(csv_file_path)

    for class_index, class_name in enumerate(CLASSES_LIST):
        print(f'Extracting Data of Class: {class_name}')
        files_list = os.listdir(os.path.join(video_dir, class_name))

        for file_name in files_list:
            # Remove the .mp4 extension from the file name
            video_name = os.path.splitext(file_name)[0]

            video_file_path = os.path.join(video_dir, class_name, file_name)
            frames = frames_extraction(video_file_path)

            if len(frames) == SEQUENCE_LENGTH:
                # Search for the exercise name in the CSV data that matches with video file name
                matching_row = csv_data[csv_data['Excercise Name'].str.lower() == video_name.lower()]

                if not matching_row.empty:
                    assessment_score = matching_row['Assessment Score'].values[0]
                    features.append(frames)
                    labels.append(class_index)
                    video_files_paths.append(video_file_path)
                    matching_files_count += 1
                    print(f'Matched file: {video_name}, Assessment Score: {assessment_score}')
                else:
                    # Append None if no matching row is found
                    features.append(frames)
                    labels.append(class_index)
                    video_files_paths.append(video_file_path)
                    print(f'No matching row found for file: {video_name}')

    features = np.asarray(features)
    labels = np.asarray(labels)

    print(f'Total matching files: {matching_files_count}')

    return features, labels, matching_files_count, video_files_paths

# %%
import pandas as pd

video_dir = '/kaggle/input/regression-folders/dataset_regression'
csv_file_path = '/kaggle/input/csv-files-regression/Ex_08_sub.csv'
features, labels, matching_files_count, video_files_paths =  create_dataset(video_dir, csv_file_path)
print("Features shape:", features.shape)
print("Labels shape:", labels.shape)
print("Matching files count:", matching_files_count)
print("Number of video files:", len(video_files_paths))
# Out:
# Extracting Data of Class: E08(Both_Leg_Flexion)
# Matched file: E08_P04_AL_VML_GM, Assessment Score: 81.9
# Matched file: E08_P42_AF_VO_GM, Assessment Score: 16.67
# Matched file: E08_P21_AR_VLL_GM, Assessment Score: 84.29
# Matched file: E08_P50_AR_VFL_GM, Assessment Score: 47.62
# Matched file: E08_P04_AF_VML_GM, Assessment Score: 97.62
# Matched file: E08_P47_AF_VML_GM, Assessment Score: 60.0
# Matched file: E08_P22_AL_VLL_GM, Assessment Score: 78.57
# Matched file: E08_P02_AR_VFL_GM, Assessment Score: 82.86
# Matched file: E08_P04_AF_VHJ_GM, Assessment Score: 83.33
# Matched file: E08_P31_AF_VO_GM, Assessment Score: 19.05
# Matched file: E08_P21_AL_VFL_GM, Assessment Score: 67.14
# Matched file: E08_P45_AF_VML_GM, Assessment Score: 52.86
# Matched file: E08_P28_AL_VFL_GM, Assessment Score: 39.52
# Matched file: E08_P48_AF_VFL_GM, Assessment Score: 33.33
# Matched file: E08_P27_AR_VFL_GM, Assessment Score: 47.62
# Matched file: E08_P07_AR_VML_GM, Assessment Score: 80.48
# Matched file: E08_P32_AF_VO_GM, Assessment Score: 34.76
# Matched file: E08_P27_AF_VFL_GM, Assessment Score: 58.57
# Matched file: E08_P22_AF_VML_GM, Assessment Score: 97.62
# Matched file: E08_P08_AF_VHJ_GM, Assessment Score: 85.71
# Matched file: E08_P47_AL_VFL_GM, Assessment Score: 57.62
# Matched file: E08_P38_AR_VFL_GM, Assessment Score: 9.52
# Matched file: E08_P47_AF_VLJ_GM, Assessment Score: 56.19
# Matched file: E08_P29_AF_VLR_GM, Assessment Score: 0.0
# Matched file: E08_P48_AR_VFL_GM, Assessment Score: 50.48
# Matched file: E08_P04_AL_VFL_GM, Assessment Score: 95.24
# Matched file: E08_P29_AR_VFL_GM, Assessment Score: 14.29
# Matched file: E08_P04_AF_VFL_GM, Assessment Score: 76.67
# Matched file: E08_P48_AL_VFL_GM, Assessment Score: 49.05
# Matched file: E08_P35_AF_VLJ_GM, Assessment Score: 21.43
# Matched file: E08_P35_AF_VLL_GM, Assessment Score: 32.38
# Matched file: E08_P04_AR_VFL_GM, Assessment Score: 95.24
# Matched file: E08_P38_AF_VLL_GM, Assessment Score: 9.52
# Matched file: E08_P07_AL_VML_GM, Assessment Score: 79.05
# Matched file: E08_P27_AF_VLR_GM, Assessment Score: 51.43
# Matched file: E08_P50_AL_VFL_GM, Assessment Score: 45.24
# Matched file: E08_P28_AF_VLL_GM, Assessment Score: 28.57
# Matched file: E08_P08_AF_VLJ_GM, Assessment Score: 69.05
# Matched file: E08_P38_AF_VFL_GM, Assessment Score: 4.76
# Matched file: E08_P46_AF_VFL_GM, Assessment Score: 55.24
# Matched file: E08_P22_AR_VLL_GM, Assessment Score: 80.0
# Matched file: E08_P47_AF_VHJ_GM, Assessment Score: 56.19
# Matched file: E08_P38_AF_VLJ_GM, Assessment Score: 9.52
# Matched file: E08_P21_AF_VFL_GM, Assessment Score: 67.14
# Matched file: E08_P08_AR_VML_GM, Assessment Score: 78.1
# Matched file: E08_P28_AF_VML_GM, Assessment Score: 39.52
# Matched file: E08_P07_AR_VLL_GM, Assessment Score: 81.9
# Matched file: E08_P42_AL_VFL_GM, Assessment Score: 16.67
# Matched file: E08_P35_AF_VFL_GM, Assessment Score: 21.43
# Matched file: E08_P32_AF_VLL_GM, Assessment Score: 34.76
# Matched file: E08_P04_AR_VHJ_GM, Assessment Score: 67.62
# Matched file: E08_P18_AR_VFL_GM, Assessment Score: 100.0
# Matched file: E08_P22_AF_VLL_GM, Assessment Score: 80.0
# Matched file: E08_P46_AL_VFL_GM, Assessment Score: 55.24
# Matched file: E08_P47_AF_VFL_GM, Assessment Score: 50.0
# Matched file: E08_P08_AR_VLJ_GM, Assessment Score: 69.05
# Matched file: E08_P48_AF_VML_GM, Assessment Score: 40.48
# Matched file: E08_P04_AL_VHJ_GM, Assessment Score: 67.62
# Matched file: E08_P38_AF_VHJ_GM, Assessment Score: 4.76
# Matched file: E08_P23_AF_VO_GM, Assessment Score: 81.43
# Matched file: E08_P21_AR_VFL_GM, Assessment Score: 65.71
# Matched file: E08_P49_AF_VHJ_GM, Assessment Score: 58.57
# Matched file: E08_P27_AF_VLJ_GM, Assessment Score: 52.38
# Matched file: E08_P08_AF_VML_GM, Assessment Score: 79.52
# Matched file: E08_P35_AF_VLR_GM, Assessment Score: 28.57
# Matched file: E08_P29_AF_VFL_GM, Assessment Score: 0.0
# Matched file: E08_P08_AL_VML_GM, Assessment Score: 78.1
# Matched file: E08_P45_AF_VFL_GM, Assessment Score: 48.1
# Matched file: E08_P42_AF_VHJ_GM, Assessment Score: 19.05
# Matched file: E08_P35_AF_VHJ_GM, Assessment Score: 2.38
# Matched file: E08_P49_AF_VML_GM, Assessment Score: 60.0
# Matched file: E08_P37_AF_VML_GM, Assessment Score: 23.81
# Matched file: E08_P02_AF_VFL_GM, Assessment Score: 82.86
# Matched file: E08_P06_AF_VML_GM, Assessment Score: 100.0
# Matched file: E08_P21_AR_VML_GM, Assessment Score: 84.29
# Matched file: E08_P08_AR_VHJ_GM, Assessment Score: 70.0
# Matched file: E08_P37_AF_VLL_GM, Assessment Score: 23.81
# Matched file: E08_P07_AF_VML_GM, Assessment Score: 80.48
# Matched file: E08_P42_AF_VLR_GM, Assessment Score: 19.05
# Matched file: E08_P22_AL_VFL_GM, Assessment Score: 70.0
# Total matching files: 80
# Features shape: (80, 30, 128, 128, 3)
# Labels shape: (80,)
# Matching files count: 80
# Number of video files: 80

# %%
np.save("features.npy", features)
np.save("labels.npy", labels)
np.save("video_files_paths.npy", video_files_paths)

# %%
features, labels, video_files_paths = np.load("features.npy"), np.load("labels.npy"), np.load("video_files_paths.npy")

# %%
print(f'Number of features: {len(features)}, Number of labels: {len(labels)}, Number of video_files_paths: {len(video_files_paths)}')
# Out:
# Number of features: 80, Number of labels: 80, Number of video_files_paths: 80

# %%
features_train, features_test, labels_train, labels_test = train_test_split(
    features, labels, test_size=0.20, shuffle=True, random_state=42
)

print(f"Training features: {features_train.shape}, Training labels: {labels_train.shape}")
print(f"Testing features: {features_test.shape}, Testing labels: {labels_test.shape}")
# Out:
# Training features: (64, 30, 128, 128, 3), Training labels: (64,)
# Testing features: (16, 30, 128, 128, 3), Testing labels: (16,)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler
import matplotlib.pyplot as plt
import numpy as np

# Define RMSE and MAD as custom metrics with correct casting
def rmse(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)  # Cast y_true to float32
    return tf.sqrt(tf.reduce_mean(tf.square(y_pred - y_true)))

def mad(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)  # Cast y_true to float32
    return tf.reduce_mean(tf.abs(y_pred - tf.reduce_mean(y_pred)))



# Define the CNN + LSTM model
def create_cnn_lstm_model(SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH):
    """
    A CNN + LSTM model for sequence prediction.
    """
    # Define the video input (3D input for CNN + LSTM)
    video_input = layers.Input(shape=(SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3))
    
    # CNN layers for feature extraction
    x = layers.Conv3D(32, (3, 3, 3), padding='same', activation='relu')(video_input)
    x = layers.MaxPooling3D((2, 2, 2))(x)
    x = layers.Dropout(0.3)(x)
    x = layers.BatchNormalization()(x)
    
    x = layers.Conv3D(64, (3, 3, 3), padding='same', activation='relu')(x)
    x = layers.MaxPooling3D((2, 2, 2))(x)
    x = layers.Dropout(0.3)(x)
    x = layers.BatchNormalization()(x)

    # Flatten the output of the CNN to make it compatible with LSTM
    x = layers.Reshape((-1, x.shape[1] * x.shape[2] * x.shape[3]))(x)  # Flatten the spatial dimensions

    # LSTM layer to capture temporal dependencies
    x = layers.LSTM(64, return_sequences=False)(x)
    
    # Dense layer with sigmoid activation to scale output to [0, 1]
    regression_output = layers.Dense(1, activation='sigmoid', name='regression_output')(x)
    
    # Build the model
    model = models.Model(inputs=video_input, outputs=[regression_output])
    model.summary()
    
    return model

# %%
# Define hyperparameters
SEQUENCE_LENGTH = 30  # Set according to your input data
IMAGE_HEIGHT = 128  # Set the height of your input images
IMAGE_WIDTH = 128  # Set the width of your input images

# Create the model
model = create_cnn_lstm_model(SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 30, 128, 128,   │             0 │
# │                                 │ 3)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d (Conv3D)                 │ (None, 30, 128, 128,   │         2,624 │
# │                                 │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d (MaxPooling3D)    │ (None, 15, 64, 64, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 15, 64, 64, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 15, 64, 64, 32) │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_1 (Conv3D)               │ (None, 15, 64, 64, 64) │        55,360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_1 (MaxPooling3D)  │ (None, 7, 32, 32, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 7, 32, 32, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 7, 32, 32, 64)  │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 64, 7168)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 64)             │     1,851,648 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ regression_output (Dense)       │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,910,081 (7.29 MB)
#  Trainable params: 1,909,889 (7.29 MB)
#  Non-trainable params: 192 (768.00 B)

# %%
# Compile the model for regression task
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='mean_squared_error',  # Use MSE for regression
              metrics=['mean_absolute_error', rmse, mad])

# Define Early Stopping and Learning Rate Scheduler callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
lr_scheduler = LearningRateScheduler(lambda epoch, lr: lr * 0.5 if epoch % 5 == 0 and epoch > 0 else lr, verbose=1)

callbacks = [early_stopping, lr_scheduler]

# Train the model
history = model.fit(features_train, labels_train,
                    validation_data=(features_test, labels_test),
                    epochs=60, batch_size=8, verbose=1, 
                    callbacks=callbacks)
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 1/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 161s 19s/step - loss: 0.1854 - mad: 0.0825 - mean_absolute_error: 0.4150 - rmse: 0.4279 - val_loss: 0.2266 - val_mad: 0.0134 - val_mean_absolute_error: 0.4755 - val_rmse: 0.4760 - learning_rate: 1.0000e-04
#
# Epoch 2: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 2/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 140s 18s/step - loss: 0.0612 - mad: 0.0985 - mean_absolute_error: 0.2127 - rmse: 0.2441 - val_loss: 0.0977 - val_mad: 0.0191 - val_mean_absolute_error: 0.3114 - val_rmse: 0.3125 - learning_rate: 1.0000e-04
#
# Epoch 3: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 3/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 142s 18s/step - loss: 0.0184 - mad: 0.0519 - mean_absolute_error: 0.1149 - rmse: 0.1307 - val_loss: 0.0244 - val_mad: 0.0144 - val_mean_absolute_error: 0.1550 - val_rmse: 0.1561 - learning_rate: 1.0000e-04
#
# Epoch 4: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 4/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 139s 17s/step - loss: 0.0039 - mad: 0.0239 - mean_absolute_error: 0.0530 - rmse: 0.0616 - val_loss: 0.0065 - val_mad: 0.0074 - val_mean_absolute_error: 0.0802 - val_rmse: 0.0807 - learning_rate: 1.0000e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 5/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 156s 20s/step - loss: 0.0023 - mad: 0.0192 - mean_absolute_error: 0.0383 - rmse: 0.0464 - val_loss: 0.0026 - val_mad: 0.0044 - val_mean_absolute_error: 0.0502 - val_rmse: 0.0505 - learning_rate: 1.0000e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 6/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 140s 18s/step - loss: 0.0015 - mad: 0.0152 - mean_absolute_error: 0.0273 - rmse: 0.0349 - val_loss: 0.0014 - val_mad: 0.0029 - val_mean_absolute_error: 0.0367 - val_rmse: 0.0368 - learning_rate: 5.0000e-05
#
# Epoch 7: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 7/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 144s 18s/step - loss: 0.0014 - mad: 0.0137 - mean_absolute_error: 0.0264 - rmse: 0.0327 - val_loss: 8.5071e-04 - val_mad: 0.0019 - val_mean_absolute_error: 0.0291 - val_rmse: 0.0292 - learning_rate: 5.0000e-05
#
# Epoch 8: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 8/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 140s 18s/step - loss: 0.0015 - mad: 0.0141 - mean_absolute_error: 0.0254 - rmse: 0.0321 - val_loss: 6.0602e-04 - val_mad: 0.0013 - val_mean_absolute_error: 0.0246 - val_rmse: 0.0246 - learning_rate: 5.0000e-05
#
# Epoch 9: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 9/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 143s 18s/step - loss: 0.0011 - mad: 0.0117 - mean_absolute_error: 0.0216 - rmse: 0.0282 - val_loss: 4.6666e-04 - val_mad: 9.0246e-04 - val_mean_absolute_error: 0.0216 - val_rmse: 0.0216 - learning_rate: 5.0000e-05
#
# Epoch 10: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 10/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 144s 18s/step - loss: 0.0021 - mad: 0.0177 - mean_absolute_error: 0.0259 - rmse: 0.0370 - val_loss: 3.8844e-04 - val_mad: 6.7825e-04 - val_mean_absolute_error: 0.0197 - val_rmse: 0.0197 - learning_rate: 5.0000e-05
#
# Epoch 11: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 11/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 145s 18s/step - loss: 5.1069e-04 - mad: 0.0075 - mean_absolute_error: 0.0188 - rmse: 0.0212 - val_loss: 3.2943e-04 - val_mad: 5.0801e-04 - val_mean_absolute_error: 0.0181 - val_rmse: 0.0181 - learning_rate: 2.5000e-05
#
# Epoch 12: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 12/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 144s 18s/step - loss: 0.0012 - mad: 0.0134 - mean_absolute_error: 0.0221 - rmse: 0.0295 - val_loss: 2.8930e-04 - val_mad: 4.0946e-04 - val_mean_absolute_error: 0.0170 - val_rmse: 0.0170 - learning_rate: 2.5000e-05
#
# Epoch 13: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 13/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 139s 18s/step - loss: 9.0406e-04 - mad: 0.0131 - mean_absolute_error: 0.0230 - rmse: 0.0287 - val_loss: 2.5918e-04 - val_mad: 3.4289e-04 - val_mean_absolute_error: 0.0161 - val_rmse: 0.0161 - learning_rate: 2.5000e-05
#
# Epoch 14: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 14/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 141s 18s/step - loss: 5.3669e-04 - mad: 0.0085 - mean_absolute_error: 0.0185 - rmse: 0.0220 - val_loss: 2.3614e-04 - val_mad: 2.9516e-04 - val_mean_absolute_error: 0.0154 - val_rmse: 0.0154 - learning_rate: 2.5000e-05
#
# Epoch 15: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 15/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 141s 18s/step - loss: 6.1068e-04 - mad: 0.0089 - mean_absolute_error: 0.0193 - rmse: 0.0226 - val_loss: 2.1847e-04 - val_mad: 2.6359e-04 - val_mean_absolute_error: 0.0148 - val_rmse: 0.0148 - learning_rate: 2.5000e-05
#
# Epoch 16: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 16/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 142s 18s/step - loss: 6.6209e-04 - mad: 0.0100 - mean_absolute_error: 0.0199 - rmse: 0.0245 - val_loss: 2.0452e-04 - val_mad: 2.4083e-04 - val_mean_absolute_error: 0.0143 - val_rmse: 0.0143 - learning_rate: 1.2500e-05
#
# Epoch 17: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 17/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 142s 18s/step - loss: 4.8144e-04 - mad: 0.0070 - mean_absolute_error: 0.0185 - rmse: 0.0210 - val_loss: 1.9313e-04 - val_mad: 2.3107e-04 - val_mean_absolute_error: 0.0139 - val_rmse: 0.0139 - learning_rate: 1.2500e-05
#
# Epoch 18: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 18/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 142s 18s/step - loss: 4.1510e-04 - mad: 0.0070 - mean_absolute_error: 0.0173 - rmse: 0.0196 - val_loss: 1.8403e-04 - val_mad: 2.2301e-04 - val_mean_absolute_error: 0.0136 - val_rmse: 0.0136 - learning_rate: 1.2500e-05
#
# Epoch 19: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 19/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 139s 17s/step - loss: 0.0011 - mad: 0.0139 - mean_absolute_error: 0.0229 - rmse: 0.0290 - val_loss: 1.7653e-04 - val_mad: 2.2330e-04 - val_mean_absolute_error: 0.0133 - val_rmse: 0.0133 - learning_rate: 1.2500e-05
#
# Epoch 20: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 20/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 140s 17s/step - loss: 4.5342e-04 - mad: 0.0066 - mean_absolute_error: 0.0170 - rmse: 0.0197 - val_loss: 1.7017e-04 - val_mad: 2.3167e-04 - val_mean_absolute_error: 0.0130 - val_rmse: 0.0130 - learning_rate: 1.2500e-05
#
# Epoch 21: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 21/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 141s 18s/step - loss: 6.2628e-04 - mad: 0.0093 - mean_absolute_error: 0.0199 - rmse: 0.0240 - val_loss: 1.6455e-04 - val_mad: 2.4588e-04 - val_mean_absolute_error: 0.0128 - val_rmse: 0.0128 - learning_rate: 6.2500e-06
#
# Epoch 22: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 22/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 139s 18s/step - loss: 5.9424e-04 - mad: 0.0077 - mean_absolute_error: 0.0173 - rmse: 0.0207 - val_loss: 1.5990e-04 - val_mad: 2.5848e-04 - val_mean_absolute_error: 0.0126 - val_rmse: 0.0126 - learning_rate: 6.2500e-06
#
# Epoch 23: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 23/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 144s 18s/step - loss: 3.5116e-04 - mad: 0.0063 - mean_absolute_error: 0.0164 - rmse: 0.0182 - val_loss: 1.5638e-04 - val_mad: 2.7145e-04 - val_mean_absolute_error: 0.0125 - val_rmse: 0.0125 - learning_rate: 6.2500e-06
#
# Epoch 24: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 24/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 139s 17s/step - loss: 4.6274e-04 - mad: 0.0074 - mean_absolute_error: 0.0174 - rmse: 0.0202 - val_loss: 1.5296e-04 - val_mad: 2.8814e-04 - val_mean_absolute_error: 0.0124 - val_rmse: 0.0124 - learning_rate: 6.2500e-06
#
# Epoch 25: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 25/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 142s 18s/step - loss: 8.7259e-04 - mad: 0.0127 - mean_absolute_error: 0.0214 - rmse: 0.0273 - val_loss: 1.5001e-04 - val_mad: 3.0470e-04 - val_mean_absolute_error: 0.0122 - val_rmse: 0.0122 - learning_rate: 6.2500e-06
#
# Epoch 26: LearningRateScheduler setting learning rate to 3.12499992105586e-06.
# Epoch 26/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 140s 18s/step - loss: 4.1246e-04 - mad: 0.0073 - mean_absolute_error: 0.0179 - rmse: 0.0201 - val_loss: 1.4701e-04 - val_mad: 3.2193e-04 - val_mean_absolute_error: 0.0121 - val_rmse: 0.0121 - learning_rate: 3.1250e-06
#
# Epoch 27: LearningRateScheduler setting learning rate to 3.12499992105586e-06.
# Epoch 27/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 141s 18s/step - loss: 4.1470e-04 - mad: 0.0075 - mean_absolute_error: 0.0175 - rmse: 0.0201 - val_loss: 1.4414e-04 - val_mad: 3.3919e-04 - val_mean_absolute_error: 0.0120 - val_rmse: 0.0120 - learning_rate: 3.1250e-06
#
# Epoch 28: LearningRateScheduler setting learning rate to 3.12499992105586e-06.
# Epoch 28/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 139s 17s/step - loss: 4.4704e-04 - mad: 0.0061 - mean_absolute_error: 0.0169 - rmse: 0.0193 - val_loss: 1.4140e-04 - val_mad: 3.5602e-04 - val_mean_absolute_error: 0.0119 - val_rmse: 0.0119 - learning_rate: 3.1250e-06
#
# Epoch 29: LearningRateScheduler setting learning rate to 3.12499992105586e-06.
# Epoch 29/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 143s 18s/step - loss: 6.2065e-04 - mad: 0.0080 - mean_absolute_error: 0.0164 - rmse: 0.0204 - val_loss: 1.3931e-04 - val_mad: 3.7406e-04 - val_mean_absolute_error: 0.0118 - val_rmse: 0.0118 - learning_rate: 3.1250e-06
#
# Epoch 30: LearningRateScheduler setting learning rate to 3.12499992105586e-06.
# Epoch 30/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 138s 17s/step - loss: 4.6972e-04 - mad: 0.0075 - mean_absolute_error: 0.0183 - rmse: 0.0209 - val_loss: 1.3719e-04 - val_mad: 3.9442e-04 - val_mean_absolute_error: 0.0117 - val_rmse: 0.0117 - learning_rate: 3.1250e-06
#
# Epoch 31: LearningRateScheduler setting learning rate to 1.56249996052793e-06.
# Epoch 31/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 141s 18s/step - loss: 4.9841e-04 - mad: 0.0078 - mean_absolute_error: 0.0173 - rmse: 0.0203 - val_loss: 1.3510e-04 - val_mad: 4.1434e-04 - val_mean_absolute_error: 0.0116 - val_rmse: 0.0116 - learning_rate: 1.5625e-06
#
# Epoch 32: LearningRateScheduler setting learning rate to 1.56249996052793e-06.
# Epoch 32/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 141s 18s/step - loss: 5.1110e-04 - mad: 0.0081 - mean_absolute_error: 0.0178 - rmse: 0.0211 - val_loss: 1.3305e-04 - val_mad: 4.3392e-04 - val_mean_absolute_error: 0.0115 - val_rmse: 0.0115 - learning_rate: 1.5625e-06
#
# Epoch 33: LearningRateScheduler setting learning rate to 1.56249996052793e-06.
# Epoch 33/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 140s 18s/step - loss: 5.1818e-04 - mad: 0.0089 - mean_absolute_error: 0.0183 - rmse: 0.0219 - val_loss: 1.3112e-04 - val_mad: 4.5359e-04 - val_mean_absolute_error: 0.0114 - val_rmse: 0.0115 - learning_rate: 1.5625e-06
#
# Epoch 34: LearningRateScheduler setting learning rate to 1.56249996052793e-06.
# Epoch 34/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 140s 18s/step - loss: 4.2042e-04 - mad: 0.0078 - mean_absolute_error: 0.0171 - rmse: 0.0200 - val_loss: 1.2916e-04 - val_mad: 4.7355e-04 - val_mean_absolute_error: 0.0114 - val_rmse: 0.0114 - learning_rate: 1.5625e-06
#
# Epoch 35: LearningRateScheduler setting learning rate to 1.56249996052793e-06.
# Epoch 35/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 144s 18s/step - loss: 4.2114e-04 - mad: 0.0067 - mean_absolute_error: 0.0165 - rmse: 0.0191 - val_loss: 1.2725e-04 - val_mad: 4.9378e-04 - val_mean_absolute_error: 0.0113 - val_rmse: 0.0113 - learning_rate: 1.5625e-06
#
# Epoch 36: LearningRateScheduler setting learning rate to 7.81249980263965e-07.
# Epoch 36/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 142s 18s/step - loss: 5.1278e-04 - mad: 0.0082 - mean_absolute_error: 0.0177 - rmse: 0.0214 - val_loss: 1.2527e-04 - val_mad: 5.1411e-04 - val_mean_absolute_error: 0.0112 - val_rmse: 0.0112 - learning_rate: 7.8125e-07
#
# Epoch 37: LearningRateScheduler setting learning rate to 7.81249980263965e-07.
# Epoch 37/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 140s 18s/step - loss: 6.2265e-04 - mad: 0.0095 - mean_absolute_error: 0.0180 - rmse: 0.0226 - val_loss: 1.2326e-04 - val_mad: 5.3471e-04 - val_mean_absolute_error: 0.0111 - val_rmse: 0.0111 - learning_rate: 7.8125e-07
#
# Epoch 38: LearningRateScheduler setting learning rate to 7.81249980263965e-07.
# Epoch 38/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 139s 17s/step - loss: 3.3107e-04 - mad: 0.0053 - mean_absolute_error: 0.0167 - rmse: 0.0180 - val_loss: 1.2128e-04 - val_mad: 5.5573e-04 - val_mean_absolute_error: 0.0110 - val_rmse: 0.0110 - learning_rate: 7.8125e-07
#
# Epoch 39: LearningRateScheduler setting learning rate to 7.81249980263965e-07.
# Epoch 39/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 144s 18s/step - loss: 7.7072e-04 - mad: 0.0108 - mean_absolute_error: 0.0200 - rmse: 0.0249 - val_loss: 1.1944e-04 - val_mad: 5.7730e-04 - val_mean_absolute_error: 0.0109 - val_rmse: 0.0109 - learning_rate: 7.8125e-07
#
# Epoch 40: LearningRateScheduler setting learning rate to 7.81249980263965e-07.
# Epoch 40/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 144s 18s/step - loss: 0.0010 - mad: 0.0132 - mean_absolute_error: 0.0205 - rmse: 0.0288 - val_loss: 1.1748e-04 - val_mad: 5.9880e-04 - val_mean_absolute_error: 0.0108 - val_rmse: 0.0108 - learning_rate: 7.8125e-07
#
# Epoch 41: LearningRateScheduler setting learning rate to 3.906249901319825e-07.
# Epoch 41/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 139s 17s/step - loss: 5.7552e-04 - mad: 0.0088 - mean_absolute_error: 0.0189 - rmse: 0.0228 - val_loss: 1.1550e-04 - val_mad: 6.1994e-04 - val_mean_absolute_error: 0.0107 - val_rmse: 0.0107 - learning_rate: 3.9062e-07
#
# Epoch 42: LearningRateScheduler setting learning rate to 3.906249901319825e-07.
# Epoch 42/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 141s 18s/step - loss: 5.7510e-04 - mad: 0.0080 - mean_absolute_error: 0.0190 - rmse: 0.0223 - val_loss: 1.1361e-04 - val_mad: 6.4157e-04 - val_mean_absolute_error: 0.0106 - val_rmse: 0.0107 - learning_rate: 3.9062e-07
#
# Epoch 43: LearningRateScheduler setting learning rate to 3.906249901319825e-07.
# Epoch 43/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 140s 18s/step - loss: 3.0746e-04 - mad: 0.0059 - mean_absolute_error: 0.0154 - rmse: 0.0171 - val_loss: 1.1169e-04 - val_mad: 6.6331e-04 - val_mean_absolute_error: 0.0105 - val_rmse: 0.0106 - learning_rate: 3.9062e-07
#
# Epoch 44: LearningRateScheduler setting learning rate to 3.906249901319825e-07.
# Epoch 44/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 144s 18s/step - loss: 4.2525e-04 - mad: 0.0066 - mean_absolute_error: 0.0163 - rmse: 0.0189 - val_loss: 1.0972e-04 - val_mad: 6.8461e-04 - val_mean_absolute_error: 0.0104 - val_rmse: 0.0105 - learning_rate: 3.9062e-07
#
# Epoch 45: LearningRateScheduler setting learning rate to 3.906249901319825e-07.
# Epoch 45/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 140s 18s/step - loss: 7.0533e-04 - mad: 0.0094 - mean_absolute_error: 0.0191 - rmse: 0.0234 - val_loss: 1.0776e-04 - val_mad: 7.0658e-04 - val_mean_absolute_error: 0.0103 - val_rmse: 0.0104 - learning_rate: 3.9062e-07
#
# Epoch 46: LearningRateScheduler setting learning rate to 1.9531249506599124e-07.
# Epoch 46/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 143s 18s/step - loss: 0.0012 - mad: 0.0144 - mean_absolute_error: 0.0219 - rmse: 0.0306 - val_loss: 1.0584e-04 - val_mad: 7.2947e-04 - val_mean_absolute_error: 0.0103 - val_rmse: 0.0103 - learning_rate: 1.9531e-07
#
# Epoch 47: LearningRateScheduler setting learning rate to 1.9531249506599124e-07.
# Epoch 47/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 139s 17s/step - loss: 4.9390e-04 - mad: 0.0088 - mean_absolute_error: 0.0172 - rmse: 0.0210 - val_loss: 1.0394e-04 - val_mad: 7.5225e-04 - val_mean_absolute_error: 0.0102 - val_rmse: 0.0102 - learning_rate: 1.9531e-07
#
# Epoch 48: LearningRateScheduler setting learning rate to 1.9531249506599124e-07.
# Epoch 48/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 145s 18s/step - loss: 4.9625e-04 - mad: 0.0078 - mean_absolute_error: 0.0178 - rmse: 0.0204 - val_loss: 1.0202e-04 - val_mad: 7.7491e-04 - val_mean_absolute_error: 0.0101 - val_rmse: 0.0101 - learning_rate: 1.9531e-07
#
# Epoch 49: LearningRateScheduler setting learning rate to 1.9531249506599124e-07.
# Epoch 49/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 141s 18s/step - loss: 5.4949e-04 - mad: 0.0093 - mean_absolute_error: 0.0186 - rmse: 0.0227 - val_loss: 1.0011e-04 - val_mad: 7.9672e-04 - val_mean_absolute_error: 0.0100 - val_rmse: 0.0100 - learning_rate: 1.9531e-07
#
# Epoch 50: LearningRateScheduler setting learning rate to 1.9531249506599124e-07.
# Epoch 50/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 141s 18s/step - loss: 6.3851e-04 - mad: 0.0100 - mean_absolute_error: 0.0185 - rmse: 0.0231 - val_loss: 9.8148e-05 - val_mad: 8.1785e-04 - val_mean_absolute_error: 0.0099 - val_rmse: 0.0099 - learning_rate: 1.9531e-07
#
# Epoch 51: LearningRateScheduler setting learning rate to 9.765624753299562e-08.
# Epoch 51/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 140s 18s/step - loss: 5.6080e-04 - mad: 0.0081 - mean_absolute_error: 0.0182 - rmse: 0.0219 - val_loss: 9.6269e-05 - val_mad: 8.3860e-04 - val_mean_absolute_error: 0.0098 - val_rmse: 0.0098 - learning_rate: 9.7656e-08
#
# Epoch 52: LearningRateScheduler setting learning rate to 9.765624753299562e-08.
# Epoch 52/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 145s 18s/step - loss: 5.2787e-04 - mad: 0.0078 - mean_absolute_error: 0.0171 - rmse: 0.0204 - val_loss: 9.4384e-05 - val_mad: 8.5873e-04 - val_mean_absolute_error: 0.0097 - val_rmse: 0.0097 - learning_rate: 9.7656e-08
#
# Epoch 53: LearningRateScheduler setting learning rate to 9.765624753299562e-08.
# Epoch 53/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 139s 17s/step - loss: 6.3611e-04 - mad: 0.0091 - mean_absolute_error: 0.0200 - rmse: 0.0233 - val_loss: 9.2510e-05 - val_mad: 8.7767e-04 - val_mean_absolute_error: 0.0096 - val_rmse: 0.0096 - learning_rate: 9.7656e-08
#
# Epoch 54: LearningRateScheduler setting learning rate to 9.765624753299562e-08.
# Epoch 54/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 145s 18s/step - loss: 4.4371e-04 - mad: 0.0068 - mean_absolute_error: 0.0163 - rmse: 0.0187 - val_loss: 9.0648e-05 - val_mad: 8.9593e-04 - val_mean_absolute_error: 0.0095 - val_rmse: 0.0095 - learning_rate: 9.7656e-08
#
# Epoch 55: LearningRateScheduler setting learning rate to 9.765624753299562e-08.
# Epoch 55/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 139s 17s/step - loss: 7.0913e-04 - mad: 0.0107 - mean_absolute_error: 0.0190 - rmse: 0.0239 - val_loss: 8.8822e-05 - val_mad: 9.1347e-04 - val_mean_absolute_error: 0.0094 - val_rmse: 0.0094 - learning_rate: 9.7656e-08
#
# Epoch 56: LearningRateScheduler setting learning rate to 4.882812376649781e-08.
# Epoch 56/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 145s 18s/step - loss: 6.5375e-04 - mad: 0.0103 - mean_absolute_error: 0.0184 - rmse: 0.0239 - val_loss: 8.7006e-05 - val_mad: 9.2990e-04 - val_mean_absolute_error: 0.0093 - val_rmse: 0.0093 - learning_rate: 4.8828e-08
#
# Epoch 57: LearningRateScheduler setting learning rate to 4.882812376649781e-08.
# Epoch 57/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 141s 18s/step - loss: 6.0718e-04 - mad: 0.0088 - mean_absolute_error: 0.0188 - rmse: 0.0228 - val_loss: 8.5241e-05 - val_mad: 9.4868e-04 - val_mean_absolute_error: 0.0092 - val_rmse: 0.0092 - learning_rate: 4.8828e-08
#
# Epoch 58: LearningRateScheduler setting learning rate to 4.882812376649781e-08.
# Epoch 58/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 140s 18s/step - loss: 3.8377e-04 - mad: 0.0074 - mean_absolute_error: 0.0161 - rmse: 0.0190 - val_loss: 8.3552e-05 - val_mad: 9.6832e-04 - val_mean_absolute_error: 0.0091 - val_rmse: 0.0091 - learning_rate: 4.8828e-08
#
# Epoch 59: LearningRateScheduler setting learning rate to 4.882812376649781e-08.
# Epoch 59/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 140s 18s/step - loss: 6.1714e-04 - mad: 0.0094 - mean_absolute_error: 0.0193 - rmse: 0.0238 - val_loss: 8.1868e-05 - val_mad: 9.8741e-04 - val_mean_absolute_error: 0.0090 - val_rmse: 0.0090 - learning_rate: 4.8828e-08
#
# Epoch 60: LearningRateScheduler setting learning rate to 4.882812376649781e-08.
# Epoch 60/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 140s 18s/step - loss: 7.7524e-04 - mad: 0.0108 - mean_absolute_error: 0.0205 - rmse: 0.0252 - val_loss: 8.0206e-05 - val_mad: 0.0010 - val_mean_absolute_error: 0.0089 - val_rmse: 0.0090 - learning_rate: 4.8828e-08

# %%
# Evaluate the model on the test data
evaluation = model.evaluate(features_test, labels_test)

# Print the evaluation results with four decimal places
print(f"Evaluation Loss (MSE): {evaluation[0]:.5f}")
print(f"Evaluation MAE: {evaluation[1]:.5f}")
print(f"Evaluation RMSE: {evaluation[2]:.5f}")
print(f"Evaluation MAD: {evaluation[3]:.5f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step - loss: 8.0206e-05 - mad: 9.8931e-04 - mean_absolute_error: 0.0089 - rmse: 0.0090
# Evaluation Loss (MSE): 0.00008
# Evaluation MAE: 0.00887
# Evaluation RMSE: 0.00896
# Evaluation MAD: 0.00099

# %%
# Plot the Train loss and validation loss
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss and validation loss')
plt.xlabel('Epoch')
plt.ylabel('Metric Value')
plt.legend()
plt.show()

# %%
# Plot the train rmse and validation rmse
plt.figure(figsize=(12, 6))
plt.plot(history.history['rmse'], label='Train RMSE')
plt.plot(history.history['val_rmse'], label='Validation RMSE')
plt.title('Train RMSE Vs Validation RMSE')
plt.xlabel('Epoch')
plt.ylabel('Metric Value')
plt.legend()
plt.show()

# %%
# Plot the tain MAD and validation MAD
plt.figure(figsize=(12, 6))
plt.plot(history.history['mad'], label='Train MAD')
plt.plot(history.history['val_mad'], label='Validation MAD')
plt.title('Train MAD Vs Validation MAD')
plt.xlabel('Epoch')
plt.ylabel('Metric Value')
plt.legend()
plt.show()

# %%
model.save('Conv3d(E08).h5')

# %%
import os
import cv2
import numpy as np

# Function to save all split videos from the test set to a folder
def save_all_split_videos(video_data, save_dir, SEQUENCE_LENGTH=16, IMAGE_HEIGHT=64, IMAGE_WIDTH=64, fps=30):
    """
    Save all split videos from the video data as individual video files in the specified directory.

    Args:
        video_data: Numpy array containing video data of shape (num_videos, SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3).
        save_dir: Directory to save the videos.
        SEQUENCE_LENGTH: Number of frames per video (default is 16).
        IMAGE_HEIGHT: Height of the frames (default is 64).
        IMAGE_WIDTH: Width of the frames (default is 64).
        fps: Frames per second for the output videos (default is 30).
    """
    # Create the save directory if it doesn't exist
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    # Iterate over all videos in the dataset
    for video_index in range(video_data.shape[0]):
        video_frames = video_data[video_index]  # Shape: (SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3)

        # Prepare the VideoWriter object to save the video
        video_filename = os.path.join(save_dir, f"split_video_{video_index + 1}.mp4")
        fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Use 'mp4v' for .mp4 format
        video_writer = cv2.VideoWriter(video_filename, fourcc, fps, (IMAGE_WIDTH, IMAGE_HEIGHT))

        # Add frames to the video
        for frame in video_frames:
            # Ensure the frame has values in the range [0, 255] and convert to uint8
            frame_rgb = (frame * 255).astype(np.uint8)
            # Convert RGB to BGR for OpenCV
            frame_bgr = cv2.cvtColor(frame_rgb, cv2.COLOR_RGB2BGR)
            # Write the frame to the video
            video_writer.write(frame_bgr)

        # Release the video writer
        video_writer.release()
        print(f"Video {video_index + 1} saved to: {video_filename}")

# Example usage: Save all split videos from the test set
# Make sure `features_test` is defined before calling this function
save_all_split_videos(features_test, save_dir="/kaggle/working/split_videos")
# Out:
# Video 1 saved to: /kaggle/working/split_videos/split_video_1.mp4
# Video 2 saved to: /kaggle/working/split_videos/split_video_2.mp4
# Video 3 saved to: /kaggle/working/split_videos/split_video_3.mp4
# Video 4 saved to: /kaggle/working/split_videos/split_video_4.mp4
# Video 5 saved to: /kaggle/working/split_videos/split_video_5.mp4
# Video 6 saved to: /kaggle/working/split_videos/split_video_6.mp4
# Video 7 saved to: /kaggle/working/split_videos/split_video_7.mp4
# Video 8 saved to: /kaggle/working/split_videos/split_video_8.mp4
# Video 9 saved to: /kaggle/working/split_videos/split_video_9.mp4
# Video 10 saved to: /kaggle/working/split_videos/split_video_10.mp4
# Video 11 saved to: /kaggle/working/split_videos/split_video_11.mp4
# Video 12 saved to: /kaggle/working/split_videos/split_video_12.mp4
# Video 13 saved to: /kaggle/working/split_videos/split_video_13.mp4
# Video 14 saved to: /kaggle/working/split_videos/split_video_14.mp4
# Video 15 saved to: /kaggle/working/split_videos/split_video_15.mp4
# Video 16 saved to: /kaggle/working/split_videos/split_video_16.mp4

# %%
# Example prediction for a new video
video_path = '/kaggle/working/split_videos/split_video_1.mp4'

# Assuming `process_video` function is implemented, use it to preprocess the video input
def process_video(video_path):
    # Example: Preprocessing video to match the input shape of (SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3)
    # You should implement this based on your dataset and requirements
    video_data = np.random.random((SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3))  # Replace with real video processing code
    return np.expand_dims(video_data, axis=0)  # Expand dims to add batch dimension

# Predict for a new video
predicted_score = model.predict(process_video(video_path))
scaled_score = predicted_score * 99 + 1
print(f"Predicted Score: {scaled_score[0][0]:.2f}")  # Assuming `predicted_score` is a 2D array
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 575ms/step
# Predicted Score: 31.90
