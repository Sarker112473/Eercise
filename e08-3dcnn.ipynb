# %%
import os
import shutil
import cv2
import math
import random
import numpy as np
import tensorflow as tf
from tensorflow import keras
from collections import deque
import matplotlib.pyplot as plt
plt.style.use("seaborn")
import tqdm
# %matplotlib inline
from tensorflow.keras import Model
from sklearn.model_selection import train_test_split
from keras.applications.mobilenet_v2 import MobileNetV2
from keras.layers import *
from keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.utils import plot_model

from IPython.display import HTML
from base64 import b64encode
from tensorflow.keras.layers import Input,Dense, Flatten, ReLU, Conv2D, DepthwiseConv2D,AvgPool2D, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.optimizers import Adam
import keras.backend as K
from typing import Optional
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings('ignore')
# Out:
# /tmp/ipykernel_30/1542781770.py:11: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
IMAGE_HEIGHT, IMAGE_WIDTH = 128, 128
SEQUENCE_LENGTH = 30

# %%
CLASSES_LIST = ["E08(Both_Leg_Flexion)"]

# %%
def frames_extraction(video_path):
    frames_list = []
    video_reader = cv2.VideoCapture(video_path)
    video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))
    skip_frames_window = max(int(video_frames_count/SEQUENCE_LENGTH), 1)

    for frame_counter in range(SEQUENCE_LENGTH):
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)
        success, frame = video_reader.read()

        if not success:
            break

        resized_frame = cv2.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))
        normalized_frame = resized_frame / 255
        frames_list.append(normalized_frame)

    video_reader.release()
    return frames_list

# %%
def create_dataset(video_dir, csv_file_path):
    features = []
    labels = []
    video_files_paths = []
    matching_files_count = 0

    # Read the CSV file
    csv_data = pd.read_csv(csv_file_path)

    for class_index, class_name in enumerate(CLASSES_LIST):
        print(f'Extracting Data of Class: {class_name}')
        files_list = os.listdir(os.path.join(video_dir, class_name))

        for file_name in files_list:
            # Remove the .mp4 extension from the file name
            video_name = os.path.splitext(file_name)[0]

            video_file_path = os.path.join(video_dir, class_name, file_name)
            frames = frames_extraction(video_file_path)

            if len(frames) == SEQUENCE_LENGTH:
                # Search for the exercise name in the CSV data that matches with video file name
                matching_row = csv_data[csv_data['Excercise Name'].str.lower() == video_name.lower()]

                if not matching_row.empty:
                    assessment_score = matching_row['Assessment Score'].values[0]
                    features.append(frames)
                    labels.append(class_index)
                    video_files_paths.append(video_file_path)
                    matching_files_count += 1
                    print(f'Matched file: {video_name}, Assessment Score: {assessment_score}')
                else:
                    # Append None if no matching row is found
                    features.append(frames)
                    labels.append(class_index)
                    video_files_paths.append(video_file_path)
                    print(f'No matching row found for file: {video_name}')

    features = np.asarray(features)
    labels = np.asarray(labels)

    print(f'Total matching files: {matching_files_count}')

    return features, labels, matching_files_count, video_files_paths

# %%
import pandas as pd

video_dir = '/kaggle/input/regression-folders/dataset_regression'
csv_file_path = '/kaggle/input/csv-files-regression/Ex_08_sub.csv'
features, labels, matching_files_count, video_files_paths =  create_dataset(video_dir, csv_file_path)
print("Features shape:", features.shape)
print("Labels shape:", labels.shape)
print("Matching files count:", matching_files_count)
print("Number of video files:", len(video_files_paths))
# Out:
# Extracting Data of Class: E08(Both_Leg_Flexion)
# Matched file: E08_P04_AL_VML_GM, Assessment Score: 81.9
# Matched file: E08_P42_AF_VO_GM, Assessment Score: 16.67
# Matched file: E08_P21_AR_VLL_GM, Assessment Score: 84.29
# Matched file: E08_P50_AR_VFL_GM, Assessment Score: 47.62
# Matched file: E08_P04_AF_VML_GM, Assessment Score: 97.62
# Matched file: E08_P47_AF_VML_GM, Assessment Score: 60.0
# Matched file: E08_P22_AL_VLL_GM, Assessment Score: 78.57
# Matched file: E08_P02_AR_VFL_GM, Assessment Score: 82.86
# Matched file: E08_P04_AF_VHJ_GM, Assessment Score: 83.33
# Matched file: E08_P31_AF_VO_GM, Assessment Score: 19.05
# Matched file: E08_P21_AL_VFL_GM, Assessment Score: 67.14
# Matched file: E08_P45_AF_VML_GM, Assessment Score: 52.86
# Matched file: E08_P28_AL_VFL_GM, Assessment Score: 39.52
# Matched file: E08_P48_AF_VFL_GM, Assessment Score: 33.33
# Matched file: E08_P27_AR_VFL_GM, Assessment Score: 47.62
# Matched file: E08_P07_AR_VML_GM, Assessment Score: 80.48
# Matched file: E08_P32_AF_VO_GM, Assessment Score: 34.76
# Matched file: E08_P27_AF_VFL_GM, Assessment Score: 58.57
# Matched file: E08_P22_AF_VML_GM, Assessment Score: 97.62
# Matched file: E08_P08_AF_VHJ_GM, Assessment Score: 85.71
# Matched file: E08_P47_AL_VFL_GM, Assessment Score: 57.62
# Matched file: E08_P38_AR_VFL_GM, Assessment Score: 9.52
# Matched file: E08_P47_AF_VLJ_GM, Assessment Score: 56.19
# Matched file: E08_P29_AF_VLR_GM, Assessment Score: 0.0
# Matched file: E08_P48_AR_VFL_GM, Assessment Score: 50.48
# Matched file: E08_P04_AL_VFL_GM, Assessment Score: 95.24
# Matched file: E08_P29_AR_VFL_GM, Assessment Score: 14.29
# Matched file: E08_P04_AF_VFL_GM, Assessment Score: 76.67
# Matched file: E08_P48_AL_VFL_GM, Assessment Score: 49.05
# Matched file: E08_P35_AF_VLJ_GM, Assessment Score: 21.43
# Matched file: E08_P35_AF_VLL_GM, Assessment Score: 32.38
# Matched file: E08_P04_AR_VFL_GM, Assessment Score: 95.24
# Matched file: E08_P38_AF_VLL_GM, Assessment Score: 9.52
# Matched file: E08_P07_AL_VML_GM, Assessment Score: 79.05
# Matched file: E08_P27_AF_VLR_GM, Assessment Score: 51.43
# Matched file: E08_P50_AL_VFL_GM, Assessment Score: 45.24
# Matched file: E08_P28_AF_VLL_GM, Assessment Score: 28.57
# Matched file: E08_P08_AF_VLJ_GM, Assessment Score: 69.05
# Matched file: E08_P38_AF_VFL_GM, Assessment Score: 4.76
# Matched file: E08_P46_AF_VFL_GM, Assessment Score: 55.24
# Matched file: E08_P22_AR_VLL_GM, Assessment Score: 80.0
# Matched file: E08_P47_AF_VHJ_GM, Assessment Score: 56.19
# Matched file: E08_P38_AF_VLJ_GM, Assessment Score: 9.52
# Matched file: E08_P21_AF_VFL_GM, Assessment Score: 67.14
# Matched file: E08_P08_AR_VML_GM, Assessment Score: 78.1
# Matched file: E08_P28_AF_VML_GM, Assessment Score: 39.52
# Matched file: E08_P07_AR_VLL_GM, Assessment Score: 81.9
# Matched file: E08_P42_AL_VFL_GM, Assessment Score: 16.67
# Matched file: E08_P35_AF_VFL_GM, Assessment Score: 21.43
# Matched file: E08_P32_AF_VLL_GM, Assessment Score: 34.76
# Matched file: E08_P04_AR_VHJ_GM, Assessment Score: 67.62
# Matched file: E08_P18_AR_VFL_GM, Assessment Score: 100.0
# Matched file: E08_P22_AF_VLL_GM, Assessment Score: 80.0
# Matched file: E08_P46_AL_VFL_GM, Assessment Score: 55.24
# Matched file: E08_P47_AF_VFL_GM, Assessment Score: 50.0
# Matched file: E08_P08_AR_VLJ_GM, Assessment Score: 69.05
# Matched file: E08_P48_AF_VML_GM, Assessment Score: 40.48
# Matched file: E08_P04_AL_VHJ_GM, Assessment Score: 67.62
# Matched file: E08_P38_AF_VHJ_GM, Assessment Score: 4.76
# Matched file: E08_P23_AF_VO_GM, Assessment Score: 81.43
# Matched file: E08_P21_AR_VFL_GM, Assessment Score: 65.71
# Matched file: E08_P49_AF_VHJ_GM, Assessment Score: 58.57
# Matched file: E08_P27_AF_VLJ_GM, Assessment Score: 52.38
# Matched file: E08_P08_AF_VML_GM, Assessment Score: 79.52
# Matched file: E08_P35_AF_VLR_GM, Assessment Score: 28.57
# Matched file: E08_P29_AF_VFL_GM, Assessment Score: 0.0
# Matched file: E08_P08_AL_VML_GM, Assessment Score: 78.1
# Matched file: E08_P45_AF_VFL_GM, Assessment Score: 48.1
# Matched file: E08_P42_AF_VHJ_GM, Assessment Score: 19.05
# Matched file: E08_P35_AF_VHJ_GM, Assessment Score: 2.38
# Matched file: E08_P49_AF_VML_GM, Assessment Score: 60.0
# Matched file: E08_P37_AF_VML_GM, Assessment Score: 23.81
# Matched file: E08_P02_AF_VFL_GM, Assessment Score: 82.86
# Matched file: E08_P06_AF_VML_GM, Assessment Score: 100.0
# Matched file: E08_P21_AR_VML_GM, Assessment Score: 84.29
# Matched file: E08_P08_AR_VHJ_GM, Assessment Score: 70.0
# Matched file: E08_P37_AF_VLL_GM, Assessment Score: 23.81
# Matched file: E08_P07_AF_VML_GM, Assessment Score: 80.48
# Matched file: E08_P42_AF_VLR_GM, Assessment Score: 19.05
# Matched file: E08_P22_AL_VFL_GM, Assessment Score: 70.0
# Total matching files: 80
# Features shape: (80, 30, 128, 128, 3)
# Labels shape: (80,)
# Matching files count: 80
# Number of video files: 80

# %%
np.save("features.npy", features)
np.save("labels.npy", labels)
np.save("video_files_paths.npy", video_files_paths)

# %%
features, labels, video_files_paths = np.load("features.npy"), np.load("labels.npy"), np.load("video_files_paths.npy")

# %%
print(f'Number of features: {len(features)}, Number of labels: {len(labels)}, Number of video_files_paths: {len(video_files_paths)}')
# Out:
# Number of features: 80, Number of labels: 80, Number of video_files_paths: 80

# %%
features_train, features_test, labels_train, labels_test = train_test_split(
    features, labels, test_size=0.20, shuffle=True, random_state=42
)

print(f"Training features: {features_train.shape}, Training labels: {labels_train.shape}")
print(f"Testing features: {features_test.shape}, Testing labels: {labels_test.shape}")
# Out:
# Training features: (64, 30, 128, 128, 3), Training labels: (64,)
# Testing features: (16, 30, 128, 128, 3), Testing labels: (16,)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler, ModelCheckpoint
import matplotlib.pyplot as plt
import numpy as np

# Define custom metrics: RMSE and MAD
def rmse(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)  # Ensure y_true is float32
    return tf.sqrt(tf.reduce_mean(tf.square(y_pred - y_true)))

def mad(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)  # Ensure y_true is float32
    return tf.reduce_mean(tf.abs(y_pred - tf.reduce_mean(y_pred)))

# Define the 3D CNN model
def create_3d_cnn_model(SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH):
    """
    A 3D CNN model for spatiotemporal feature extraction and regression.
    """
    # Define the video input (4D input for 3D CNN)
    video_input = layers.Input(shape=(SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3))
    
    # 3D CNN layers for spatiotemporal feature extraction
    x = layers.Conv3D(32, (3, 3, 3), padding='same', activation='relu')(video_input)
    x = layers.MaxPooling3D((2, 2, 2))(x)
    x = layers.Dropout(0.4)(x)
    x = layers.BatchNormalization()(x)
    
    x = layers.Conv3D(64, (3, 3, 3), padding='same', activation='relu')(x)
    x = layers.MaxPooling3D((2, 2, 2))(x)
    x = layers.Dropout(0.4)(x)
    x = layers.BatchNormalization()(x)
    
    x = layers.Conv3D(128, (3, 3, 3), padding='same', activation='relu')(x)
    x = layers.MaxPooling3D((2, 2, 2))(x)
    x = layers.Dropout(0.4)(x)
    x = layers.BatchNormalization()(x)

    # Flatten the output of the 3D CNN
    x = layers.GlobalAveragePooling3D()(x)

    # Dense layer for regression output
    regression_output = layers.Dense(1, activation='sigmoid', name='regression_output')(x)
    
    # Build the model
    model = models.Model(inputs=video_input, outputs=[regression_output])
    model.summary()
    
    return model

# %%
# Define hyperparameters
SEQUENCE_LENGTH = 30  # Set according to your input data
IMAGE_HEIGHT = 128  # Set the height of your input images
IMAGE_WIDTH = 128  # Set the width of your input images

# Create the model
model = create_3d_cnn_model(SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 30, 128, 128,   │             0 │
# │                                 │ 3)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d (Conv3D)                 │ (None, 30, 128, 128,   │         2,624 │
# │                                 │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d (MaxPooling3D)    │ (None, 15, 64, 64, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 15, 64, 64, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 15, 64, 64, 32) │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_1 (Conv3D)               │ (None, 15, 64, 64, 64) │        55,360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_1 (MaxPooling3D)  │ (None, 7, 32, 32, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 7, 32, 32, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 7, 32, 32, 64)  │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_2 (Conv3D)               │ (None, 7, 32, 32, 128) │       221,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_2 (MaxPooling3D)  │ (None, 3, 16, 16, 128) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 3, 16, 16, 128) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 3, 16, 16, 128) │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling3d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling3D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ regression_output (Dense)       │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 280,321 (1.07 MB)
#  Trainable params: 279,873 (1.07 MB)
#  Non-trainable params: 448 (1.75 KB)

# %%
# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='mean_squared_error',  # Use MSE for regression
              metrics=['mean_absolute_error', rmse, mad])

# Define Early Stopping and Learning Rate Scheduler callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

lr_scheduler = LearningRateScheduler(lambda epoch, lr: lr * 0.5 if epoch % 10 == 0 and epoch > 0 else lr, verbose=1)



# Callbacks list
callbacks = [early_stopping, lr_scheduler]
# Train the model
history = model.fit(features_train, labels_train,
                    validation_data=(features_test, labels_test),
                    epochs=60, batch_size=8, verbose=1, 
                    callbacks=callbacks)
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 1/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 149s 18s/step - loss: 0.2501 - mad: 0.0225 - mean_absolute_error: 0.4992 - rmse: 0.5001 - val_loss: 0.2309 - val_mad: 0.0016 - val_mean_absolute_error: 0.4805 - val_rmse: 0.4805 - learning_rate: 1.0000e-04
#
# Epoch 2: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 2/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 136s 17s/step - loss: 0.2477 - mad: 0.0293 - mean_absolute_error: 0.4962 - rmse: 0.4977 - val_loss: 0.2162 - val_mad: 0.0042 - val_mean_absolute_error: 0.4649 - val_rmse: 0.4650 - learning_rate: 1.0000e-04
#
# Epoch 3: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 3/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 141s 17s/step - loss: 0.2451 - mad: 0.0331 - mean_absolute_error: 0.4932 - rmse: 0.4950 - val_loss: 0.1795 - val_mad: 0.0024 - val_mean_absolute_error: 0.4236 - val_rmse: 0.4236 - learning_rate: 1.0000e-04
#
# Epoch 4: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 4/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 144s 18s/step - loss: 0.2423 - mad: 0.0341 - mean_absolute_error: 0.4902 - rmse: 0.4923 - val_loss: 0.2168 - val_mad: 0.0048 - val_mean_absolute_error: 0.4655 - val_rmse: 0.4656 - learning_rate: 1.0000e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 5/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 138s 17s/step - loss: 0.2385 - mad: 0.0249 - mean_absolute_error: 0.4872 - rmse: 0.4884 - val_loss: 0.1837 - val_mad: 0.0015 - val_mean_absolute_error: 0.4286 - val_rmse: 0.4286 - learning_rate: 1.0000e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 6/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 136s 17s/step - loss: 0.2348 - mad: 0.0147 - mean_absolute_error: 0.4841 - rmse: 0.4846 - val_loss: 0.2106 - val_mad: 0.0026 - val_mean_absolute_error: 0.4589 - val_rmse: 0.4589 - learning_rate: 1.0000e-04
#
# Epoch 7: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 7/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 143s 18s/step - loss: 0.2316 - mad: 0.0103 - mean_absolute_error: 0.4811 - rmse: 0.4813 - val_loss: 0.1869 - val_mad: 0.0017 - val_mean_absolute_error: 0.4324 - val_rmse: 0.4324 - learning_rate: 1.0000e-04
#
# Epoch 8: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 8/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 142s 18s/step - loss: 0.2287 - mad: 0.0099 - mean_absolute_error: 0.4780 - rmse: 0.4782 - val_loss: 0.1945 - val_mad: 0.0024 - val_mean_absolute_error: 0.4410 - val_rmse: 0.4410 - learning_rate: 1.0000e-04
#
# Epoch 9: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 9/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 136s 17s/step - loss: 0.2257 - mad: 0.0108 - mean_absolute_error: 0.4749 - rmse: 0.4751 - val_loss: 0.1982 - val_mad: 0.0025 - val_mean_absolute_error: 0.4452 - val_rmse: 0.4452 - learning_rate: 1.0000e-04
#
# Epoch 10: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 10/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 138s 17s/step - loss: 0.2226 - mad: 0.0074 - mean_absolute_error: 0.4717 - rmse: 0.4718 - val_loss: 0.1897 - val_mad: 0.0025 - val_mean_absolute_error: 0.4355 - val_rmse: 0.4355 - learning_rate: 1.0000e-04
#
# Epoch 11: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 11/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 139s 18s/step - loss: 0.2201 - mad: 0.0107 - mean_absolute_error: 0.4689 - rmse: 0.4691 - val_loss: 0.1979 - val_mad: 0.0030 - val_mean_absolute_error: 0.4448 - val_rmse: 0.4449 - learning_rate: 5.0000e-05
#
# Epoch 12: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 12/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 144s 18s/step - loss: 0.2186 - mad: 0.0111 - mean_absolute_error: 0.4673 - rmse: 0.4675 - val_loss: 0.1941 - val_mad: 0.0032 - val_mean_absolute_error: 0.4405 - val_rmse: 0.4405 - learning_rate: 5.0000e-05
#
# Epoch 13: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 13/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 140s 18s/step - loss: 0.2170 - mad: 0.0107 - mean_absolute_error: 0.4657 - rmse: 0.4659 - val_loss: 0.1683 - val_mad: 0.0031 - val_mean_absolute_error: 0.4102 - val_rmse: 0.4102 - learning_rate: 5.0000e-05
#
# Epoch 14: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 14/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 138s 17s/step - loss: 0.2156 - mad: 0.0135 - mean_absolute_error: 0.4641 - rmse: 0.4643 - val_loss: 0.1712 - val_mad: 0.0035 - val_mean_absolute_error: 0.4138 - val_rmse: 0.4138 - learning_rate: 5.0000e-05
#
# Epoch 15: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 15/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 143s 18s/step - loss: 0.2141 - mad: 0.0124 - mean_absolute_error: 0.4624 - rmse: 0.4627 - val_loss: 0.1786 - val_mad: 0.0040 - val_mean_absolute_error: 0.4226 - val_rmse: 0.4226 - learning_rate: 5.0000e-05
#
# Epoch 16: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 16/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 144s 18s/step - loss: 0.2124 - mad: 0.0085 - mean_absolute_error: 0.4608 - rmse: 0.4609 - val_loss: 0.1612 - val_mad: 0.0038 - val_mean_absolute_error: 0.4014 - val_rmse: 0.4014 - learning_rate: 5.0000e-05
#
# Epoch 17: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 17/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 143s 18s/step - loss: 0.2109 - mad: 0.0099 - mean_absolute_error: 0.4591 - rmse: 0.4592 - val_loss: 0.1859 - val_mad: 0.0045 - val_mean_absolute_error: 0.4311 - val_rmse: 0.4312 - learning_rate: 5.0000e-05
#
# Epoch 18: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 18/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 138s 17s/step - loss: 0.2094 - mad: 0.0094 - mean_absolute_error: 0.4574 - rmse: 0.4576 - val_loss: 0.1726 - val_mad: 0.0042 - val_mean_absolute_error: 0.4154 - val_rmse: 0.4154 - learning_rate: 5.0000e-05
#
# Epoch 19: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 19/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 144s 18s/step - loss: 0.2078 - mad: 0.0092 - mean_absolute_error: 0.4557 - rmse: 0.4558 - val_loss: 0.1968 - val_mad: 0.0048 - val_mean_absolute_error: 0.4436 - val_rmse: 0.4436 - learning_rate: 5.0000e-05
#
# Epoch 20: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 20/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 137s 17s/step - loss: 0.2063 - mad: 0.0117 - mean_absolute_error: 0.4540 - rmse: 0.4542 - val_loss: 0.1669 - val_mad: 0.0047 - val_mean_absolute_error: 0.4084 - val_rmse: 0.4085 - learning_rate: 5.0000e-05
#
# Epoch 21: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 21/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 147s 18s/step - loss: 0.2049 - mad: 0.0091 - mean_absolute_error: 0.4525 - rmse: 0.4526 - val_loss: 0.1691 - val_mad: 0.0051 - val_mean_absolute_error: 0.4111 - val_rmse: 0.4112 - learning_rate: 2.5000e-05
#
# Epoch 22: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 22/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 137s 17s/step - loss: 0.2041 - mad: 0.0102 - mean_absolute_error: 0.4516 - rmse: 0.4518 - val_loss: 0.1790 - val_mad: 0.0054 - val_mean_absolute_error: 0.4231 - val_rmse: 0.4231 - learning_rate: 2.5000e-05
#
# Epoch 23: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 23/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 144s 18s/step - loss: 0.2033 - mad: 0.0088 - mean_absolute_error: 0.4508 - rmse: 0.4509 - val_loss: 0.1625 - val_mad: 0.0055 - val_mean_absolute_error: 0.4031 - val_rmse: 0.4031 - learning_rate: 2.5000e-05
#
# Epoch 24: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 24/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 137s 17s/step - loss: 0.2026 - mad: 0.0110 - mean_absolute_error: 0.4499 - rmse: 0.4501 - val_loss: 0.1713 - val_mad: 0.0059 - val_mean_absolute_error: 0.4138 - val_rmse: 0.4139 - learning_rate: 2.5000e-05
#
# Epoch 25: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 25/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 136s 17s/step - loss: 0.2017 - mad: 0.0069 - mean_absolute_error: 0.4490 - rmse: 0.4491 - val_loss: 0.1604 - val_mad: 0.0061 - val_mean_absolute_error: 0.4004 - val_rmse: 0.4005 - learning_rate: 2.5000e-05
#
# Epoch 26: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 26/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 152s 18s/step - loss: 0.2010 - mad: 0.0100 - mean_absolute_error: 0.4481 - rmse: 0.4483 - val_loss: 0.1639 - val_mad: 0.0065 - val_mean_absolute_error: 0.4047 - val_rmse: 0.4048 - learning_rate: 2.5000e-05
#
# Epoch 27: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 27/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 144s 18s/step - loss: 0.2002 - mad: 0.0094 - mean_absolute_error: 0.4473 - rmse: 0.4474 - val_loss: 0.1717 - val_mad: 0.0069 - val_mean_absolute_error: 0.4142 - val_rmse: 0.4143 - learning_rate: 2.5000e-05
#
# Epoch 28: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 28/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 139s 17s/step - loss: 0.1994 - mad: 0.0108 - mean_absolute_error: 0.4464 - rmse: 0.4466 - val_loss: 0.1611 - val_mad: 0.0072 - val_mean_absolute_error: 0.4013 - val_rmse: 0.4014 - learning_rate: 2.5000e-05
#
# Epoch 29: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 29/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 136s 17s/step - loss: 0.1986 - mad: 0.0095 - mean_absolute_error: 0.4455 - rmse: 0.4457 - val_loss: 0.1774 - val_mad: 0.0077 - val_mean_absolute_error: 0.4211 - val_rmse: 0.4212 - learning_rate: 2.5000e-05
#
# Epoch 30: LearningRateScheduler setting learning rate to 2.499999936844688e-05.
# Epoch 30/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 142s 17s/step - loss: 0.1978 - mad: 0.0097 - mean_absolute_error: 0.4446 - rmse: 0.4448 - val_loss: 0.1772 - val_mad: 0.0082 - val_mean_absolute_error: 0.4208 - val_rmse: 0.4210 - learning_rate: 2.5000e-05
#
# Epoch 31: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 31/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 149s 18s/step - loss: 0.1972 - mad: 0.0109 - mean_absolute_error: 0.4438 - rmse: 0.4440 - val_loss: 0.1615 - val_mad: 0.0081 - val_mean_absolute_error: 0.4017 - val_rmse: 0.4018 - learning_rate: 1.2500e-05
#
# Epoch 32: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 32/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 143s 18s/step - loss: 0.1967 - mad: 0.0100 - mean_absolute_error: 0.4434 - rmse: 0.4435 - val_loss: 0.1694 - val_mad: 0.0084 - val_mean_absolute_error: 0.4114 - val_rmse: 0.4116 - learning_rate: 1.2500e-05
#
# Epoch 33: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 33/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 138s 17s/step - loss: 0.1963 - mad: 0.0088 - mean_absolute_error: 0.4429 - rmse: 0.4431 - val_loss: 0.1747 - val_mad: 0.0087 - val_mean_absolute_error: 0.4177 - val_rmse: 0.4179 - learning_rate: 1.2500e-05
#
# Epoch 34: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 34/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 137s 17s/step - loss: 0.1959 - mad: 0.0112 - mean_absolute_error: 0.4425 - rmse: 0.4427 - val_loss: 0.1584 - val_mad: 0.0085 - val_mean_absolute_error: 0.3978 - val_rmse: 0.3980 - learning_rate: 1.2500e-05
#
# Epoch 35: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 35/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 146s 18s/step - loss: 0.1955 - mad: 0.0067 - mean_absolute_error: 0.4420 - rmse: 0.4421 - val_loss: 0.1491 - val_mad: 0.0086 - val_mean_absolute_error: 0.3859 - val_rmse: 0.3861 - learning_rate: 1.2500e-05
#
# Epoch 36: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 36/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 137s 17s/step - loss: 0.1951 - mad: 0.0087 - mean_absolute_error: 0.4416 - rmse: 0.4417 - val_loss: 0.1574 - val_mad: 0.0090 - val_mean_absolute_error: 0.3965 - val_rmse: 0.3968 - learning_rate: 1.2500e-05
#
# Epoch 37: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 37/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 144s 17s/step - loss: 0.1947 - mad: 0.0094 - mean_absolute_error: 0.4411 - rmse: 0.4413 - val_loss: 0.1746 - val_mad: 0.0096 - val_mean_absolute_error: 0.4176 - val_rmse: 0.4178 - learning_rate: 1.2500e-05
#
# Epoch 38: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 38/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 136s 17s/step - loss: 0.1944 - mad: 0.0103 - mean_absolute_error: 0.4407 - rmse: 0.4409 - val_loss: 0.1632 - val_mad: 0.0098 - val_mean_absolute_error: 0.4037 - val_rmse: 0.4040 - learning_rate: 1.2500e-05
#
# Epoch 39: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 39/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 138s 17s/step - loss: 0.1939 - mad: 0.0091 - mean_absolute_error: 0.4402 - rmse: 0.4403 - val_loss: 0.1651 - val_mad: 0.0102 - val_mean_absolute_error: 0.4060 - val_rmse: 0.4063 - learning_rate: 1.2500e-05
#
# Epoch 40: LearningRateScheduler setting learning rate to 1.249999968422344e-05.
# Epoch 40/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 136s 17s/step - loss: 0.1937 - mad: 0.0126 - mean_absolute_error: 0.4398 - rmse: 0.4401 - val_loss: 0.1628 - val_mad: 0.0105 - val_mean_absolute_error: 0.4031 - val_rmse: 0.4035 - learning_rate: 1.2500e-05
#
# Epoch 41: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 41/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 140s 18s/step - loss: 0.1931 - mad: 0.0082 - mean_absolute_error: 0.4394 - rmse: 0.4395 - val_loss: 0.1612 - val_mad: 0.0107 - val_mean_absolute_error: 0.4011 - val_rmse: 0.4015 - learning_rate: 6.2500e-06
#
# Epoch 42: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 42/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 136s 17s/step - loss: 0.1930 - mad: 0.0110 - mean_absolute_error: 0.4392 - rmse: 0.4394 - val_loss: 0.1640 - val_mad: 0.0111 - val_mean_absolute_error: 0.4046 - val_rmse: 0.4050 - learning_rate: 6.2500e-06
#
# Epoch 43: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 43/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 146s 18s/step - loss: 0.1928 - mad: 0.0091 - mean_absolute_error: 0.4389 - rmse: 0.4391 - val_loss: 0.1675 - val_mad: 0.0114 - val_mean_absolute_error: 0.4089 - val_rmse: 0.4093 - learning_rate: 6.2500e-06
#
# Epoch 44: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 44/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 137s 17s/step - loss: 0.1926 - mad: 0.0112 - mean_absolute_error: 0.4387 - rmse: 0.4389 - val_loss: 0.1655 - val_mad: 0.0117 - val_mean_absolute_error: 0.4065 - val_rmse: 0.4069 - learning_rate: 6.2500e-06
#
# Epoch 45: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 45/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 139s 17s/step - loss: 0.1924 - mad: 0.0101 - mean_absolute_error: 0.4385 - rmse: 0.4386 - val_loss: 0.1653 - val_mad: 0.0119 - val_mean_absolute_error: 0.4062 - val_rmse: 0.4066 - learning_rate: 6.2500e-06
#
# Epoch 46: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 46/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 142s 18s/step - loss: 0.1922 - mad: 0.0095 - mean_absolute_error: 0.4382 - rmse: 0.4384 - val_loss: 0.1664 - val_mad: 0.0121 - val_mean_absolute_error: 0.4074 - val_rmse: 0.4079 - learning_rate: 6.2500e-06
#
# Epoch 47: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 47/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 143s 18s/step - loss: 0.1920 - mad: 0.0102 - mean_absolute_error: 0.4380 - rmse: 0.4382 - val_loss: 0.1606 - val_mad: 0.0123 - val_mean_absolute_error: 0.4003 - val_rmse: 0.4007 - learning_rate: 6.2500e-06
#
# Epoch 48: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 48/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 145s 18s/step - loss: 0.1918 - mad: 0.0096 - mean_absolute_error: 0.4378 - rmse: 0.4380 - val_loss: 0.1601 - val_mad: 0.0123 - val_mean_absolute_error: 0.3996 - val_rmse: 0.4001 - learning_rate: 6.2500e-06
#
# Epoch 49: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 49/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 139s 17s/step - loss: 0.1916 - mad: 0.0086 - mean_absolute_error: 0.4375 - rmse: 0.4377 - val_loss: 0.1612 - val_mad: 0.0125 - val_mean_absolute_error: 0.4010 - val_rmse: 0.4015 - learning_rate: 6.2500e-06
#
# Epoch 50: LearningRateScheduler setting learning rate to 6.24999984211172e-06.
# Epoch 50/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 141s 18s/step - loss: 0.1915 - mad: 0.0112 - mean_absolute_error: 0.4373 - rmse: 0.4376 - val_loss: 0.1518 - val_mad: 0.0125 - val_mean_absolute_error: 0.3892 - val_rmse: 0.3897 - learning_rate: 6.2500e-06
#
# Epoch 51: LearningRateScheduler setting learning rate to 3.12499992105586e-06.
# Epoch 51/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 138s 17s/step - loss: 0.1913 - mad: 0.0120 - mean_absolute_error: 0.4371 - rmse: 0.4374 - val_loss: 0.1542 - val_mad: 0.0127 - val_mean_absolute_error: 0.3922 - val_rmse: 0.3927 - learning_rate: 3.1250e-06
#
# Epoch 52: LearningRateScheduler setting learning rate to 3.12499992105586e-06.
# Epoch 52/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 142s 17s/step - loss: 0.1911 - mad: 0.0093 - mean_absolute_error: 0.4370 - rmse: 0.4372 - val_loss: 0.1591 - val_mad: 0.0130 - val_mean_absolute_error: 0.3984 - val_rmse: 0.3989 - learning_rate: 3.1250e-06
#
# Epoch 53: LearningRateScheduler setting learning rate to 3.12499992105586e-06.
# Epoch 53/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 137s 17s/step - loss: 0.1910 - mad: 0.0096 - mean_absolute_error: 0.4369 - rmse: 0.4371 - val_loss: 0.1592 - val_mad: 0.0131 - val_mean_absolute_error: 0.3985 - val_rmse: 0.3990 - learning_rate: 3.1250e-06
#
# Epoch 54: LearningRateScheduler setting learning rate to 3.12499992105586e-06.
# Epoch 54/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 137s 17s/step - loss: 0.1909 - mad: 0.0098 - mean_absolute_error: 0.4368 - rmse: 0.4370 - val_loss: 0.1582 - val_mad: 0.0133 - val_mean_absolute_error: 0.3972 - val_rmse: 0.3978 - learning_rate: 3.1250e-06
#
# Epoch 55: LearningRateScheduler setting learning rate to 3.12499992105586e-06.
# Epoch 55/60
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 146s 18s/step - loss: 0.1908 - mad: 0.0086 - mean_absolute_error: 0.4367 - rmse: 0.4368 - val_loss: 0.1556 - val_mad: 0.0134 - val_mean_absolute_error: 0.3938 - val_rmse: 0.3944 - learning_rate: 3.1250e-06

# %%
# Evaluate the model on the test data
evaluation = model.evaluate(features_test, labels_test)

# Print the evaluation results with four decimal places
print(f"Evaluation Loss (MSE): {evaluation[0]:.5f}")
print(f"Evaluation MAE: {evaluation[1]:.5f}")
print(f"Evaluation RMSE: {evaluation[2]:.5f}")
print(f"Evaluation MAD: {evaluation[3]:.5f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - loss: 0.1491 - mad: 0.0083 - mean_absolute_error: 0.3859 - rmse: 0.3861
# Evaluation Loss (MSE): 0.14909
# Evaluation MAE: 0.38589
# Evaluation RMSE: 0.38612
# Evaluation MAD: 0.00834

# %%
# Plot the Train loss and validation loss
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss and validation loss')
plt.xlabel('Epoch')
plt.ylabel('Metric Value')
plt.legend()
plt.show()

# %%
# Plot the train rmse and validation rmse
plt.figure(figsize=(12, 6))
plt.plot(history.history['rmse'], label='Train RMSE')
plt.plot(history.history['val_rmse'], label='Validation RMSE')
plt.title('Train RMSE Vs Validation RMSE')
plt.xlabel('Epoch')
plt.ylabel('Metric Value')
plt.legend()
plt.show()

# %%
# Plot the tain MAD and validation MAD
plt.figure(figsize=(12, 6))
plt.plot(history.history['mad'], label='Train MAD')
plt.plot(history.history['val_mad'], label='Validation MAD')
plt.title('Train MAD Vs Validation MAD')
plt.xlabel('Epoch')
plt.ylabel('Metric Value')
plt.legend()
plt.show()

# %%
model.save('CNN3d(E08).h5')

# %%
import os
import cv2
import numpy as np

# Function to save all split videos from the test set to a folder
def save_all_split_videos(video_data, save_dir, SEQUENCE_LENGTH=30, IMAGE_HEIGHT=128, IMAGE_WIDTH=128, fps=30):
    """
    Save all split videos from the video data as individual video files in the specified directory.

    Args:
        video_data: Numpy array containing video data of shape (num_videos, SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3).
        save_dir: Directory to save the videos.
        SEQUENCE_LENGTH: Number of frames per video (default is 16).
        IMAGE_HEIGHT: Height of the frames (default is 64).
        IMAGE_WIDTH: Width of the frames (default is 64).
        fps: Frames per second for the output videos (default is 30).
    """
    # Create the save directory if it doesn't exist
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    # Iterate over all videos in the dataset
    for video_index in range(video_data.shape[0]):
        video_frames = video_data[video_index]  # Shape: (SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3)

        # Prepare the VideoWriter object to save the video
        video_filename = os.path.join(save_dir, f"split_video_{video_index + 1}.mp4")
        fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Use 'mp4v' for .mp4 format
        video_writer = cv2.VideoWriter(video_filename, fourcc, fps, (IMAGE_WIDTH, IMAGE_HEIGHT))

        # Add frames to the video
        for frame in video_frames:
            # Ensure the frame has values in the range [0, 255] and convert to uint8
            frame_rgb = (frame * 255).astype(np.uint8)
            # Convert RGB to BGR for OpenCV
            frame_bgr = cv2.cvtColor(frame_rgb, cv2.COLOR_RGB2BGR)
            # Write the frame to the video
            video_writer.write(frame_bgr)

        # Release the video writer
        video_writer.release()
        print(f"Video {video_index + 1} saved to: {video_filename}")

# Example usage: Save all split videos from the test set
# Make sure `features_test` is defined before calling this function
save_all_split_videos(features_test, save_dir="/kaggle/working/split_videos")
# Out:
# Video 1 saved to: /kaggle/working/split_videos/split_video_1.mp4
# Video 2 saved to: /kaggle/working/split_videos/split_video_2.mp4
# Video 3 saved to: /kaggle/working/split_videos/split_video_3.mp4
# Video 4 saved to: /kaggle/working/split_videos/split_video_4.mp4
# Video 5 saved to: /kaggle/working/split_videos/split_video_5.mp4
# Video 6 saved to: /kaggle/working/split_videos/split_video_6.mp4
# Video 7 saved to: /kaggle/working/split_videos/split_video_7.mp4
# Video 8 saved to: /kaggle/working/split_videos/split_video_8.mp4
# Video 9 saved to: /kaggle/working/split_videos/split_video_9.mp4
# Video 10 saved to: /kaggle/working/split_videos/split_video_10.mp4
# Video 11 saved to: /kaggle/working/split_videos/split_video_11.mp4
# Video 12 saved to: /kaggle/working/split_videos/split_video_12.mp4
# Video 13 saved to: /kaggle/working/split_videos/split_video_13.mp4
# Video 14 saved to: /kaggle/working/split_videos/split_video_14.mp4
# Video 15 saved to: /kaggle/working/split_videos/split_video_15.mp4
# Video 16 saved to: /kaggle/working/split_videos/split_video_16.mp4

# %%
# Example prediction for a new video
video_path = '/kaggle/working/split_videos/split_video_1.mp4'

# Assuming `process_video` function is implemented, use it to preprocess the video input
def process_video(video_path):
    # Example: Preprocessing video to match the input shape of (SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3)
    # You should implement this based on your dataset and requirements
    video_data = np.random.random((SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3))  # Replace with real video processing code
    return np.expand_dims(video_data, axis=0)  # Expand dims to add batch dimension

# Predict for a new video
predicted_score = model.predict(process_video(video_path))
scaled_score = predicted_score * 99 + 1
print(f"Predicted Score: {scaled_score[0][0]:.2f}")  # Assuming `predicted_score` is a 2D array
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 542ms/step
# Predicted Score: 30.00
